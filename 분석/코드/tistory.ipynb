# %%
#def tistory_crawling(search_name) , 전체 라인 한칸씩 탭하고 input()제거할 것.
import bs4
import requests
from urllib import parse
import re

session = requests.Session()
header = {"User-Agent":"Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/81.0.4044.138 Safari/537.36"}

print("작품이름 -> ")
search_name=input()
tmp = search_name + "리뷰"

url = "https://search.daum.net/search?w=blog&nil_search=btn&DA=STC&enc=utf8&q="+parse.quote(tmp) + "&f=section&SA=tistory&page=1"
#For문 사용시 마지막 count가 1씩 올라감.
r=requests.get(url)
c=r.content
html = bs4.BeautifulSoup(c, "html.parser")

main=html.find('div',{'class','coll_cont'})

total=html.find('span',{'class','txt_info'}).text.split("/ ")[1].replace("건","").replace(",","")
print(int(total))
ul=main.find('ul')
li_s=ul.findAll('li')
for li in li_s:
    url=li.find('a').attrs['href'].replace(".com/",".com/m/")
    r=session.get(url,headers=header)
    html = bs4.BeautifulSoup(r.content, "html.parser")
    
    title_area=html.find('div',{'class','blogview_tit'})

    title=title_area.find('h2',{'class','tit_blogview'})
    print("제목 : " + title.text)

    author=title_area.find('span',{'class','txt_by'})
    print("작성자 : " + author.text)

    info_area=html.find('div',{'class','blogview_info'})
    date=info_area.find('time',{'class','txt_date'})
    print("작성일시 : " + date.text)

    post_area=html.find('div',{'class','blogview_content'})

    posts=post_area.findAll('p')
    print("\n----------------------------------------\n" + "게시글\n" + "----------------------------------------\n")
    for post in posts:
        print(post.text)
    print("\n----------------------------------------\n")
# Out:
# 작품이름 ->
# 닥터 최태수
# 17
# 제목 : [리뷰] 닥터 최태수[조석호_현대 판타지_완결]
# 작성자 : 잔망탱이
# 작성일시 : 2019. 4. 8. 00:55
#
# ----------------------------------------
# 게시글
# ----------------------------------------
#
# <닥터 최태수>
#
# 저자 : 조석호
# 출판사 : 마이더스스토리
# 장르 : 현대판타지, 성장물, 전문직, 환상체험
# 완결 유무 : 완결(3,236화)
# 책 소개
#
# “그래. 환자를……. 무서워해야 돼.
# 두려워하고 손발이……. 떨리는 공포도 느껴야지.”“…….”“거기서 도망치지……. 않아야 진짜 의사가 되는 거야.”“말씀하시면 출혈이 계속돼요.”다급함에 젖어든 반항적인 태수의 말투에도 노인은 미소를 잃지 않고 말했다.“언제고 어느 때고……. 도망치고 싶을 때가 올 거야. 그땐 지금을……. 떠올려.
# 환자가 의지할 사람은……. 자네 한 사람 뿐이라는 걸 말이야.”삶과 죽음이 교차하는 그 시간이 지났다.그후!!!!!!
# 평범했던 한 인턴의 운명이 송두리째 바뀌었다.살릴 수 있다면?살릴 가능성이 있다면?어떤 상황에서라도 메스를 들어야 한다.그런 불굴의 신념 하나면 충분하다.닥터 최태수, 그는 진정한 외과의사의 길을 택했다.
# 리뷰
#
# 정말 길고 길었던 조석호 작가님의 "닥터 최태수"의 완결이 나왔어요.
# 주인공 최태수라는 사람이 의사로서 성장하는 모습을 다루는 소설로서 3,236화라는 어마어마한 연재 분량으로 최근 완결이 되었지요.
# 저는 아직 완결까지 읽지는 못했지만 지금도 꾸준하게 읽고 있습니다.
# 읽을 때마다 느끼는 것이지만 조석호 작가님의 정보 수집력에 항상 놀라게 되는 것 같아요.
# 메디컬 소설 자체가 전문적인 용어도 많고 수술 방법에 대해서도 다양한 지식이 있어야 하는데 의사도 아닌 분이 전문용어는 물론이고 그 상황이 상상될 정도로 묘사하는 필력에서 항상 감탄을 금하지 못했어요.
# 이 정도로 준비하려면 거의 병원에서 살면서 의사들에게 물어보고 다양한 의학자료를 읽으면서 정보를 취합하는 것을 1~2년은 해야 가능할 것 같은데 생각할수록 존경스럽네요.
# 언제나 흥미진진하게 만들어서 몰입감을 높여주는 이 소설의 초반부 줄거리를 알려드릴게요.
# (적다 보니 조금 길어요...)
# 서울 연성 대학병원의 흉부외과 인턴 최태수.
# 인턴도 의사이지만 끝없는 갈굼과 스스로의 판단으로 아무것도 할 수 없는 의사가 인턴이다.
# 하루하루 힘들게 병원 생활을 이어나가던 그는 오래간만에 찾아온 쉬는 날에 산에 올라가는 도중 낙상사고를 당한 외국 노인을 발견하게 된다.
# 그는 급하게 응급조치를 하지만 회생 불가능한 상태였는데 의식이 있던 노인과의 마지막 대화를 나누고 그의 임종을 지켜보고 나서 그의 삶에 변화가 찾아온다.
# 차트를 보는 것도 익숙해지고 환자를 지켜보면서도 다양한 조치 방법이 떠오르는 현상을 경험하는데 그게 실제 취할 수 있는 최적의 방법이라는 것에 다시 한번 놀라게 된다.
# 이런 알 수 없는 일들을 계속 겪으면서 의문스러워하던 그는 곧 놀라운 소식을 듣게 되었는데, 그것은 자신이 산에서 임종을 지켜보았던 노인이 세계 최고의 흉부외과 권위자였던 리차드 카프레네였다는 것이다.
# 그 사실을 알게 되면서 자신이 꾸었던 카프레네의 꿈의 내용을 기억해내고 그의 기억과 경험이 자신에게 전이된 것이라는 생각을 가지게 된다.
# 그러나 그럴 경우가 없다는 사실에 잠시 그 생각을 떨쳐내지만 병원 생활을 하면서 변화된 자신의 기억과 익숙함에 다시 상기하게 되고, 도서관에서 카프레네 의사가 집필한 책을 읽으면서 확신을 가지게 된다.
# 그 후 병원에 근무하면서 다양한 일을 겪게 되고 환자를 위하는 마음과 살리고자 하는 마음이 강한 최대수는 자신이 살릴 수 있는 환자가 있다면 앞뒤를 생각하지 않고 일단 환자를 먼저 돌본다.
# 그러나 현실에서 인턴은 아무런 힘이 없는 존재라서 최태수의 행동과 판단이 여러 가지 문제로 구설수에 휘말리게 되고, 끝내 동기의 실수를 감싸다가 그토록 원하던 병원에 쫓겨나게 된다.
# 이후 다른 병원을 찾던 중에 평소 그를 좋게 생각하던 교수로부터 지방 병원을 추천받게 되면서 그의 인생이 새롭게 시작된다.
# (자세한 내용은 자제)
# ※ 장점 ※
#
# 1. 항상 노력하는 주인공
# 매 화마다 주인공 최태수가 환자를 살리고자 하는 열망과 노력을 알 수 있는데 감탄할 정도이다.
# 자신보다는 환자를 생각하여 더욱 노력하고, 준비하고, 공부하는 모습에서 자만과 나태함을 느낄 수 없다.
# 또, 언제나 최선을 다하는 그의 모습을 보면서 주변에 등장하는 다른 의사들도 덩달아 변화하게 되는데 이것은 여러모로 서로에게 좋은 일이라고 생각한다.
#
# 2. 현실성 높은 묘사
# 조석호 작가님의 묘사력은 정말 뛰어난 것 같다.
# 긴박감이 느껴지는 수술 현장은 물론이고 환자를 살리고자 하는 의사들의 노력이 글을 읽으면서 상상이 되는 수준이다.
# 수술하는 부분에서 1분 1초가 아쉬운 상황이 눈 앞에 그려지는데 어느새 덩달아 같이 긴장하게 되어 집중하게 된다.
# 또, 인간미 넘치는 인물들의 대화에서 삶과 죽음에 대해 다시 한번 생각하게 되고, 상황에 따라서 재미도 있고 감동도 있어서 읽으면서도 여운이 남게 된다.
#
# 3. 철저한 조사와 탄탄한 스토리 라인
# 아직 완결까지는 읽지 못하였기에 끝부분이 어떤지는 모르겠다.
# 그러나 지금까지 읽었던 부분에서는 스토리가 자연스럽게 이어지고 있었다.
# 사건/사고가 끊이지 않는 곳이 병원이기에 이야기의 소재가 넘치는 것도 맞겠지만 매 순간 환자의 병명이 달라지고 수술방법도 달라지는데 대처하는 방법이나 표현이 억지스럽지는 않다.
# 또, 의사들의 전문용어는 물론 수술 용어 및 도구의 명칭, 상황을 설명하는 내용에서는 조석호 작가님의 사전 조사가 얼마나 철저했는지 알 수 있다.
# 이러한 노력이 있었기에 지금의 소설이 있게 된 것 같다.
# ※ 단점 ※
#
# 아직까지는 뚜렷하게 단점이라고 생각되는 부분이 없다.
# 이 부분은 완결까지 읽은 후에 다시 적어보려고 한다.
# 조석호 작가님의 "닥터 최대수" 리뷰는 이 정도에서 끝낼게요.
# 환자를 살리기 위해서 치열하게 살아가는 의사들의 모습을 보여주는 이 소설을 다른 분들에게도 추천합니다.
# 그래도 개인의 취향에 따라서 호불호가 달라질 테니 모두들 직접 읽어보시고 판단해보시기 바랍니다^^
#
# 그럼 이만~!
#
# ----------------------------------------
#
# 제목 : 닥터 최태수 - 조석호 / 소설 리뷰
# 작성자 : LeeJK0217
# 작성일시 : 2017. 8. 12. 11:26
#
# ----------------------------------------
# 게시글
# ----------------------------------------
#
#
# 닥터 최태수 - 조석호
#
# 조석호 작가의 의학 판타지 소설 <닥터 최태수> 리뷰입니다.
#
# 어리버리한 인턴 나부랭이가 세계적으로 유명한 의사 카프레네의 실족사 현장에서 그의 죽음을 지킵니다. 그리고 그의 의학 지식과 경험을 그대로 물려받게 되는데요. 그것을 바탕으로 의술을 펼치면서 주인공 최태수는 카프레네의 모든 것을 자신의 것으로 만들기 위해서 엄청난 노력을 기울입니다. 그렇게 카프레네를 이어서 세계 최고의 의사가 되기 위한 주인공 최태수의 이야기를 그려 낸 소설입니다.
#
# "사"자가 들어간 이야기라서 그런지 흥미로우면서 재미가 있는 소설입니다. 개인적으로 메디컬 드라마를 좋아해서 꾸준하게 보는 편인데요. 이번 소설 <닥터 최태수>도 메디컬 드라마와 같은 퀄리티를 자랑하는 소설입니다. 작가가 의학적 지식이 상당한 것 같아요.
#
# 응급실의 긴박한 상황이나 수술실에서 펼쳐지는 여러 상황이 사실감 있고 꼼꼼하게 표현되어서 꼭 드라마를 보는듯한 느낌입니다. 평소 의학 드라마를 좋아하는 분이라면 꽤 마음에 드실 소설일 겁니다.
#
# 현재 1900화가 넘도록 연재되고 있지만, 여전히 인기를 끌고 있는 소설 중 하나입니다. 개인적으로 의학 판타지 소설 중에서 최고인듯하네요. ^^
#
# ----------------------------------------
#
# 제목 : [리뷰] 닥터 최태수 / 의료
# 작성자 : 놈핑이
# 작성일시 : 2019. 10. 25. 12:55
#
# ----------------------------------------
# 게시글
# ----------------------------------------
#
#
# 카카오페이지 총 3236화 중 360화 하차 / 의료
#
# (중도 하차 작품은 소개글을 작성하지 않습니다.)
#
#
# ★★★☆☆ 몰입력이 뛰어난 글
#
# 아마도 단기간 내에 이렇게 정신없이 많이 읽었던 글은 이만한 글이 없었던 것 같다. 그만큼 이 글은 몰입력이 엄청나게 뛰어나고 정말 순식간에 시간을 보낼 수 있었다. 편수가 꽤나 많긴 하지만 한가지 글을 오랫동안 읽고 싶다면 꽤나 재밌게 읽을 수 있을 듯.
#
# 배경은 현대이지만, 주인공은 카프레네라는 세계적인 명의의 모든 지식을 전수 받게 되는 판타지적 요소가 섞인 내용이다. 이런 류의 소설은 처음 읽어봤지만, 게다가 의학 소설이라 일반 독자들이 이해하기 어렵지 않을까 걱정했지만, 그런 걱정을 불식시키고 매우 쉽고 편하게 읽을 수 있었다.
#
# 다만 중도하차하게 된 가장 큰 이유는, 너무나도 작위적인 전개와 설정 때문이다. 물론 이야기를 전개해 나가면서 당연히 어느정도의 작위적인 설정은 들어갈 수 밖에 없다. 그것이 스토리를 이어나가기 위한 장치이든, 아니면 주인공을 돋보이게 하는 장치이건. 하지만 이 작품에서 그러한 설정은 정말 도를 지나칠 정도로 과하다.
#
# 격전지인 카슈미르에 해외봉사를 가는 간호사가 피공포증이 있다고 심각한 외상을 입은 환자를 버려두질 않나, 생판 처음 보는 통역원이 갑자기 응급수술에 투입되고 어느순간 되니 의사 간호사 쌈싸다구 날리는 의료지식을 쌓아놓고 있고. 게다가 한국 의료체계의 권위적인 모습을 '환자가 먼저다'는 캐치프레이즈로 깨부수는 모습을 보여주고 싶은 것 같은데, 계속해서 보다보니 이건 권위타파가 아니라 걍 싸가지가 없는 거다. 한국 의사들은 전부다 무능력자에 권위만 중시하는 쓰레기들로 보이게 하는 것이다.
#
# 그래도 동성 종합병원 편까지는 스스로가 그 권위에 도전하고 뚫고 나가는 모습을 보며 답답한 한국사회에서 대리만족의 해갈을 느꼈지만, 특히 NGO에서 근무했던 제임스가 한국으로 돌아오고 나서부턴 이게 뭔가 싶다. 막히는 게 있으면 일단 제임스 콜해놓고 와서 뭐라해주세요~ 징징징. 무슨 권위주의 때려부수기 위해서 더 큰 권위에 기대는 게 올바른 모습인가? 이부분부터 흥미가 급감해서 하차하게 됐다.
#
# 게다가 무슨 카슈미르는 모든 게 용서되는 만능 치트키다. 겨우 레지던트 4년차인 최태수가 외과 과장들 씹바를 정도로 실력과 지식을 갖고 있는 것도 카슈미르, 제임스가 그를 무조건 신뢰하는 것도 카슈미르, 그 외에도 뭐 있다 싶으면 다 카슈미르랜다. 물론 NGO 밑에서 해외 의료봉사를 다녔다는 것은 굉장히 훌룡한 일이지만, 그저 뭐 만능 치트키가 되어버린 것 같아서 별로였다.
#
# 물론 내가 읽은 건 겨우 300편. 전체가 3600편이 넘어가니 겨우 10% 정도 읽어놓고 전체를 판단하기엔 좀 모자랄 것이다. 그래도 이 소설에서 벌어지는 사건들의 패턴은 뻔해보이니 계속 읽더라도, 응급환자발생 - 한국의사가 막음 - 태수랑 싸움 - 제임스 콜 or 병원장 도움 - 성공률 10%미만 수술이지만 그냥 성공 이 패턴이 반복될 게 뻔해서 하차했다.
#
# ----------------------------------------
#
# 제목 : 웹 소설 [닥터 최태수] 리뷰, TV 드라마 흉부외과로 재 탄생
# 작성자 : 티스토리언
# 작성일시 : 2018. 10. 12. 15:30
#
# ----------------------------------------
# 게시글
# ----------------------------------------
#
#
# .
#
# 총점 : ★★★★☆
#
#
#     똑같은 패턴의 반복이지만 숨도 못쉬고 몰입하게하는 작품
#
#
#
#   평소 드라마를 즐겨 보지 않는 나지만, 어느날 우연히 드라마를  틀어놓고 딴짓을 하던 중 익숙한 이름이 들렸다. [외과의사 최태수] '어?'하는 기분으로 드라마를 보게되었는데 내가 예전에 읽었던 웹 소설 [닥터 최태수]를 모태로한 드라마가 맞았다. 그래서 관심을 가지고 드라마를 보긴 했지만, 원작을 읽었던 나에게 지나친 각색은 부담스럽게 다가왔고 결국 TV를 끄게 되었다. 결론, 원작이 더 재밌다.
#
#
#   이 작품은 판타지 소설에 분류 되지만, 우리가 익히 알고있는 판타지와는 성격이 다르다. 지극히 현실적이다. 판타지적 요소는 최태수가 얻게된 기연, 세계적인 외과의의 지식이 태수에게 전해진 것 뿐이다. 사실, 그냥 평범한 의학 소설에 재미를 위해 조금의 판타지적 요소를 첨가한 것으로 보인다.
#
#
#  나는 평소 의료계에 무지했다. 의사면 다 같은 의사인줄만 알았다. 이 소설을 읽고 인턴 레지던트 전문의 과정이 있는줄 알았고 그들이 의사로써 환자를 치료할 수 있게 될 때 까지 얼마나 많은 노력을 하는지 알게되었다.
#
#
#  내 리뷰만 보면 그냥 평범한 의학 소설이잖아? 라고 생각할 수 있지만, 왠만한 소설보다 훨씬 더 재미있고 흡입력 있다. 교훈도 있고 울림도 있다. 다만... 장편소설임에도 불구하고 너무 같은 패턴이라 후반부가면 조금 뻔해지는 감이 없지않아 있는데 훌륭한 소설임에는  틀림이 없다.
#
#
# 드라마도 재미있지만 원작 소설이 더 재미있는 이런 작품은 한번 읽어봄직 하지 않을까? 의학드라마 좋아하시는분들께는 강력 추천하는 바이다.
#
#
# ----------------------------------------
#
# 제목 : [리뷰]닥터 최태수(1~1349화) - 조석호
# 작성자 : 동네책방
# 작성일시 : 2016. 11. 18. 13:46
#
# ----------------------------------------
# 게시글
# ----------------------------------------
#
#
# 제 목: 닥터 최태수
# 지은이: 조석호
# 출판사: 마이더스스토리
# 출판일: 2016년 11월 18일
# 별 점: ★★★
#
# 조석호 작가님의 닥터 최태수(1~1349화 연재중)입니다. 회사 동료가 결제해 놓은 것을 무임승차로 읽었습니다. 500화 이후에는 반복되는 내용에 지칩니다. 무임이 아니었으면 중간에 하차했을 겁니다.
#
#
#
# 주요내용은 환자를 먼저 생각하는 주인공(최태수)이 세계적인 명의 카프레네의 실족사 현장에 있다 그의 기억 중 의술에 관련된 지식을 얻습니다. 환자를 먼저 생각하며 행동하다가 연성대학병원을 나오게 되고 충청권에 있는 병원에 가게 됩니다.
#
# 당연히 옮긴 병원에서도 문제가 발생하여 해외에서 봉사활동을 하며 실력을 쌓습니다(카프레네의 기억에 있던 지식을 자기 것으로 만듬). 그런 후에 돌아와서 레지던트 임에도 전문의보다 뛰어난 실력으로 승승장구 한다는 내용입니다.
#
# 최근에 나온 현판치고 주인공 능력이 과하지 않은 것이 좋습니다. 문제는 현실성이 없는 주인공의 행동들이 눈에 거슬리고 반복되는 어려운 수술을 성공하는 스토리만 나오니 지쳐서 대충대충 읽게 만듭니다.
#
# 이 책을 읽기 바로 전에 감동적인 실화를 담고 있는 '숨결이 바람 될 때'를 읽어서 더 평가가 박한지도 모르겠습니다.
#
#
#
#
#   : 반복적인 내용에 지친다.
#
# 별점 3점
#
#
# ----------------------------------------
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-5-bc3ece7d4680> in <module>
#      30     title_area=html.find('div',{'class','blogview_tit'})
#      31
# ---> 32     title=title_area.find('h2',{'class','tit_blogview'})
#      33     print("제목 : " + title.text)
#      34
#
# AttributeError: 'NoneType' object has no attribute 'find'

# %%
import bs4
import requests
from urllib import parse
import re

session = requests.Session()
header = {"User-Agent":"Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/81.0.4044.138 Safari/537.36"}

print("작품이름 -> ")
search_name=input()
tmp = search_name + "리뷰"

base_url = "https://search.daum.net/search?w=blog&nil_search=btn&DA=STC&enc=utf8&q="+parse.quote(tmp) + "&f=section&SA=tistory&page={}"
n=1
pre_page=None
while True:
    url=base_url.format(n)
    r=requests.get(url)
    c=r.content
    html = bs4.BeautifulSoup(c, "html.parser")
        
    count=html.find('span',{'class','txt_info'})
    if(count==None):
        print("프로그램 종료합니다")
        break
    page=count.text.split(" /")[0]
    if(pre_page==page):
        print("프로그램 종료합니다")
        break
    pre_page=page
    print(page)
    n=n+1
