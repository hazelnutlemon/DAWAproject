# %%
import Date_List as DL

date_list=DL.make_date_list()
print(date_list)

print(DL.date_list_pos('2010-01-01'))

"""
date_array[0][1]=date_array[0][1]+90.2
date_array[0][2]+=1
print(date_array[0])

result=date_array[0][1]/date_array[0][2] # DB에 저장할 데이터
print("Date : " + date_array[0][0])
print("긍정도 : " + str(result))
"""
# Out:
# [['2010-01-01', 0, 0], ['2010-02-01', 0, 0], ['2010-03-01', 0, 0], ['2010-04-01', 0, 0], ['2010-05-01', 0, 0], ['2010-06-01', 0, 0], ['2010-07-01', 0, 0], ['2010-08-01', 0, 0], ['2010-09-01', 0, 0], ['2010-10-01', 0, 0], ['2010-11-01', 0, 0], ['2010-12-01', 0, 0], ['2011-01-01', 0, 0], ['2011-02-01', 0, 0], ['2011-03-01', 0, 0], ['2011-04-01', 0, 0], ['2011-05-01', 0, 0], ['2011-06-01', 0, 0], ['2011-07-01', 0, 0], ['2011-08-01', 0, 0], ['2011-09-01', 0, 0], ['2011-10-01', 0, 0], ['2011-11-01', 0, 0], ['2011-12-01', 0, 0], ['2012-01-01', 0, 0], ['2012-02-01', 0, 0], ['2012-03-01', 0, 0], ['2012-04-01', 0, 0], ['2012-05-01', 0, 0], ['2012-06-01', 0, 0], ['2012-07-01', 0, 0], ['2012-08-01', 0, 0], ['2012-09-01', 0, 0], ['2012-10-01', 0, 0], ['2012-11-01', 0, 0], ['2012-12-01', 0, 0], ['2013-01-01', 0, 0], ['2013-02-01', 0, 0], ['2013-03-01', 0, 0], ['2013-04-01', 0, 0], ['2013-05-01', 0, 0], ['2013-06-01', 0, 0], ['2013-07-01', 0, 0], ['2013-08-01', 0, 0], ['2013-09-01', 0, 0], ['2013-
# ...

# %%
from flask import Flask

app = Flask(__name__)


@app.route('/')
def hello_world():
    return '<h1>Hello World!</h1><input type="textbox"/>'


if __name__ == '__main__':
    app.run()
# Out:
#  * Serving Flask app "__main__" (lazy loading)
#  * Environment: production
#    WARNING: This is a development server. Do not use it in a production deployment.
#    Use a production WSGI server instead.
#  * Debug mode: off
#  * Running on http://127.0.0.1:5000/ (Press CTRL+C to quit)
# 127.0.0.1 - - [10/Sep/2020 22:33:08] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [10/Sep/2020 22:33:08] "GET /favicon.ico HTTP/1.1" 404 -
