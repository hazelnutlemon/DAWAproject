# %% [markdown]
# # 리디북스 - CSS Selector 이용

# %%
import requests
from bs4 import BeautifulSoup

req=requests.get('https://ridibooks.com/books/875103701')
source=req.text
soup=BeautifulSoup(source, 'html.parser')

# 제목
title_list=soup.select("#page_detail > div.detail_wrap > div.detail_body_wrap > section > article.detail_header.trackable > div.header_info_wrap > div.info_title_wrap > h3")
title=title_list[0].text
title=title[5:] #'[연재] '가 제목 앞에 붙음

# 저자
author_list=soup.select("#page_detail > div.detail_wrap > div.detail_body_wrap > section > article.detail_header.trackable > div.header_info_wrap > div > p.metadata.metadata_writer > span > a")
author=author_list[0].text

# 출판사
publisher_list=soup.select("#page_detail > div.detail_wrap > div.detail_body_wrap > section > article.detail_header.trackable > div.header_info_wrap > div > p.metadata.file_info.publisher_info > a")
publisher=publisher_list[0].text

# 총 연재화수 - 정수
book_count_list=soup.select("#page_detail > div.detail_wrap > div.detail_body_wrap > section > article.detail_header.trackable > div.header_info_wrap > div > p.metadata.metadata_info_series_complete_wrap > span.metadata_item.book_count")
book_count=book_count_list[0].text
book_count=book_count[2:len(book_count)-1]
book_count=int(book_count)

# 완결 여부
complete_list=soup.select("#page_detail > div.detail_wrap > div.detail_body_wrap > section > article.detail_header.trackable > div.header_info_wrap > div > p.metadata.metadata_info_series_complete_wrap > span.metadata_item.not_complete")
if complete_list[0].text=='미완결':
    complete='미완결'
else:
    complete='완결'

# 출간일
published_date_list=soup.select("#page_detail > div.detail_wrap > div.detail_body_wrap > section > article.detail_header.trackable > div.Header_Metadata_Block > ul > li.Header_Metadata_Item.book_info.published_date_info > ul > li")
published_date=published_date_list[0].text
published_date=published_date[2:13]
    
# 최근 업데이트일
recent_update_list=soup.select("#SeriesListWrap > ul.module_compact_book_list.white_theme.js_compact_book_list > li > div > div > div.table_cell.book_info > div > ul > li.info_reg_date")
update=recent_update_list[book_count-1].text
update=update[6:16]

# 표지 사진
img=soup.find("img")
img_src=img.get("src")

# 카테고리
category_list=soup.select("#page_detail > div.detail_wrap > div.detail_body_wrap > section > article.detail_header.trackable > div.header_info_wrap > p > a")
category=category_list[1].text

# 별점 점수
star_rate_list=soup.select("#page_detail > div.detail_wrap > div.detail_body_wrap > section > article.detail_header.trackable > div.header_info_wrap > div > p > span > span.StarRate_Score")
star_rate=star_rate_list[0].text

# 별점 참여자
star_rate_count_list=soup.select("#page_detail > div.detail_wrap > div.detail_body_wrap > section > article.detail_header.trackable > div.header_info_wrap > div > p > span > span.StarRate_ParticipantCount")
star_rate_count=star_rate_count_list[0].text

# 관심도
preference_list=soup.select("#page_detail > div.detail_wrap > div.detail_body_wrap > section > article.detail_header.trackable > div.header_thumbnail_wrap > div.header_preference > button > span > span.button_text.js_preference_count")
preference=preference_list[0].text

# 책소개
introduction_list=soup.select("#introduce_book > p")
introduction=introduction_list[2].text
introduction= introduction.replace("<[연재] "+title+"> ","")
introduction= introduction.replace("\r","")
introduction= introduction.replace("책 소개","")
introduction= introduction.replace("펼쳐보기 ","")

############################## 결과 출력 #############################

print("제목: " + title)
print("저자: " + author)
print("출판사: " + publisher)
print("표지 url: " + img_src)
print("총 연재화수: ", book_count)
print("완결 여부: " + complete)
print("출간일: " + published_date)
print("최근 업데이트일: " + update)
print("장르: " + category)
print("별점: " + star_rate)
print("별점 참여자: " + star_rate_count)
print("관심도: " + preference)
print("소개: " + introduction)
# Out:
# 제목: 백작가의 망나니가 되었다
# 저자: 유려한
# 출판사: 도서출판 청어람
# 표지 url: //img.ridicdn.net/cover/875125926/xxlarge
# 총 연재화수:  574
# 완결 여부: 미완결
# 출간일: 2018.10.02.
# 최근 업데이트일: 2020.05.08
# 장르: 퓨전 판타지
# 별점: 4.8점
# 별점 참여자: 3,929명
# 관심도: 0
# 소개: 눈을 떠보니 소설 속이었다.
# 그것도 망나니로 유명한 백작가 도련님 몸으로.
#
# 하지만,
# 그렇다고 망나니가 될 순 없잖아?

# %% [markdown]
# # 조아라 - Selenium 이용

# %%
import urllib.request
from selenium import webdriver
import bs4
import requests
from urllib import parse

url = "http://www.joara.com/premium_new/book_intro.html?book_code=1445186"
driver = webdriver.Chrome("C:/project/chromedriver.exe")
driver.get(url)

html=driver.page_source
soup=BeautifulSoup(html, 'lxml')

# 표지 사진
img_class = soup.find(name="div", attrs={"class":"img_s"})
img_tag = img_class.find_all('img')
url_list = []
for a in img_tag:
    url_list.append(a.get('src'))
img_url=url_list[0]

info_class = soup.find(name="div", attrs={"class":"txt_c_sty01"})

# 제목
title_class= info_class.find('a')
title=title_class.text

# 카테고리
category= info_class.strong.text.split(' ')[0].replace("[","")
category= category.replace("]","")

#저자
author_class= info_class.find('span')
author=author_class.text
author= author.replace(" ","")
author= author.replace("\n","")
author= author.replace("/","")

# 총 연재화수
book_count_class = info_class.find(name="div", attrs={"class":"work_view"})
book_count_class= book_count_class.find(name="span", attrs={"class":"select"})
book_count=book_count_class.text.replace("\n","")

# 최근 업데이트일
last_date_class = info_class.find(name="div", attrs={"class":"info_c"})
last_date_class= last_date_class.find(name="span", attrs={"class":"date"})
last_date=last_date_class.text
update=last_date[:10]+'.'

# 완결 여부
complete_class = info_class.find(name="div", attrs={"class":"info_c"})
complete_class= complete_class.find(name="strong")
if complete_class.text=='마지막 연재일':
    complete='미완결'
else:
    complete='완결'

# 조회수, 추천, 선호작
info2_class = info_class.find(name="p", attrs={"class":"info2"})
info2_class = info2_class.find_all(name="span", attrs={"class":"date"})
views = info2_class[0].text.replace(",","") # 조회수
recommend = info2_class[1].text # 추천
like = info2_class[2].text # 선호작

# 책소개
introduction_class = soup.find(name="div", attrs={"class":"t_cont_v"})
introduction=introduction_class.text.replace("\t","")
introduction=introduction.replace("\n","")

############################## 결과 출력 ############################

print("제목: " + title)
print("장르: " + category)
print("저자: " + author)
print("표지 url: " + img_url)
print("총 연재화수: ", book_count)
print("최근 업데이트일: " + update)
print("완결 여부: " + complete)
print("조회수: " + views)
print("추천수: " + recommend)
print("관심도: " + like)
print("소개: " + introduction)

# print("출판사: " + publisher) : 안내 없음
# print("별점: " + star_rate)
# print("별점 참여자: " + star_rate_count)
# print("출간일: " + published_date)

driver.close()
# Out:
# 제목: 튜토리얼 오류로 최강
# 장르: 판타지
# 저자: [북극펭귄]
# 표지 url: http://cf.joara.com/literature_file/20200428_1848521675.jpg_thumb.png
# 총 연재화수:  244편
# 최근 업데이트일: 2020.04.29.
# 완결 여부: 완결
# 조회수: 132908
# 추천수: 506
# 관심도: 724
# 소개: 아팠다. 이미 수십 번은 차인 곳이었는데 아프기는 매번 지독하게 아팠다.“네가 내 것이 되지 못한다면…….”머리에 단어가, 문장이 울려퍼진다. 마치 신의 목소리처럼.“그냥 자살해 줘.”...눈을 떴다.[그럼 지금부터 카운트에 들어갑니다. 한 시간 안에 자신이 도전할 난이도를 선택한 후 문을 열어 주십시오.]‘죽음의 시련’난이도 10 시련의 또 하나의 이름.생존률이 0%의 시련.그곳으로 들어간다.

# %% [markdown]
# ## 조아라 - CSS Selector 이용

# %%
import requests
from bs4 import BeautifulSoup

req=requests.get('http://www.joara.com/premium_new/book_intro.html?book_code=1360670')
source=req.text
soup=BeautifulSoup(source, 'html.parser')

# 제목
title_list=soup.select("#premium_content > div.latest > div.best_list_list_wrap > div.box_sty01 > div > div > div.txt_c_sty01 > strong > em > a")
title=title_list[0].text

# 저자
author_list=soup.select("#premium_content > div.latest > div.best_list_list_wrap > div.box_sty01 > div > div > div.txt_c_sty01 > strong > span > span")
author=author_list[0].text

# 총 연재화수 - 정수
book_count_list=soup.select("#premium_content > div.latest > div.best_list_list_wrap > div.box_sty01 > div > div > div.txt_c_sty01 > div.work_view > span.select > span")
book_count=book_count_list[0].text
book_count=book_count.replace("편","")
book_count=int(book_count)

# 완결 여부
complete_list=soup.select("#premium_content > div.latest > div.best_list_list_wrap > div.box_sty01 > div > div > div.txt_c_sty01 > div.info_c > p.info > strong")
if complete_list[0].text=='마지막 연재일':
    complete='미완결'
else:
    complete='완결'

# 출간일
published_date_list=soup.find("table")
published_date_list=published_date_list.find_all("tr")
published_date_list=published_date_list[book_count]
published_date_list=published_date_list.find_all("a")
published_date=published_date_list[2].text
    
# 최근 업데이트일
recent_update_list=soup.select("#premium_content > div.latest > div.best_list_list_wrap > div.box_sty01 > div > div > div.txt_c_sty01 > div.info_c > p.info > span")
update=recent_update_list[0].text
update=update[:10]+'.'

# 표지 사진 url
img=soup.find("div")
img=soup.find(class_="img_s")
img=img.find("img")
img_src=img.get("src")

# 장르
category_list=soup.select("#premium_content > div.latest > div.best_list_list_wrap > div.box_sty01 > div > div > div.txt_c_sty01 > strong")
category=category_list[0].text
category= category.split(' ')[0].replace("[","")
category= category.replace("]","")

# 조회수 - 정수
count_list=soup.select("#premium_content > div.latest > div.best_list_list_wrap > div.box_sty01 > div > div > div.txt_c_sty01 > div.info_c > p.info2 > span")
views=count_list[0].text
views=views.replace(",","")
views=int(views)

# 추천수 - 정수
recommend=count_list[2].text
recommend=recommend.replace(",","")
recommend=int(recommend)

# 관심도 - 정수
preference=count_list[4].text
preference=preference.replace(",","")
preference=int(preference)

# 책소개
introduction_list=soup.select("#premium_content > div.latest > div.best_list_list_wrap > div.t_cont_v")
introduction=introduction_list[0].text
introduction= introduction.replace("\t","")
introduction= introduction.replace("\r","")
#introduction= introduction.replace("\n","")

############################## 결과 출력 #############################

print("제목: " + title)
print("장르: " + category)
print("저자: " + author)
print("표지 url: " + img_src)
print("총 연재화수: ", book_count)
print("최근 업데이트일: " + update)
print("출간일: " + published_date)
print("완결 여부: " + complete)
print("조회수: ", views)
print("추천수: ", recommend)
print("관심도: ", like)
print("소개: " + introduction)

# print("출판사: " + publisher) : 안내 없음
# print("별점: " + star_rate)
# print("별점 참여자: " + star_rate_count)
# Out:
# 제목: 무한서고의 계약자!
# 장르: 판타지
# 저자: 준솔
# 표지 url: http://cf.joara.com/literature_file/20190418_121420.jpg_thumb.png
# 총 연재화수:  220
# 최근 업데이트일: 2019.06.04.
# 출간일: 19/04/03
# 완결 여부: 완결
# 조회수:  613218
# 추천수:  3965
# 관심도:  724
# 소개:
# 스킬북을 포함한 모든 서적들이 기록되어 있는 무한서고.
# 나는 그런 무한서고를 열람할 수 있는 권능을 얻게 되는데···.

# %% [markdown]
# ## 검색 링크 - 리디

# %%
import requests
from bs4 import BeautifulSoup

def get_info(url, book_id):
    print(url)
    print("리디북스 ID no. " + book_id)
    print("\n-------------------------\n")
    req=requests.get(ridi_url)
    source=req.text
    soup=BeautifulSoup(source, 'html.parser')

    # 제목
    title_list=soup.select("#page_detail > div.detail_wrap > div.detail_body_wrap > section > article.detail_header.trackable > div.header_info_wrap > div.info_title_wrap > h3")
    title=title_list[0].text
    title=title[5:] #'[연재] '가 제목 앞에 붙음

    # 저자
    author_list=soup.select("#page_detail > div.detail_wrap > div.detail_body_wrap > section > article.detail_header.trackable > div.header_info_wrap > div > p.metadata.metadata_writer > span > a")
    author=author_list[0].text

    # 출판사
    publisher_list=soup.select("#page_detail > div.detail_wrap > div.detail_body_wrap > section > article.detail_header.trackable > div.header_info_wrap > div > p.metadata.file_info.publisher_info > a")
    publisher=publisher_list[0].text

    # 총 연재화수 - 정수
    book_count_list=soup.select("#page_detail > div.detail_wrap > div.detail_body_wrap > section > article.detail_header.trackable > div.header_info_wrap > div > p.metadata.metadata_info_series_complete_wrap > span.metadata_item.book_count")
    book_count=book_count_list[0].text
    book_count=book_count[2:len(book_count)-1]
    book_count=int(book_count)

    # 완결 여부
    complete_list=soup.select("#page_detail > div.detail_wrap > div.detail_body_wrap > section > article.detail_header.trackable > div.header_info_wrap > div > p.metadata.metadata_info_series_complete_wrap > span.metadata_item.not_complete")
    if complete_list[0].text=='미완결':
        complete='미완결'
    else:
        complete='완결'

    # 출간일
    published_date_list=soup.select("#page_detail > div.detail_wrap > div.detail_body_wrap > section > article.detail_header.trackable > div.Header_Metadata_Block > ul > li.Header_Metadata_Item.book_info.published_date_info > ul > li")
    published_date=published_date_list[0].text
    published_date=published_date[2:13]
    
    # 최근 업데이트일
    recent_update_list=soup.select("#SeriesListWrap > ul.module_compact_book_list.white_theme.js_compact_book_list > li > div > div > div.table_cell.book_info > div > ul > li.info_reg_date")
    update=recent_update_list[book_count-1].text
    update=update[6:16]

    # 표지 사진
    img=soup.find("img")
    img_src=img.get("src")

    # 카테고리
    category_list=soup.select("#page_detail > div.detail_wrap > div.detail_body_wrap > section > article.detail_header.trackable > div.header_info_wrap > p > a")
    category=category_list[1].text

    # 별점 점수
    star_rate_list=soup.select("#page_detail > div.detail_wrap > div.detail_body_wrap > section > article.detail_header.trackable > div.header_info_wrap > div > p > span > span.StarRate_Score")
    star_rate=star_rate_list[0].text

    # 별점 참여자
    star_rate_count_list=soup.select("#page_detail > div.detail_wrap > div.detail_body_wrap > section > article.detail_header.trackable > div.header_info_wrap > div > p > span > span.StarRate_ParticipantCount")
    star_rate_count=star_rate_count_list[0].text

    # 관심도
    preference_list=soup.select("#page_detail > div.detail_wrap > div.detail_body_wrap > section > article.detail_header.trackable > div.header_thumbnail_wrap > div.header_preference > button > span > span.button_text.js_preference_count")
    preference=preference_list[0].text

    # 책소개
    introduction_list=soup.select("#introduce_book > p")
    for j in introduction_list:
        introduction=j.text
        if(introduction.find("<[연재] "+title+">")>=0):
            introduction= introduction.replace("<[연재] "+title+"> ","")
            introduction= introduction.replace("\r","")
            introduction= introduction.replace("책 소개","")
            introduction= introduction.replace("펼쳐보기 ","")
            break;

    ############################## 결과 출력 #############################

    print("제목: " + title)
    print("저자: " + author)
    print("출판사: " + publisher)
    print("표지 url: " + img_src)
    print("총 연재화수: ", book_count)
    print("완결 여부: " + complete)
    print("출간일: " + published_date)
    print("최근 업데이트일: " + update)
    print("장르: " + category)
    print("별점: " + star_rate)
    print("별점 참여자: " + star_rate_count)
    print("관심도: " + preference)
    print("소개: " + introduction)

#################################################################################

ridi_base="https://ridibooks.com/search/?q="
ridi_work=input("작품 검색 : ")
print("\n-------------------------\n")
ridi_search=ridi_base+ridi_work.replace(" ","+")

req=requests.get(ridi_search)
source=req.text
soup=BeautifulSoup(source, 'html.parser')

url_list=soup.select("#page_search_result > div.result_list_wrapper > article > div.book_macro_wrapper.js_book_macro_wrapper > div")
check=0
for i in url_list:
    if(i.text.find("연재")>0):
        ridi_bookID=i.find(class_="book_thumbnail_wrapper")
        ridi_bookID=ridi_bookID.get("data-book_id_for_tracking")
        ridi_url="https://ridibooks.com/books/"+ridi_bookID
        get_info(ridi_url,ridi_bookID)
        check=1
        #print(book_id)
        break;

if check==0:
    print("검색 결과가 없습니다.")
else:
    print("\n-------------------------\n\n검색 결과 출력 완료")
# Out:
# 작품 검색 : 내게 복종하세요
#
# -------------------------
#
# https://ridibooks.com/books/3049006830
# 리디북스 ID no. 3049006830
#
# -------------------------
#
# 제목: 내게 복종하세요
# 저자: 견우
# 출판사: 뷰컴즈
# 표지 url: //img.ridicdn.net/cover/3049008246/xxlarge
# 총 연재화수:  122
# 완결 여부: 미완결
# 출간일: 2020.02.03.
# 최근 업데이트일: 2020.05.08
# 장르: 판타지물
# 별점: 4.6점
# 별점 참여자: 1,515명
# 관심도: 0
# 소개: 왕세자에게 일방적인 파혼을 당하고,
# 자숙 차 오른 여행길에서 자유를 만끽하던 그때.
#
# [안녕.]
#
# 그것, 아니, 그를 깨워 버렸다.
#
# [나는 나타니엘.]
#
# 그가 말했다.
#
# [여기 사람들은 나를 ‘종말’이라 부르더구나.]
#
# 겨울의 왕 같은 아름다운 남자가, 권태롭고 오만하게 미소 지었다.
#
# ***
#
# “나가게 해 줘요.”
#
# 나타니엘이 손을 뻗었다. 키리에가 그것을 뿌리쳤으나, 뼈가 도드라진 흰 손은 오히려 더 느리고 부드럽게, 키리에의 귀와 뺨 근처를 어루만졌다.
#
# [그런 생각은 하지 않는 게 좋을걸. 묶여 지내고 싶지 않다면.]
#
# 대답 대신, 키리에의 이가 나타니엘의 손가락을 깨물었다.
# 그는 천천히 고개를 숙여, 키리에와 이마를 맞댔다. 코앞의 푸른 눈은 키리에의 보라색 눈동자가 불안에 흔들릴수록 더 황홀에 취하는 것 같았다.
#
# [옷은 알아서 벗도록.]
#
# 나타니엘이 엉망이 된 자신의 소맷자락을 내려다보며 사납게 미소지었다.
#
# [또 허튼짓하면 목줄을 채울 줄 알아.]
#
# -------------------------
# 검색 결과 출력 완료

# %% [markdown]
# ## 검색 링크 - 조아라

# %%
import requests
from bs4 import BeautifulSoup

def get_info(url, book_id):
    print(url)
    print("조아라 ID no. " + book_id)
    print("\n-------------------------\n")
    req=requests.get(url)
    source=req.text
    soup=BeautifulSoup(source, 'html.parser')

    # 제목
    title_list=soup.select("#premium_content > div.latest > div.best_list_list_wrap > div.box_sty01 > div > div > div.txt_c_sty01 > strong > em > a")
    title=title_list[0].text

    # 저자
    author_list=soup.select("#premium_content > div.latest > div.best_list_list_wrap > div.box_sty01 > div > div > div.txt_c_sty01 > strong > span > span")
    author=author_list[0].text

    # 총 연재화수 - 정수
    book_count_list=soup.select("#premium_content > div.latest > div.best_list_list_wrap > div.box_sty01 > div > div > div.txt_c_sty01 > div.work_view > span.select > span")
    book_count=book_count_list[0].text
    book_count=book_count.replace("편","")
    book_count=int(book_count)

    # 완결 여부
    complete_list=soup.select("#premium_content > div.latest > div.best_list_list_wrap > div.box_sty01 > div > div > div.txt_c_sty01 > div.info_c > p.info > strong")
    if complete_list[0].text=='마지막 연재일':
        complete='미완결'
    else:
        complete='완결'

    # 출간일
    published_date_list=soup.find("table")
    published_date_list=published_date_list.find_all("tr")
    published_date_list=published_date_list[book_count]
    published_date_list=published_date_list.find_all("a")
    published_date=published_date_list[2].text
    
    # 최근 업데이트일
    recent_update_list=soup.select("#premium_content > div.latest > div.best_list_list_wrap > div.box_sty01 > div > div > div.txt_c_sty01 > div.info_c > p.info > span")
    update=recent_update_list[0].text
    update=update[:10]+'.'

    # 표지 사진 url
    img=soup.find("div")
    img=soup.find(class_="img_s")
    img=img.find("img")
    img_src=img.get("src")

    # 장르
    category_list=soup.select("#premium_content > div.latest > div.best_list_list_wrap > div.box_sty01 > div > div > div.txt_c_sty01 > strong")
    category=category_list[0].text
    category= category.split(' ')[0].replace("[","")
    category= category.replace("]","")

    # 조회수 - 정수
    count_list=soup.select("#premium_content > div.latest > div.best_list_list_wrap > div.box_sty01 > div > div > div.txt_c_sty01 > div.info_c > p.info2 > span")
    views=count_list[0].text
    views=views.replace(",","")
    views=int(views)

    # 추천수 - 정수
    recommend=count_list[2].text
    recommend=recommend.replace(",","")
    recommend=int(recommend)

    # 관심도 - 정수
    preference=count_list[4].text
    preference=preference.replace(",","")
    preference=int(preference)

    # 책소개
    introduction_list=soup.select("#premium_content > div.latest > div.best_list_list_wrap > div.t_cont_v")
    introduction=introduction_list[0].text
    introduction= introduction.replace("\t","")
    introduction= introduction.replace("\r","")
    #introduction= introduction.replace("\n","")

    ############################## 결과 출력 #############################

    print("제목: " + title)
    print("장르: " + category)
    print("저자: " + author)
    print("표지 url: " + img_src)
    print("총 연재화수: ", book_count)
    print("최근 업데이트일: " + update)
    print("출간일: " + published_date)
    print("완결 여부: " + complete)
    print("조회수: ", views)
    print("추천수: ", recommend)
    print("관심도: ", preference)
    print("소개: " + introduction)

    # print("출판사: " + publisher) : 안내 없음
    # print("별점: " + star_rate)
    # print("별점 참여자: " + star_rate_count)
    
##########################################################################

joara_base="http://www.joara.com/search/search.html?sl_search=book&sl_keyword="
joara_work=input("작품 검색 : ")
print("\n-------------------------\n")
joara_search=joara_base+joara_work.replace(" ","+")

req=requests.get(joara_search)
source=req.text
soup=BeautifulSoup(source, 'html.parser')

url_list=soup.select("#content > div.view > div.layout > div.series")
check=0
for i in url_list:
    # 프리미엄 카테고리 검색
    if(i.find("h3").text.find("프리미엄")>=0):
        joara_list=i.find("div")
        joara_list=joara_list.find("a")
        joara_list=joara_list.get("href")
        joara_workID=joara_list.split('=')[1]

        # url 링크 추출
        joara_url="http://www.joara.com/premium_new/book_intro.html?book_code="+joara_workID
        get_info(joara_url, joara_workID)
        check=1
        break;

if check==0:
    print("검색 결과가 없습니다.")
else:
    print("\n-------------------------\n\n검색 결과 출력 완료")
# Out:
# 작품 검색 : 투수
#
# -------------------------
#
# http://www.joara.com/premium_new/book_intro.html?book_code=1427653
# 조아라 ID no. 1427653
#
# -------------------------
#
# 제목: 천재 투수 민덕수
# 장르: 판타지
# 저자: [창세후]
# 표지 url: http://cf.joara.com/literature_file/20200214_095229.jpg_thumb.png
# 총 연재화수:  175
# 최근 업데이트일: 2020.03.05.
# 출간일: 20/03/05
# 완결 여부: 완결
# 조회수:  3829
# 추천수:  18
# 관심도:  18
# 소개:
# 거구의 산골 소년이 야구공을 던지자,
# 모든 야구계 인사들이 눈을 크게 뜨며 외쳤다.
# "아니, 저런 괴물을 어디서 데려온 거야?"
#
# 산골마을에서 동네 야구를 하던 한 소년.
# 기억력이 좋아 라디오 중계로 야구 용어를 배우고,
# 혼자서 나무에 돌맹이를 던지며 시간을 때웠다.
#
# 야구부도 없는 고교에서 특별한 인연을 만나고,
# 열악한 환경, 부모의 반대, 동료의 텃세.
# 모든 것을 이겨내고 마침내 세계 무대로 이어지는
# 천재투수 민덕수의 우직한 야구 일념일로(一念一路)!
#
# 강속구, 뛰어난 머리, 강심장, 포커페이스.
# 모든 것을 갖춘 흔들리지 않는 괴물이 세계를 놀라게 한다!
#
# -------------------------
#
# 검색 결과 출력 완료

# %% [markdown]
# # 리디북스 작품 리스트 추출

# %%
import requests
from bs4 import BeautifulSoup

# [카테고리 : 로맨스 연재]
romance_page = 0
romance_count = 0
while True:
    romance_page += 1
    url = 'https://ridibooks.com/category/books/1650?page=' + str(romance_page)
    print(url)
    
    req=requests.get(url)
    source=req.text
    soup=BeautifulSoup(source, 'html.parser')
    
    # 제목 위치
    title_list=soup.select("#page_category > div.book_macro_wrapper.js_book_macro_wrapper > div > div.book_metadata_wrapper > h3 > a > span")

    # 한 페이지 당 작품 최대 20개
    for num in range(20):
        try:
            title=title_list[num].text.replace("\n","")
            title = title.split() # 제목 추출
            del title[0] # [연재] 제거
            title = " ".join(title)
            print(title)
            romance_count += 1
        except:
            break
    
    print("\n-----------------------------------------------\n")
    
    # 마지막 페이지 확인
    page_list=soup.select("#page_category > div.module_paging > ul > li.btn_next")
    if not page_list:
        break
        
# [카테고리 : 판타지 연재]
fantasy_page = 0
fantasy_count = 0
while True:
    fantasy_page += 1
    url = 'https://ridibooks.com/category/books/1750?page=' + str(fantasy_page)
    print(url)
    
    req=requests.get(url)
    source=req.text
    soup=BeautifulSoup(source, 'html.parser')
    
    # 제목 위치
    title_list=soup.select("#page_category > div.book_macro_wrapper.js_book_macro_wrapper > div > div.book_metadata_wrapper > h3 > a > span")

    # 한 페이지 당 작품 최대 20개
    for num in range(20):
        try:
            title=title_list[num].text.replace("\n","")
            title = title.split() # 제목 추출
            del title[0] # [연재] 제거
            title = " ".join(title)
            print(title)
            fantasy_count += 1
        except:
            break
    
    print("\n-----------------------------------------------\n")
    
    # 마지막 페이지 확인
    page_list=soup.select("#page_category > div.module_paging > ul > li.btn_next")
    if not page_list:
        break
        
# [카테고리 : BL 연재]
BL_page = 0
BL_count = 0
while True:
    BL_page += 1
    url = 'https://ridibooks.com/category/books/4051?page=' + str(BL_page)
    print(url)
    
    req=requests.get(url)
    source=req.text
    soup=BeautifulSoup(source, 'html.parser')
    
    # 제목 위치
    title_list=soup.select("#page_category > div.book_macro_wrapper.js_book_macro_wrapper > div > div.book_metadata_wrapper > h3 > a > span")

    # 한 페이지 당 작품 최대 20개
    for num in range(20):
        try:
            title=title_list[num].text.replace("\n","")
            title = title.split() # 제목 추출
            del title[0] # [연재] 제거
            title = " ".join(title)
            print(title)
            BL_count += 1
        except:
            break
    
    print("\n-----------------------------------------------\n")
    
    # 마지막 페이지 확인
    page_list=soup.select("#page_category > div.module_paging > ul > li.btn_next")
    if not page_list:
        break
  
        
print("로맨스 장르 총 " + str(romance_count) + "편")
print("로맨스 장르 페이지 : " + str(romance_page))
print("판타지 장르 총 " + str(fantasy_count) + "편")
print("판타지 장르 페이지 : " + str(fantasy_page))
print("BL 장르 총 " + str(BL_count) + "편")
print("BL 장르 페이지 : " + str(BL_page))
# Out:
# https://ridibooks.com/category/books/1650?page=1
# 포식자의 혼약자
# 계모인데, 죽음을 피하는 게 너무 쉽다
# 테라리움 어드벤처
# 디어 에데르트
# 낯선여름
# 가짜 여동생을 원하면
# 너밖에 모르는
# 먼치킨들의 총애를 받고 있습니다
# 파반느
# 나를 사랑하지 않는 그대에게
# 악마를 교화하는 방법
# 라이트 앤 다크
# 로잔의 가시덤불
# 상사와 몰래 하는 짓
# 그림자 없는 밤
# 내 죽음으로 흑화하지 마세요
# 내게 복종하세요
# 악녀에게 의리가 어디 있어
# 내 악역 남편을 위하여
# 흑막 용을 키우게 되었다
#
# -----------------------------------------------
#
# https://ridibooks.com/category/books/1650?page=2
# 배덕 황후
# 폐하의 밤
# 미친개가 몽둥이를 물어버리면
# 더티스캔들
# 파보르 (favor)
# 엘리트 공주님의 수석지침서
# 몽중연
# 악마가 나를 부르면
# 약탈혼
# 가짜 성녀는 퇴장을 기다린다
# 비비안의 사정
# 불온한 결속
# 핸디캡 이론
# 이제야 나를 그리워한다
# 폐하가 너무 귀찮게 해
# 이 결혼은 어차피 망하게 되어 있다
# 폭군과 여우
# 인 더 케이지(In the CAGE)
# 짐승 계약
# 상수리나무 아래
#
# -----------------------------------------------
#
# https://ridibooks.com/category/books/1650?page=3
# 아니라도
# 야수의 성
# S급의 히든 퀘스트
# 홈, 비터 홈
# 낙원
# 해피엔딩은 없다
# 조연은 너나 하세요
# 악역 대공비의 위험한 이중생활
# 직장내 불순교제
# 싫으니까 더
# 롤 더 본즈(Roll the Bones)
# 둘이 하는 나쁜 짓
# 불행의 기원
# 어느 날 공주가 되어버렸다
# 도원향
# 뱀의 혀
# 스르륵
# 까마귀는 반짝이는 것을 좋아해
# 페어 트레이드(fair trade)
# 아폴론의 심장
#
# -----------------------------------------------
#
# https://ridibooks.com/category/books/1650?page=4
# 매리지 앤 압생트(Marriage and Absente)
# 메이드 (house maid)
# 달뜨는 밤
# 사랑하는 나의 대공전하
# 사랑이 아니기를
# 아폴리티카
# 스폰서 따위
# 순수하지 않은 감각
# 시한부 악녀가 복수하는 방법
# 가짜 남편
# 검은 발 아래 은빛 눈
# 마지막 여행이 끝나면
# 셰리 공녀 이야기
# 나의 자리
# 브렐린 : 작가는 시한부 악역의 삶을 산다
# 들키면 죽습니다!
# 사랑받기 원하지 않는다
# 붉은 미궁
# 원수와의 계약 결혼
# 일레나 에보이 관찰 일지
#
# -----------------------------------------------
#
# https://ridibooks.com/category/books/1650?page=5
# 기사와 헌터의 겸직
# 광안(외전)
# 못된 짐승을 길들이는 법
# 속 좁은 황후
# 극락신선
# 투명한 비밀
# 왕자님, 악당 길만 걸어요!
# 탐낼 수 없는
# 삼킨 것은
# 심야 비서
# 쪽방에 괴물 아저씨
# 대단한 아가씨
# 광휘(狂徽)
# 괴물의 아내
# 마법사를 꿀꺽한 아가씨
# 운상연담: 화불능귀일락
# 새를 잊은 마녀에게
# 리셋팅 레이디
# 황제의 약혼녀로 산다는 것은
# 아래 팬아트북
#
# -----------------------------------------------
#
# https://ridibooks.com/category/books/1650?page=6
# 우리 같이 살아요
# 배드 아일랜드
# 마른 장마
# 애프터 선셋(AFTER SUNSET)
# 금수의 붉은 달
# 결혼식장에서 남편을 바꿨다
# 남주를 키웠다가 잡아먹혀 버렸다
# 우아한 야만의 바다
# 사내에서는 정숙할 것
# 선셋글로우
# 악역의 사촌으로 살아남기
# 나쁜 남편의 구애
# 베일을 벗겨주세요
# 나의 그대는 악마
# 보호자의 역할
# 마왕의 막내딸
# 슬라임이라도 꿈꿀 순 있어!
# 베스티아
# 그에게 안기다
# 붉은 낙인
#
# -----------------------------------------------
#
# https://ridibooks.com/category/books/1650?page=7
# 오로지하다
# 밤도 아닌데 밤까지
# 마찰열
# 육식주의
# 치료가 이런 건가요
# 빙신과 아가씨
# 벨 브론즈
# 나를 탐하는 수인들
# 도망치세요, 아가씨
# 내 밑에서 울어봐, 주인님
# 로맨틱 섹슈얼
# 버려진 공작부인의 밤
# 길들여진 상속녀
# 계약 좀 합시다
# 피폐물이라 감사합니다
# 야수라는 공작에게 시집왔는데
# 늪 속의 불
# 그 책을 끝까지 읽었어야 했다
# 벗어나기 애매한
# 마법소녀가 되는 방법
#
# -----------------------------------------------
#
# https://ridibooks.com/category/books/1650?page=8
# 스테이, 마이 디어(Stay, My Dear)
# 마귀
# 빨간 망토
# 담당자의 재량
# 런어웨이 달링
# 우리가 마주한 순간
# 베아트리체
# 베스트 맨
# 폭군의 번역기가 되어버렸다
# 싸이코 레이디
# 열어요
# 누구세요. 노예님?
# 꿈속의 기분
# 악역의 유능한 부하 직원이 되었습니다
# 진홍의 왕, 칠흑의 세계
# 은밀한 바다, 깊이
# 안녕, 내 똥강아지
# 실연당했는데 이계로 넘어왔습니다
# 캐스니어 비망록
# 그 영애의 생존 일지
#
# -----------------------------------------------
#
# https://ridibooks.com/category/books/1650?page=9
# 나의 아름다운 밤의 꽃
# 벙어리 왕좌
# 원수와의 이혼까지 D-365
# 오늘부터 부부
# 지옥열정
# 공작의 아내가 되려는 이유
# 공녀님 우리 공녀님
# 사랑의 마법약을 해독하는 방법
# 나무를 담벼락에 끌고 들어가지 말라 3부
# 완전한 행복
# 교활하지 못한 마녀에게
# 미쳐서, 미(美)치게 사랑한다
# 두 번의 사랑
# 팁시 레이디
# 연애공백기
# 반대가 끌리는 이유
# 천적 (외전)
# 어린황후
# 마담 아스트라
# 흑과 백의 퀸
#
# -----------------------------------------------
#
# https://ridibooks.com/category/books/1650?page=10
# 사蛇의 찬미
# 완전한 감금
# 이엘라
# 이야기는 아직 끝나지 않았다
# 도망친 성녀와 영원의 밤
# 역하렘 소설에 빙의했다
# 하녀의 품격
# 미안한데, 기억에 없어서
# 구원의 밤
# 훼손
# 여섯 번째 별
# 도주하는 대공비
# 미친 남자
# 테베의 절세미인
# 나인 테일 폭스
# 재생, 영원의 맹세
# 입술 끝이 닿으면
# 격렬히 탐해주세요
# 금단의 꽃
# 이 중매는 뭔가 잘못되었다
#
# -----------------------------------------------
#
# https://ridibooks.com/category/books/1650?page=11
# 흑요의 정원
# 나의 신에게
# 당신 하나만을 위한 꽃들이 피다
# 사육제
# 기록적 선우
# 발칙한 제안
# 왜 먹지를 못하니
# 결혼을 앓다
# 귀부인과 두 남자
# 죽도록 너를
# 고, 백(Go, Back)
# 호희비사
# 아리엘, 그 음탕한 성녀
# 공작부부 재결합기
# 돌아올 수 없는
# 야수의 밤
# 태연한 거짓말
# 도피오 센소
# 마녀와 그레텔
# 개와 덫의 시간
#
# -----------------------------------------------
#
# https://ridibooks.com/category/books/1650?page=12
# 유혹의 늪
# 아가씨
# 플리즈
# 옆집에는 호랑이가 산다
# 구원자의 요리법
# 붉은 짐승
# 그놈 양반
# 沙風(사풍)
# 여의주를 훔치는 방법
# 헤이망드의 핏줄
# 가짜 성녀 (무삭제판)
# 상무님, 방 잡을까요?
# 악역이 아니라 선역 가문이랬는데
# 코럴(Coral)
# 페레이라
# 총독의 신부
# 터치 미 리드 미
# 신들의 성좌
# 버려진 성녀와 마족 노예
# 금단을 맛보다. 사랑에 취하다.
#
# -----------------------------------------------
#
# https://ridibooks.com/category/books/1650?page=13
# 악역을 구하고 떠나려 합니다
# 만월의 아스모데우스
# 위험한
# 이상 기후
# 그 책은 18세 미만 구독 불가였습니다
# 폭군론
# 호랑이를 잡아먹은 토끼
# 현자를 위한 네 심장
# 붉은 낙인 (紅印)
# 이스닐다
# 미친놈 고쳐 쓰는 법
# 티타임엔 금수저
# 너를 먹고 싶어
# 황제의 두 얼굴(삽화본)
# 꽃의 짐승
# [GL] 우리가 사는 세계는
# 조선에 핀 백합
# 너를 채워줄게
# 뱀의 방식
# 애동과의 로맨스
#
# -----------------------------------------------
#
# https://ridibooks.com/category/books/1650?page=14
# 은밀한 유희
# 나랑 한번만 해요, 그거
# 마이 시크릿 대디
# 보호해줘, 오빠
# 너와 나의 숨결 사이
# 나쁜 짓
# 늪으로(Deep into the Swamp)
# 황금숲
# 금수들의 여왕
# 귀혼
# 첫사랑에게
# 온 에어 24
# 홍염, 화(花)
# 더티 로즈
# 이나의 밤
# 야성의 숨결
# 잠식
# 치닫도록
# 황제의 독사과
# 술탄의 덫
#
# -----------------------------------------------
#
# https://ridibooks.com/category/books/1650?page=15
# 아니, 돼요
# 갈래길
# 농촌 프린세스
# 스타의 여자
# 속박은 짙게
# 세크레타
# 마이 러블리 피핑 톰
# 잠 못 드는 밤에
# 약속 지키세요, 성녀님
# 어스퀘이크 (Earthquake)
# 공작님, 파혼해 주세요!
# 나의 특별한 호위무사
# 추상의 정원
# 마법소녀 알고리즘
# 레이디 오드리의 인생
# 용은 독에 물들고
# 꽃의 여왕
# 불건전한 사내연애
# 엉뚱한 유혹
# 별나게 묘하게
#
# -----------------------------------------------
#
# https://ridibooks.com/category/books/1650?page=16
# 또다시 너를
# 그와 그녀의 비밀
# 빌어먹을 '서른' 따위
# 파리 인 러브
# 히든 게임 시즌5 크리티컬 히트
# 만져도 좋아
# 첫사랑주의보
# S와 S의 관계
# 존잘님을 납치했다
# 오늘도 아빠를 꼬셔보려 합니다만?
# 덫에 걸린, 꿈 토끼
# 우리 무슨 사이예요?
# 폭발적인 사랑
# 사락
# 일족의 신부
# 에이미의 우울
# 윈터 브라이드
# 금요일의 시간 여행자
# 라르고
# 상드리용의 덫
#
# -----------------------------------------------
#
# https://ridibooks.com/category/books/1650?page=17
# 사야나의 왕녀
# 은밀한 연애
# 개정판 | 더 원
# 여우야 여우야 뭐 하니
# 랩소디 인 파리
# 라 노떼 (la notte)
# 봄바람
# 그녀는 내 경호원
# 저주받은 아이
# 은하, 시간을 열다 : 비아스텔라
# 꺼진 불도 다시 보자
# 살루암의 해
# 혼수는 검 한 자루
# 데아 루베르
# 비터 로즈
# 유월의 봄
# 찬란하게 가두다
# 하얀 밤을 건너다
# 우아하게 용을 낳는 방법
# 재와 꽃
#
# -----------------------------------------------
#
# https://ridibooks.com/category/books/1650?page=18
# 노예는 물든다
# 목줄의 주인은 바뀌었다
# 애프터 레인(AFTER RAIN)
# 내가 잠든 사이
# 경성탐정사무소
# 아스텔
# 용기있는 자가 미남을 얻는다
# 연애할까요?
# 착각하지 마
# 그리지 않는 이야기
# 원작은 내 이야기가 아니었다
# 칸의 여자
# 예쁘고 못된 내 여자친구
# 여명은 잿불에서 일어난다
# 꽃잎 떨어지는 마티에
# 굿 와이프
# 썸머 로드
# 화홍 1, 2부
# 숨 고르기
# 겨울별의 플라네타륨
#
# -----------------------------------------------
#
# https://ridibooks.com/category/books/1650?page=19
# 겨울, 깊은 밤
# 사랑하는 공작님께
# 세이 썸띵 (Say something)
# 케이지
# 손길
# 늑대왕, 루프스
# 강남 황녀
# 애딕트(addict)
# 아는 사이
# 르 블랑(Le Blanc)
# 율도 (律道)
# 니어 앤 디어
# 말하지 않아도 괜찮아
# 악녀는 악녀를 알아본다
# 길티 플레져
# 내게로 오세요
# 거절할 수 없는 제안
# 디어 디어 (Dear deer)
# 붉게 탐하다
# 평화와 함께
#
# -----------------------------------------------
#
# https://ridibooks.com/category/books/1650?page=20
# 오리의 정원
# 연하가 짖다
# 마타리
# 황제 해시트
# 공작부인의 비밀
# 리바이어던
# 퀸
# 로미오의 남자
# 죄의 흔적 + 모래 바다를 거닐다
# 거울에 비친 왕관
# 프리마 돈나의 로맨스 비자
# 미인도(美人圖) : 신수의 여인
# 검은 오팔
# 경성야사
# 조선상인별곡: 그 처음의 시작
# 고려람여상열지사(高麗覽旅相悅之詞)
# 에스퍼 항쟁
# 결혼 계절
# 룩센의 연인
# 다시 만날 테니까
#
# -----------------------------------------------
#
# https://ridibooks.com/category/books/1650?page=21
# 잠자는 꿈속의 배우님
# 박히다
# 돈을 주웁시다
# 소녀는 순수하지 않다
# 그러므로, 사랑
# 나의 정복자
# 금은의 왕관
# 비꽃
# 맞춤형 와이프
# 거짓말쟁이 연인
# 악마의 숨결 아래에서
# 말하지 아니하고
# 흡혈귀는 장미이슬을 탐한다
# 가짜 성녀
# 홀리 마드모아젤
# 독보천하
# 뱀파이어 교수
# 마이 비포 선라이즈 (My 「Before Sunrise」)
# 페이드인
# 마왕의 반려
#
# -----------------------------------------------
#
# https://ridibooks.com/category/books/1650?page=22
# 민씨 낭자전
# 페로몬 영역
# 못 말리는 공작부인
# 악에 피는 꽃
# 원스 (ONCE)
# 세실리아의 발밑에는 검은 머리칼이 묻혀 있다
# 번데기 속 고양이
# 상냥한 무희의 우울
# 캐롯
# 원수를 사랑하게 된 이유에 대하여
# 호구의 봄
# 좋아하는 드라마
# 젠틀맨의 순정
# 사랑을 쟁취하라
# 은의 황제 적의 왕
# 늑대들의 사정
# 아이 아빠는 처음이에요
# 공작 부인 웬디
# 시에르타의 대공 포획 작전
# 미치도록 달콤한
#
# -----------------------------------------------
#
# https://ridibooks.com/category/books/1650?page=23
# 그대를 마시는 시간
# 동거의 해법
# 그림자 정원의 마리오네트
# 리버스
# 후작가에 가정 교사가 필요한 이유
# 측천황제
# 허그 미 타이트(Hug Me Tight)
# 그림자 얼굴
# 우련 붉어라
# 사랑니
# 연
# 고교 시절, 첫 키스
# 묘(妙)하다
# 서울 아랑전
# 첫사랑 코디네이터
# 비밀의 황후
# 다시 사랑한다 말할까?
# 이리나
# 러브리폼
# 공유 하실래요?
#
# -----------------------------------------------
#
# https://ridibooks.com/category/books/1650?page=24
# 사랑을 꿈꾸라(‘순간을 영원히’ 시리즈 2)
# 프로파일러Ⅱ : 에페타(éfeta)
# 실례지만, 폭탄입니다
# 최애캐와의 동거
# 치명적 소유
# 베아트리스를 위한 헌사
# 숨은 봄
# 정염의 관계
# 탐라여국
# 대마법사를 훔쳐라
# 이런 사랑, 다시 할 수 있을까
# 밤의 마중
# 장송행진곡 (Funeral March)
# 을의 연애
# 시골 소녀라도 회귀할 수 있어!
# 그림자
# 그러나, 그래도, 그래서 너를
# 엘레노아
# 영혼의 노래
# 악마 같은 사장님
#
# -----------------------------------------------
#
# https://ridibooks.com/category/books/1650?page=25
# 마녀의 장례식
# 그 황제의 은밀한 욕구
# 운명적 황후
# 조선 노비 공주
# 너무 사랑하지 않기를
# 아빠 둘, 엄마 셋
# 수상한 그들이 사는 법
# 계약 비서
# 적장과의 결혼
# 불쾌한 씨의 유쾌한 가을
# 여왕의 가호를
# 새벽을 기다리며
# 나는 너를 사랑하지 않을 거야
# 14년 후
# 남자가 여자를 사랑할 때
# 야수의 은밀한 저택
# 꽃시리즈 - 떨어지는 꽃, 흐르는 물 & 꽃무릇
# 춘향환상곡
# 책사 주도리
# 옷을 벗기는 여자
#
# -----------------------------------------------
#
# https://ridibooks.com/category/books/1650?page=26
# 썸머타임
# 여우손님
# 봉서나인
# 리스타트(Restart)
# 화장하는 남자
# 하늘에 영광
# 요화 요괴의 꽃
# 주도면밀한 주은행
# 절대그녀
# 저널리스트
# 유일한 적수
# 원수를 사랑하라
# 열혈남편 독한아내 섹시청년
# 앤서미
# 줄리아, 어디에 있니?
# 짝사랑, 있다 없으니까
# 러브 포비아
# 굶주린 늑대의 사랑법
# 러브모드
# 로스트(Lost)
#
# -----------------------------------------------
#
# https://ridibooks.com/category/books/1650?page=27
# 코드 블루(개정증보판)
# 옐로(Yellow)
# 다섯 번째 계절
# 조선반당록
# 베키엄가 막내딸
# 아가씨의 비밀
# 나의 신사님
# 북풍의 마실리아
# 궁인일기
# 장미의 이름
# 소주찬가
# 거짓말
# 장르가 잘못했네
# 눈보다 아름다운
# 기생열전
# 수상한 동물원
# 기적이란 이름으로
# 제신의 하루
# 검은 눈의 공작부인
# 맛있는 여자
#
# -----------------------------------------------
#
# https://ridibooks.com/category/books/1650?page=28
# 현월
# 미운새끼오리
# 뜨겁게 타오르다
# 연애술사
# 썸씽 스페셜
# 꽃집의 아가씨는 예뻐요
# 비도화지향 (悲桃花之香)
# 퀸을 위하여 - 1부 Story From J. Queen
# 마음 결핍 증후군
# 사랑의 환상곡
# 천사의 모래시계
# 쉬즈 베스트 (shes best)
# 홀인원
# 한 남자 그리고 한 여자
# 풀 스토리
# 폴 인 러브
# 퀼터 앤 닥터
# 쿨 가이
# 첫 번째 만남, 세번의 키스
# 우린, 사랑일까
#
# -----------------------------------------------
#
# https://ridibooks.com/category/books/1650?page=29
# 완월
# 오아시스 내 청춘
# 연애, 하고 있습니까
# 아랫집 강짱과 윗집 늑대들
# 살짝궁 손 잡아드립니다
# 보통연애 환자와 연애할 수 있을까요
# 보살님은 연애중
# 바람 이를때면
# 바나나형수님
# 밀키러브
# 몽환 한자락
# 말썽쟁이 약혼녀
# 떴다 그녀
# 달빛연인
# 늑대, 그녀에게 길들여지다
# 나의 아름다운 야수
# 그저, 사랑
# 그녀에게 올인하다
# 그 남자, 날씬해진 그 여자의 사정
# NEO, 박씨부인전
#
# -----------------------------------------------
#
# https://ridibooks.com/category/books/1650?page=30
# 붉은 핏빛의 유혹
# 독과 나비
# 이계궁녀
# 목어화
# 지중해의 검은 표범
# 타르탄기담
# 레벨 업 위드 유(Level up with you)
# 마이 러블리 캡틴
# 지금 죽으러 가는 길입니다
# 그날의 약속
# 사랑할 수 밖에 없는
# 궁중 스캔들
# 구속(외전합본)
# 프라블럼(Problem)
# 사랑에 길을 잃다
# 애정소환
# 강박증
# 남자가 되어 돌아온, 그 녀석
# 센트럴빌리지의 열대야
# 그녀의 로맨스는 달달하다
#
# -----------------------------------------------
#
# https://ridibooks.com/category/books/1650?page=31
# 개정판 | 썸씽 (Something)
# 신경 좀 꺼주실래요?
# 정심심 Mental Clinic
# 이중인격 바로잡기
# 사랑, 불변의 법칙
# 누님vs형님
# 꽃같은 증인보호
# 신데렐라와 바보온달
# 음침한 베라와 이상한 우주
# 꽃이 피어날 때
# 이자벨라 융커
# 본색
# 매혹 당한 그녀
# 황제 폐하 교육은 어떻게 하나요?
# 캔유 렛미인 ( Can you let me in )
# 아침이 오지 않아도
# 웨어울프
# 야수개
# 너를 갖는 건, 음악이 흐른 뒤에
# 오직 특별한 너
#
# -----------------------------------------------
#
# https://ridibooks.com/category/books/1650?page=32
# 규방로맨스 - 소저의 정인
# 개정판 | 발코니의 그 녀석
# 나는 너를 원해(Je Te Veux)
# 이끌림
# 쓰담쓰담
# 오후에 키스해
# 내 집에 유령각시
# 저스트 더 투 오브 어스
# 여기는 약방이지, 찻집이 아닌데요
# 용용 죽겠지
# 비형낭 연가
# 우연에서 운명까지
# 홍대 앞 로맨스
# 방관자가 되는 법
# 힘센 로맨스
# 우리집에 왕자님이 산다
# 섹시한 광남 씨의 애정 행각
# 꿈꾸는 펜던트
# 나는 큐피드와 함께 산다
# 꽃모닝! 여우별
#
# -----------------------------------------------
#
# https://ridibooks.com/category/books/1650?page=33
# 나쁜남자
# 기억에 살아
# 운신
# 당신이 사는 세계
# 미명의 추적자
# 오늘은 더워요
# 아이돌처럼 노래하고 싶어!
#
# -----------------------------------------------
#
# https://ridibooks.com/category/books/1750?page=1
# 내 안에 마교있다
# 내 머릿속에 2000년 마법 역사
# 이세계 천재 화가
# 회귀의 전설
# 내가 키운 S급들
# 전지적 독자 시점
# 재능이 자꾸 늘어
# 아포칼립스의 고인물
# 로그인하자마자 VIP
# 패왕이 되는 방법
# 웹소설만 읽으면 강해져
# 수의사 진태민
# 이번엔 진짜 재벌!
# 백작가의 망나니가 되었다
# 나 혼자만 레벨업
# 헨드릭의 시스템
# 환생표사
# 명문고 EX급 조연의 리플레이
# 망나니 1왕자가 되었다
# 달콤, 찬란한 재벌기
#
# -----------------------------------------------
#
# https://ridibooks.com/category/books/1750?page=2
# 리퍼-무공수확자
# VVVIP 차원 쇼퍼
# 용사를 방치했더니 차원 최강
# 회귀해서 다해먹음
# 상단주의 망나니 아들이 되었습니다
# 일신상의 이유로 잠시 휴재합니다
# 레벨제한이 없는 유일한 헌터
# 나만 1회차
# 내가 만든 AI가 성좌가 되었다
# 번개를 맞았다
# 히든 퀘스트로 탑셰프
# AOS 소설 아닌데요?
# 막내 공자가 제일 강해
# 10서클 직전에 환생
# 무신귀환록
# 아기부터 시작하는 연예계 생활
# 최강재능으로 회귀하다
# 나도 정상은 아니더라
# 무림에서 레벨업
# 질풍패도
#
# -----------------------------------------------
#
# https://ridibooks.com/category/books/1750?page=3
# 군주로 돌아왔다
# 이계에서 독점방송
# 허세작렬 배우님
# 공작님, 회개해주세요!
# 뉴비가 너무 강함
# 재력으로 후려치는 환생 경찰
# 구천마신
# 공작가의 수치, 회귀하다
# 만렙커피:던전입구점
# SSS급 자살헌터
# 근육조선
# 얼굴값하는 톱스타
# 대표님의 향기로운 덕질생활
# 막장 재벌 3세가 되었다
# 무인환생
# 신창, 망국의 귀족이 되다
# 히트미
# 신화를 만드는 축구 감독
# 이것이 명의다
# 천마 객잔
#
# -----------------------------------------------
#
# https://ridibooks.com/category/books/1750?page=4
# 심장이 두 개인 남자
# 플레이 메이커
# 1993 회귀재벌
# 적국의 왕자로 사는 법
# 개정판 | 아키에이지 연대기
# 성스러운 아이돌
# 천재배우의 아우라Aura
# 다시 쓰는 필모그래피
# 부검 스페셜리스트
# C급 용병, 시스템으로 정점까지
# 악당의 리턴!
# 회귀검사가 다 때려잡음
# 나만 보는 찌라시
# 기사의 일기(Diary of a Knight)
# 전설, 망나니를 꿈꾸다
# 경애하는 수령동지
# 시체만 있으면 강해져!
# 하룬
# 넣어 키운 걸그룹
# 시스템 탑스타
#
# -----------------------------------------------
#
# https://ridibooks.com/category/books/1750?page=5
# 권왕환생
# 이계로 가다 정신만?
# 네크로맨서는 세계최강
# 다른 세계에서 주워왔습니다
# 회귀자 사용설명서
# 철혈의 오버로드
# 정령 농사꾼
# 미친 황제가 되어버렸다
# 사상 최강의 보안관
# 주인공이 힘을 숨김
# 탑 매니지먼트
# 약빨이 신선함
# 카드빨로 축구 스타
# 역대급 먼치킨 힐러의 탄생
# 아들이 되었다
# 탤런트 스토어
# 협상의 대가
# 너의 스탯이 보여
# 신세계: 시스템 아포칼립스
# 국적없는 용병
#
# -----------------------------------------------
#
# https://ridibooks.com/category/books/1750?page=6
# 알고 보니 창술최강
# 최고난이도로 강해져
# 그리고 용사는 행복하게 살았습니다?
# 슬기로운 매니저 생활
# 작곡천재 노래방송
# 매일매일 이벤트로 레벨업
# 지옥발 히트 메이커
# 신탁의 대군주
# 유령으로 세계최강
# 재벌가 서자의 신화
# 내가 미륵이니라
# 실명무사
# 회귀하니 스탯이 두 배
# 귀신 들린 제작자
# 템신 강림하신다
# 대마법사 회장님
# 재벌가의 막내사위
# 망나니, 재벌 아들로 환생했다!
# 달빛조각사
# 사상 최강의 드루이드
#
# -----------------------------------------------
#
# https://ridibooks.com/category/books/1750?page=7
# 레전드 플레이어의 귀환
# 시작부터 EX등급
# 현실에서도 플레이어
# 임기 첫날에 게이트가 열렸다
# 현질해서 톱스타!
# 힘 스탯 999 4번타자
# 천마님 효도하신다!
# 색공학자
# 없어? 내가 만들지 뭐
# 공작이 회귀함
# 대군으로 살어리랏다
# 그 드라마의 15화
# 종말 이후의 포인트 사용법
# 유토피아
# 말단 병사에서 군주까지
# 신화 속 영웅의 귀환
# 개정판 | 인스턴트 킬
# 소드마스터의 환생
# 전국(戰國)
# 망나니 회귀하다
#
# -----------------------------------------------
#
# https://ridibooks.com/category/books/1750?page=8
# 디아블로 씨는 조용히 살고 싶어
# 좌천당한 하급 장교가 살아남는 법
# 환생으로 독존한다
# 작곡의 신이 되었다
# 백작가 막내-카론의 귀환
# 던전 디펜스
# 홈런치는 괴물투수
# 서역에서 돌아오다
# 일륜도천파
# 신화의 전장
# 리더(Reader) : 읽는 자
# 아빠가 너무 강함
# 돌아온 용병왕
# 극한의 재능충
# 탑 기타리스트
# 내 등급 측정불가
# 축복의 천신계
# 게임 속 전사가 되었다
# 보스 몹답게 행동하세요, 스왈로우씨!
# 작은 아버지는 동탁 [삼국지 동황전]
#
# -----------------------------------------------
#
# https://ridibooks.com/category/books/1750?page=9
# 스마트한 영주님
# 최강 귀환자의 행복 라이프
# 막나가는 백작가 망나니
# 마지막 황제, 칼끝에 서다
# 그 남자가 살아가는 방법
# 룡이 보우하사
# 게임의 신, 돌아오다
# 게임 관리자 모드
# 스킬로 탑배우
# 멸망한 세계의 생존 지침서
# 조선제왕전기: 세종의 손자
# 마두객잔
#
# 수호문주 강 순경
# 운명을 보는 회사원
# 위키 쓰는 용사
# 1억 관객 제작자
# 내 스킬 효과 999배
# 보이스피싱인데 인생역전
# 유물의 목소리가 들려
#
# -----------------------------------------------
#
# https://ridibooks.com/category/books/1750?page=10
# 소시민, 재벌 되다.
# 망겜의 성기사
# 스트라이크를 던져라
# 영화속 능력흡수
# Genome(게놈)
# 컨빨
# 성군이십니다
# 천룡유희
# 재벌서자이지만 천재라서
# 레벨업 하는 일인군단
# 회귀했더니 능력 무한
# 죽음을 먹는 멸망급 헌터
# 축구레전드 다 밟고 쿼드러플
# 요리의 신께서 보우하사
# 하렘 어드벤쳐
# 백작가 서자의 가정교사
# 스킬조합으로 꿀빠는 공무헌터
# 전직지존
# 환생무림 비행(飛行)
# 회귀하니 천재 재벌
#
# -----------------------------------------------
#
# https://ridibooks.com/category/books/1750?page=11
# 리치, 헌터가 되다!
# 기사가문 망나니는 10클래스
# 혈마, 21세기를 지배하다
# 나는 회귀했다
# 타임 1937
# 숨겨진 옵션이 보여!
# 역대급 미드필더의 탄생
# 템빨
# 조선의 명왕, 강림하다
# 한량 정인환 - 혁명의 시대
# 역대급 재벌 사위
# 하고 싶은 여자 판독기
# 백천랑
# 대물로 태어나게 해주세요!
# 내 손안에 백만 대군
# 환생했더니 정령군주
# 뇌신雷神
# 귀환자의 영지 경영
# S급 재능, 한유림
# 필드의 고인물
#
# -----------------------------------------------
#
# https://ridibooks.com/category/books/1750?page=12
# 제국의 강철함대
# 신이 축복한 남자
# 이계 내가 가 봤는데 별거 없더라
# 좀비의 왕
# 절대자의 푸드트럭
# 밑바닥 플레이어에서 자동저장으로 정상되다!
# 천마를 삼켰다
# 개정판 | 정령왕 엘퀴네스
# 재벌이 돈을 숨김
# 절대 검감(絶對 劍感)
# BJ무림존물
# 폐품 무학관
# 알고보니 천재작가
# 마왕님, 배송이 시작되었습니다
# F급 광합성 헌터, 회귀하다
# 돈 벌고 싶어? 내가 벌게 해줄게
# 천마님 던전 가신다
# 지옥과 인간의 대결 (Man vs. Hell)
# 귀환 마교관
# 억만장자 배우님
#
# -----------------------------------------------
#
# https://ridibooks.com/category/books/1750?page=13
# 무신, 오빠로서 책임을 다하다
# 내 행운은 만렙이다
# 백제의 이름을 잇다
# 음악천재를 위하여
# 초인의 게임
# 오늘부터 플레이어
# 전생검신
# 킬 더 에일리언
# 시스템 강호지존
# 귀환한 역대급 창기사
# 회귀자의 소소한 꿀팁방송
# 작전명 : 귀향
# 평범한 회사원입니다
# 재벌 야망
# 홈 플레이트의 빌런
# 소설 속 엑스트라
# 독식전설
# 거기가 예쁜 남자
# 사상 최강의 길드마스터
# 뽑기로 SSS급 군단 육성
#
# -----------------------------------------------
#
# https://ridibooks.com/category/books/1750?page=14
# 미래를 보는 투자자
# 회귀자가 다 뺏어먹음
# 나 혼자 무한 보급!
# 영웅쟁패
# 무공을 배우다
# 조선 해양왕: 강대국의 조건
# 별들의 별
# 강자생존
# 제3차 세계 대전
# 몬스터를 길들이는 방법
# 지하경제, 돈의 맛
# 음악재능 다 내꺼
# 뇌전검왕 SSS급 헌터되다
# 루머 읽는 배우님
# 회귀한 공간 보유자
# 비혼라이프
# 의느님을 믿습니까
# 최강 변호사가 해결한다
# 납골당의 어린왕자
# 에스티오
#
# -----------------------------------------------
#
# https://ridibooks.com/category/books/1750?page=15
# 연예계에 등장한 몬스터 PD
# 게임천재가 회귀했다
# 기적을 전해드립니다
# 네 심장이 멈추는 시간
# 최고부자
# 핵재벌 개망나니
# 화산마왕
# 배낭여행으로 재벌 되기!
# Mr. 언터처블
# 최초의 헌터
# 70억분의 1의 이레귤러
# 탑클래스
# 1999년 게임 스타트
# 헌터 세상의 정원사
# 극한의 컨셉충
# 거대 인공지능 키우기
# 규격외 등급 해석사
# 신화급 각성으로 최상위종
# 최강 : 신이라 불리는 사나이
# 검신의 검은 우주를 가르고
#
# -----------------------------------------------
#
# https://ridibooks.com/category/books/1750?page=16
# 운명찬탈자 : 미래를 보는 헌터
# 이과생 둘이 회귀했다
# 무모한 도전의 게이머
# 재벌 작가
# 주식 재벌 박태준
# 사상 최강의 스트리머
# 아르카나 마법도서관
# 소환하는 헌터
# 너의 보컬 능력치가 보여
# 검선지가
# E급부터 시작하는 대마법사
# 신검 반어자
# 삼국지 위인전
# 폭딜탱커
# 월드스타 이주원
# 태존비록(怠尊秘錄)
# 귀환자의 저세상 예능방송
# Project_Mar-On
# 정령왕이 귀환했다
# 내가 키운 메이저리거
#
# -----------------------------------------------
#
# https://ridibooks.com/category/books/1750?page=17
# 역대급 톱스타의 회귀
# 핵인싸 이계 모험기
# 환생좌
# 좀비묵시록 82-08
# 천만번 환생한 공작가 망나니
# 최고의 축구선수로 만들어 드립니다
# 기적의 물리치료사
# 제왕검전
# 카드깡으로 발롱도르
# 기적의 IT재벌
# 헌터 때려치고 이제 내조 합니다.
# 귀족 사회
# 공작가의 집사
# 마운드의 짐승
# 사상 최강의 매니저
# 꿈 속 퀘스트 보상은 현실에서
# 내 생의 두 번째 축구
# Dr. 스펠
# 금뱃지
# 해골왕
#
# -----------------------------------------------
#
# https://ridibooks.com/category/books/1750?page=18
# 빅 라이프
# 치트키 플레이어
# 나는 골렘입니다
# 우리동네 탱커
# 겨울성의 열쇠
# 부여섭3부
# 용사들의 이중생활
# 사기당해 지구최강
# 스틸러 벤
# 5초 후의 게시판이 보여!
# 채널 마스터
# 무한전생-스페이스 니트
# 로또 맞은 사나이
# 퇴역용병 엔터테인먼트
# 된 세상에서 마법사는
# 주식의 신
# 회귀가 뭐 이래
# 조선 왕조 역대 반항아 이야기
# 만렙 신병 받아라!
# 둔재, 회귀하다
#
# -----------------------------------------------
#
# https://ridibooks.com/category/books/1750?page=19
# 소드마스터, 낙제생 되다
# 에볼루션!
# 시체사냥꾼
# 내 머리 속의 컴퓨터
# 맵핵으로 미궁 정복
# 정벌 군주
# 북경의 신룡
# 포텐 보는 축구천재
# 물량으로 승부한다
# 눈 떠 보니 현대 라이프
# 상점창 스트라이커
# 화룡
# 역대급 먼치킨 재벌
# 랭커의 귀환
# 만들면 레벨과 스텟이 올라
# 회귀자의 기연 싹쓸이
# 고려왕이 된 망나니
# 역대급 천재 재벌
# 무공서가 생겼다
# 회귀를 한다는 건
#
# -----------------------------------------------
#
# https://ridibooks.com/category/books/1750?page=20
# 각성하니 아내가 자꾸 늘어난다
# 황제가 돌아왔다
# 데우스 큐브(DEUS CUBE)
# 야구를 더 잘하게 됨
# 암묵의 지배자들(원제 : 불의 고리)
# 전국수석 무림가다
# 사파제일인의 막내 제자
# 화산마신
# 상태창 삼국지
# 재벌집 서자, 그레이트 어게인
# 알고보니 일대일 천재
# 환생 천하무적
# 시스템 에러로 종족초월
# 역대급 후원으로 세계최강
# 내 고양이는 S급
# 제작의 신: 내가 만들면 대박
# 삼국지 호접몽전
# 9전단 1941
# 죽지 않고 살아남기
# 섹스만 해도 레벨 업!
#
# -----------------------------------------------
#
# https://ridibooks.com/category/books/1750?page=21
# 내 눈에만 보이는 명장면
# 묵룡쟁패
# 내 포인트 무한
# 나혼자 진짜 재벌
# 육식주의 헌터
# 키워 먹는 트레이너
# 병약한 귀족이 되었다
# 내 코인 999,999,999,999,999
# 파트너 어플
# 로또 1등도 출근합니다
# 아저씨 왔다
# 흑마법 마스터
# 초 F급 이레귤러
# 거침없이 싸라 : 진정한 정복자
# 악당이 살아가는 법
# 낚시로 레벨업하는 플레이어
# F등급 헌터의 싸움
# 치트코치 정수찬
# 처음부터 절대무적
# 던전리셋
#
# -----------------------------------------------
#
# https://ridibooks.com/category/books/1750?page=22
# 망한 재벌 4세, 돌아오다
# 학사신공
# 천마는 조용히 살고싶다
# 100년 만에 돌아온 망캐
# 복수의 끝은 재벌
# 내 멋대로 스킬북
# 소작농의 아들이 더 행복함
# 인류의 배반자, 회귀하다
# 안 보이는 투명츄
# 리버스 빌런
# 최초로 업적을 획득한
# 기계신과 함께
# 증권가 큰손 백 할머니
# 튜토리얼만 1만년 했다
# 회귀하니 재벌집 탕아
# 빌런이 방송을 너무 잘함
# 도굴왕
# 무한빙의로 세계 최강
# 나 혼자 GTA(Great The Avenger)
# 무사 우백
#
# -----------------------------------------------
#
# https://ridibooks.com/category/books/1750?page=23
# 이도구검(異道求劍):잘써는놈
# 축구 천재의 재능 폭격!
# 마제의 신화
# 주인공이 자비를 숨김
# 회귀자의 스타트업
# 나 혼자 대리사냥!
# 정감록
# 권능의 마갑
# 나 혼자 두배!
# 거침없이
# 다크로드 블리츠 (연재)
# 독표무적 (연재)
# 각성자
# 로드는 로드 중
# 센 놈!
# 슬기로운 연예생활
# 재벌을 향해 Suit Up!
# 철종
# 먹지 못했던 여사친들
# 역대급 야구 천재의 탄생
#
# -----------------------------------------------
#
# https://ridibooks.com/category/books/1750?page=24
# BJ대마도사
# 무신탄생
# 마이스터 - Prophet
# 나 혼자 천재 DNA
# 무한 회귀의 용사
# 회귀로 압도한다
# 대물 스카우터
# 링커 : 유물의 주인을 찾아드립니다
# 천재 광대, 톱스타되다!
# 불장난
# 골프가 좋아
# 500년 만에 돌아온 천마
# 회귀한 톱스타의 힐링라이프
# 최강전설 아저씨
# 하루가 두 번
# 플레이어님 귀환하신다!
# 월드스타 슈베르트
# 학자인데 너무 강함
# 톱스타, 그 자체
# 나는 폭군이다
#
# -----------------------------------------------
#
# https://ridibooks.com/category/books/1750?page=25
# 투사의 탈을 쓴 모차르트
# 탈모형 미드필더
# 오크지만 찬양해
# 능력자의 포스
# 생명력 Max!
# 강남 퇴마사
# 폭풍의 한반도
# 똥볼 투수의 귀환
# 부검의 신 : 망자의 기억
# 만렙 영웅님께서 귀환하신다!
# 주인공이 모르는 게 없음
# SSS급 마트 점원
# 세계는 넓고 할 일은 많지만 서자였다
# 축구천재 귀화하다
# 중원이 지다
# 이 맛에 재벌한다.
# 무협지 엑스트라가 되다
# 재벌가 망나니입니다만?
# 현대 네크로맨서 길라잡이
# 21세기 갑부[甲富]
#
# -----------------------------------------------
#
# https://ridibooks.com/category/books/1750?page=26
# 용돈이 계속 늘어!
# 모든 것을 강화하는 헌터
# 게임 같은 무인도 생존기
# 천마재혼: 회귀로 모든 것을 얻다
# 배틀 킹덤 언플의 킹
# 대남궁세가
# 나 혼자 현실 패치
# 육군 대위, 귀환하다
# 무적자(無敵者)
# 나 혼자 역대급 수련
# 마운드의 미친 재능
# 기프티드 (GIFTED)
# 특급 강화 중독자!
# 전능의 헌터
# 아이돌로 회귀하다
# 일념영원
# 크래쉬(Crash)
# 게임 속 검투사가 되었다
# 삼국지 조비전(曹丕傳)
# 로또 1등 재벌 정벌기
#
# -----------------------------------------------
#
# https://ridibooks.com/category/books/1750?page=27
# 얼굴 천재 톱스타
# 나 홀로 전생자
# 신비의 제왕
# 리얼 파이어볼러
# 번개 맞고 축구천재
# 탐식의 재림
# 영화의 신
# 뚝배기로 발롱도르
# NPC는 모두 내 편
# 코딩의 신 IT재벌 되다
# 회귀했더니 입대 전날
# 수강신청으로 세계최강
# 액션스타 마춘동
# 악마가 내린 재능
# 위대한 편집자
# 농사짓는 플레이어
# 풍운신검(風雲神劍)
# 1000만 전생 배우
# 아티스트 메이커
# 정도문
#
# -----------------------------------------------
#
# https://ridibooks.com/category/books/1750?page=28
# 나 혼자 네크로맨서
# 아이돌 육성의 천재
# 재벌가 망나니
# 청동기 시대에서 살아남기
# 무한의 성자
# 삼국지 유봉전
# 백작가 초절정 고수
# 악당 같은 영웅
# 나 혼자 한 클로즈베타
# 지옥왕, 귀환하다
# 격동의 신대한제국
# 9서클 아이돌
# 기연을만나다
# 강한 금강불괴되다
# 유부녀의 일탈
# 베놈 마스터
# 일일전생 일일현생
# 환생천마
# 악마의 음악
# 양학하는 기갑 헌터
#
# -----------------------------------------------
#
# https://ridibooks.com/category/books/1750?page=29
# 헌터세계의 귀환자
# 주인공이 자꾸자꾸 부활함
# 아메리카 심시티
# 2인자 전성시대
# 기자(欺者)-라이어(LIAR)
# 과금무적
# 오빠, 나랑할래?
# 던전을 수호하라
# 차원종결자
# 제천마영 (연재)
# 생사무운 : 아수라의 길
# 내 싱크로율 999%
# 카오스맨
# 검에 비친 달을 보다
# 빙마
# 9클래스 소드 마스터 : 검의 구도자
# 마성의 손길
# 이상한 소설 속 로빈
# 레벨업하는 무신님
# 노래하는 망나니
#
# -----------------------------------------------
#
# https://ridibooks.com/category/books/1750?page=30
# 마운드의 학살자
# 호러명가 JD하우스
# 건물로 인생역전!
# 나는 헌터가 싫다
# 그 배우의 게임 라이프
# 귀환자의 삼시세끼
# 말단 마법공학자의 귀환
# 막장 악역이 되다
# 다시 일어나는 대한
# 헌터 김황제의 몸속 왕국
# 리메이크 축구명가
# 시작부터 대마법사
# 시스템이 만든 괴물 투수
# 마도선자
# 소수정예로 세계 최강
# 픽미업!
# 레전드가 빙의했다
# 신경외과의사 박재현
# 재벌가 후레자식
# 멸망 이후의 세계
#
# -----------------------------------------------
#
# https://ridibooks.com/category/books/1750?page=31
# 서문반점
# 재앙급 빌런의 출근
# 천재의 게임방송
# 해피해피 고문재단
# 탑셰프의 이세계 레시피
# The Natural Order
# 최강의 검술 천재가 되었다
# 신의 파편
# 귀환천하
# 나 혼자 미래독식 서바이벌
# SSS급 특성으로 촌장에서 황제까지
# 슈퍼 에이전트 : 미래가 보여
# 전설을 꿈꾸다!
# 기적의 스킬 자판기
# 특성강탈자
# 절대귀환
# 나 혼자 특성무한
# 지금 출세하러 갑니다
# 혈마, 망나니되다
# 이번 생은 재벌이다!
#
# -----------------------------------------------
#
# https://ridibooks.com/category/books/1750?page=32
# 나 혼자 엔딩을 본 성자
# 던전에서 성자性者가 하는 일
# 몽골 사용 설명서
# 국회의원 이성윤
# 외계문명 계승자
# 남작 가문 차남 이야기
# 주인공이 물량으로 승부함
# 환생한 F1 레이서
# 능력 먹는 헌터
# 귀환했더니 최강 힐러
# 후작가 대공자는 무림인
# 퍼펙트 라이프
# 대마법사의 재능을 흡수함
# 시스템을 초기화하시겠습니까?
# 세계 최고 축구스타
# 이번 생은 축구다
# 뽑으면 무조건 SSR이 나옴
# 콜렉터 : 회귀자의 마운드
# 천령검제(天靈劒帝)
# 그림 보면 강해지는 최강헌터
#
# -----------------------------------------------
#
# https://ridibooks.com/category/books/1750?page=33
# 나 혼자만 먼치킨
# 마운드의 악마
# 더블게이트
# 노숙자 재벌 되다
# 시크릿 플레이어
# 이드
# 꿈속에서 무한각성
# 물만 마셔도 힘쪄
# 경험치가 계속 올라
# 보너스 스텟 100배
# 환생 카이얀
# 회귀했더니 너무 강해졌다
# BJ는 종말에 적응했다
# 다시 태어나도 그 놈은 피해라
# 야왕, 환생하다!
# 만렙 튜토리얼 깨고 왔다.
# 무너져 가는
# 로드 오브 머니
# 학사재생
# 군에서 종으로, 종에서 조로
#
# -----------------------------------------------
#
# https://ridibooks.com/category/books/1750?page=34
# 나 혼자 블리츠볼 피쳐
# 내 사거리 100만
# 깡패가 종말에 대비하는 법
# 전능의 뮤지션
# 악마의 길을 간다
# VVIP 유료템으로 캐리한다
# 회귀해서 매니저
# 다섯 개의 능력을 쥐었다
# 신을 만나면 신을 죽이고
# 간도진위대 2부
# 악룡 회귀하다
# 죄악의 군주
# 풍운전신
# 무종도담
# 무림오적
# 배드 엔딩 메이커
# 귀신 보는 남자 오덕팔
# 천룡무적
# 적룡 둥지의 수호자
# 여왕전하의 비선실세
#
# -----------------------------------------------
#
# https://ridibooks.com/category/books/1750?page=35
# 닭 튀기고 레벨 업!
# 인생 리셋 오 소위!
# 재앙급 수배자의 헌터 생활
# 역대급 제작사의 탄생
# 스킬 마스터
# 골대 앞의 망나니
# 재벌, 아버지로 회귀하다
# 탑신병자 프로게이머 되다
# 미네랄 쌓아서 이계 군주
# 궁귀 혼자 보우마스터
# FFF급 관심용사
# 피아노의 신
# 내 상태창 2개
# 그라운드의 철벽
# 고양이가 주워온 용
# 악마가 용사를 상대하는 방법
# 서바이벌로 세계 최강
# 무자비한 득점 기계
# 던전 폐기물 센터장의 비밀
# 무제 관우전: 천하를 품은 구름
#
# -----------------------------------------------
#
# https://ridibooks.com/category/books/1750?page=36
# 로그인 더 헌터
# 축구 능력 다운로드 중입니다
# 조선철강왕
# 베스트셀러가 보여
# 미친놈이 연기를 했을 때
# 망나니 불사신의 골목식당
# 환생검마
# 주인공 갑질만세!
# 황룡의 비상
# 천마, 강림하다
# 현대무기로 이계 최강
# 그라운드 위의 택배기사
# 뜻밖의 초특급 서포터
# 시작부터 월드클래스
# 특수지원중대 알베르트 소위
# 석유재벌 채유찬 수상이 되다
# 나 혼자 역대급 귀환 용사
# 회귀해서 레벨업
# 테이밍마스터
# 아이템 효과 999배
#
# -----------------------------------------------
#
# https://ridibooks.com/category/books/1750?page=37
# 다시 쓰는 헌터사
# 케미
# 밥먹고가라
# 탑 코더
# 내 부하들은 천하제일기재
# 미연시인데 연애를 할 수 없는 건에 대하여
# 묵향
# 귀두대도
# 무한전생-사냥꾼 아크
# 삼국지천하 : 여포로 살다
# 포텐 터진 배우님
# 태을검제
# 폭군 고종대왕 일대기
# 던전에서 살아남기!
# 지옥에서 돌아온 용병
# 킹갓 탤런트
# 천마신교 낙양본부
# 완전판 | 황홀의 제국
# 스카우트
# 각성하는 플레이어
#
# -----------------------------------------------
#
# https://ridibooks.com/category/books/1750?page=38
# 게임하면 강해지는 히어로
# 환생검성
# 힐러인데 먼치킨
# 미션깨고 석유왕
# 히든 피스 다 내꺼
# 마운드의 괴물
# 성장률 SSS급 천마
# 이세계 특성 포식자
# 환생 부교주
# 레전드급 낙오자
# 회귀자의 은퇴 라이프
# 회귀에서 클리어까지
# 아름다운 톱가수
# 인형들
# 환생한 줄 알았더니
# 차원여행하고 돌아왔습니다
# 명군이 되어보세!
# 내 이름은 마대
# 튜토리얼로 EX급
# 회귀해서 슈퍼리치!
#
# -----------------------------------------------
#
# https://ridibooks.com/category/books/1750?page=39
# 게임 재벌
# 대한민국 슈퍼 리치
# 절대 고수 성장기
# 귀환한 군주님의 현대 라이프
# 어쩌다 아이돌
# 수컷의 품격
# 데스 나이트였던 아저X씨
# 영겁소혼기
# 상태창빨로 톱스타
# 어쩌다 톱스타
# 공작가 셋째아들
# 아 잠깐만! 나 또 강해짐
# 마왕을 그만둔 이유
# 대물천하
# 표국천하
# 삼류회귀록
# 철과 화염의 시대
# 마신 강림(魔神 降臨)
# 어서 와, 이런 투수는 처음이지?!
# 타자가 공을 너무 잘 던짐
#
# -----------------------------------------------
#
# https://ridibooks.com/category/books/1750?page=40
# 서쳐 - 볼수록 능력치 올라
# 천상계 지갑전사
# Lv999의 귀환
# 이번에는 정말 톱스타
# 벌써 벗은 영주님 : 델로아 전기
# 드래곤을 주운 테이머
# 마도지존
# 차원군주님의 은밀한 귀환 생활
# 삼국지 마초
# My Mp 999999999.999
# 킹갓엠페러 투신의 귀환
# 독점 마법사
# 트레이너
# 야구공에 맞고 모든 게 달라졌다!
# 나는 EX급 헌터다
# 개정판 | Baseball Country
# 19금 게임의 주인공이 되어버렸어
# 고결한 기사님
# 언리미티드 패시브
# 8클래스 마법사의 회귀
#
# -----------------------------------------------
#
# https://ridibooks.com/category/books/1750?page=41
# 규격 외 인챈트 헌터
# 만렙 귀환자의 휴식 계획
# 작은 무사
# 검제
# 중국 재벌
# 올 스탯 9999
# 9이닝 : 야구의 찬가
# 영화는 돈이다
# 발키리 마스터 X-RATE
# 숨만 쉬어도 강해지는 남자
# 칼든 자들의 도시
# 튜토리얼이 너무 어렵다
# 세계 최강 행복한 가장
# 1000층 보상 특별스킬상자
# 섹스 없인 살 수 없어
# 거꾸로 레벨업
# 이벤트 호라이즌
# 무림에서 온 몸치
# 체인지업
# 톱스타가 대수냐
#
# -----------------------------------------------
#
# https://ridibooks.com/category/books/1750?page=42
# 이번 생엔 탑스타
# 권왕전기
# 비밀 카페
# 싱글파파는 천마님!
# 악당들의 빌런
# 코리아 신흥 재벌
# 꺼질 놈들
# 남태령
# 칼에 취한 밤을 걷다
# 메디컬 환생
# 성공신화
# 던전 브레이커
# 1레벨 초월자
# 예능의 제왕
# 천재배우의 페르소나
# 소환수의 이중생활
# 시스템빨로 야구 천재
# 버스킹
# 고기방패, 회귀하다
# 레벨 업 무림세가
#
# -----------------------------------------------
#
# https://ridibooks.com/category/books/1750?page=43
# 필드의 괴물 러닝백
# 스타 여행작가 기동우
# 업어 키운 걸그룹
# 연예기획사 사장의 아들로 태어났다
# 더 퍼거토리
# 학사환생
# 퍼펙트 써전
# 재벌집 막내아들
# 통각수치 100%로 이계 최강
# 입금 완료, S급 용병!
# 제로 라이트: 1만 시간의 법칙
# 나만 플레이어로 소환되지 않았다
# 재벌가 대물사위
# 회귀자의 그랜드슬램
# 내 눈에 탑스타
# 주무르면 다 고침
# 최강 감독 내 머릿 속 A.I
# 던전 탈출이 너무 힘들다
# 창궁지룡
# 망나니 투수가 되었다
#
# -----------------------------------------------
#
# https://ridibooks.com/category/books/1750?page=44
# 별들의 게임
# 용사는 개뿔, 트롤 받아라
# 내 딸이 천마인데 나는 무림맹주
# 전직고수
# 사상 최강의 영주
# 최강,최악의 사신
# 눈 떠보니 흥행의 신
# 역대급 재능으로 환생
# S급 앱의 탑스타
# 내가 바로 세종대왕의 아들이다
# 공포흉가 비제이
# 색황, 귀환하여 헌터가 되다.
# 해트트릭
# 드래곤은 나 혼자 잡는다
# 세계로 간다!
# 강남 큰손 이야기
# 더 레이더 : 초월자라 불리울 사나이
# 내 눈에 시청률이 보여
# 괴물 피지컬
# 레이드 테스터
#
# -----------------------------------------------
#
# https://ridibooks.com/category/books/1750?page=45
# 조선, 혁명의 시대
# 배우, 다시 서다
# 아무도 모르게 레벨업
# 천 년만에 귀환한 사신
# 악마는 클래식을 듣는다
# 마법천재 마술방송
# 초대남 양두기
# 신이 내린 방송천재
# 만렙의 귀환
# 은둔형 마법사
# 개망나니 철종
# 던전 포식자
# 충무공의 후예는 청년백수
# 미래 나노봇을 먹었다
# 100년 수련한 축구선수
# 내가 바로 연예계 최강남자지
# 역대급 먼치킨 소환사의 귀환
# 스탯이 두 배
# 무명낭인
# 개정판 | 천하제일 이인자
#
# -----------------------------------------------
#
# https://ridibooks.com/category/books/1750?page=46
# F급 선수, S급 감독 되다!
# 앰뷸런스
# 조선, 봉황이 포효하다
# 1983 전생 만화왕
# 빙의한 악역이 너무 강함
# 영웅 : 삼국지
# 주식의 귀재
# 정령의 아이
# 꼬마 영주와 전투 골렘
# 스페셜 원: 가장 특별한 감독
# 야수에서 타자까지
# 백 년 만에 귀환 : 잃어버린 명예
# 솔플의 제왕
# 19금 교육법
# 나는 다시 최강이 된다
# 천마님 육아하신다
# 이계용병왕
# 호타준족
# 회귀로 게임 정점
# 검마재생
#
# -----------------------------------------------
#
# https://ridibooks.com/category/books/1750?page=47
# 독재자의 당번병
# 정복군주 대인선
# 백병쟁투
# 망나니 7황자는 꿀 빨고 싶다
# 유닛 뽑는 헌터
# 레벨업하는 남궁세가 소공자님
# 전직 킬러 헌터 되다
# 삼국지 헌제전[獻帝]
# 신이 내게 이상한 놈을 보냈다
# 노가다로 게임지존
# 조선, 제국주의에 물들다
# 소드마스터 플레이어
# 무기를 씹어먹는 헌터
# 어쩌다 보니 대마법사
# 포심 패스트볼
# 지옥에서 돌아온 박부장
# 재벌 서자의 회귀
# 땅만 파도 랭커
# 최후의 생존자, 회귀하다
# 학사군림보
#
# -----------------------------------------------
#
# https://ridibooks.com/category/books/1750?page=48
# 제국을 향해 쏴라!
# 패월진천
# 재벌이 되어버렸다
# 국뽕 스트라이커 박규태
# 하이퍼 서퍼 벤젠스
# 환생축구
# 영주가 너무 셈
# 유골호인
# 역대급 재벌
# 백작가 장자는 재벌
# 무한서고의 계약자!
# 만렙 귀환자입니다만?
# 고인물이 회귀해 버렸습니다
# SSS급 소환능력자
# 엄청난 기연과 회귀
# 던전이터
# 왕따, 재벌되다!
# 전생 20번이면 무림 정복!
# 오펜스 챌린지
# 전능의 팔찌
#
# -----------------------------------------------
#
# https://ridibooks.com/category/books/1750?page=49
# 영웅, 회귀하다
# 미래를 본다
# 먼치킨 고인물 영주되다
# 셰프가 너무 강함
# 남궁세가의 역대급 망나니
# 마법으로 SSS급 빌런 라이프!
# 재벌 정벌기
# 롬대륙 견문록
# 귀멸사, 천하제일 고수
# 임진록, 대륙의 별
# 마녀 사용설명서
# 몬스터를 암살해드립니다
# 100억 영혼으로 꿀 좀 빨겠습니다
# 세계 최초 마궁사
# 책 먹는 배우님
# 기다리면 레벨업
# 레벨이 왜 계속 올라?
# 전쟁의 신
# 종의 기원
# 졸부 집 망나니
#
# -----------------------------------------------
#
# https://ridibooks.com/category/books/1750?page=50
# 내 무공 넘사벽!
# 잠룡전기(潛龍傳奇)
# 당신의 매니저
# 글의 신을 향하여
# 우주게임의 사령관
# 돌아온 기간트 마스터
# 대물남 오천국
# 사상 최강의 에이스
# 기연무적
# 축구를 너무 잘함
# 뽑기로 강해진 SSS급 헌터
# 광고천재의 회귀생활
# 사자의 귀환
# 개정판 | 무림 드래곤
# SSS급 마왕의 귀환
# 헬무트
# 나만이 무공을 사용할 수 있다!
# 튜토리얼 라이프
# 나 빼고 다 젊은이
# 나 혼자 무림 플레이어
#
# -----------------------------------------------
#
# https://ridibooks.com/category/books/1750?page=51
# 마인예속
# 백작가 도련님은 회귀자
# 연기를 너무 잘함
# 야구가 너무 쉬움
# 이세계 최면 유희
# 검신, 던전 출수
# 탑 아이돌 락커를 꿈꾸다
# SSS급 촉수괴물이 지능을 얻음!
# 여초 삼국지
# 전생 라이프
# 이과장은 탑스타!
# 재벌 닷컴
# 변혁 1990
# 무적선생
# 삼국지 위현전 - 죽림결의
# 전생에 음악의 신이었던 남자
# 알브레히트 일대기
# 수양대군, 코끼리를 만나다!
# 백룡의 비상
# 공작가의 소드마스터
#
# -----------------------------------------------
#
# https://ridibooks.com/category/books/1750?page=52
# 페로몬맨
# 자고나니 세상이 게임으로 바뀌었다!
# 농구가 보인다!
# 블러드 씨커
# 만렙in현실
# 조선군벌
# 사마지존(邪魔至尊)
# 악역 바스타드입니다만
# 레벨업만이 살길
# FFF급 구단 매니지먼트
# 경험치 포식자
# 닥터 최태수
# 나 혼자 통조림 사러 멀리 갔다 왔다
# 나 혼자 10만 대군
# 미래의 통장으로 재벌 되다
# 한냥 표국
# 마운드의 제왕
# 차원 이동으로 재벌된 남자
# 열혈 닥터, 명의를 향해!
# 이것이 법이다
#
# -----------------------------------------------
#
# https://ridibooks.com/category/books/1750?page=53
# 3루의 귀신
# 눈 떠 보니 슈퍼스타
# 섹신!
# 난 대물이다
# 덮쳐놓고 레벨업
# 귀환자님 뭐 하세요?
# 그리스의 성신 군주
# 침대 위의 판타지스타
# 금융왜란
# 레저렉션
# 홍원
# 중세지만, 혹성탈출 상황입니다
# 풍운만리행(風雲萬里行)
# 쌍룡현신
# 칼의 목소리가 보여
# 야구는 잘하는 놈이 잘한다
# 어쩌다 재벌아들
# 불멸강호
# 신대륙
# 농사로 이계 평정
#
# -----------------------------------------------
#
# https://ridibooks.com/category/books/1750?page=54
# 한 방의 랭커
# 이계접속
# 정복군주 공민왕
# 벼락스타
# 역대급 먼치킨 마법사의 회귀
# 99만 전생이 날 도와줘
# 필선
# 흡수헌터
# 드래곤이 되다
# 나 혼자 자동보상
# 아이템 매니아
# 중원 싹쓸이
# 돈 버는 스케일이 계속 커져!
# 이 악물고 레벨업!
# 무림대공
# 검은 성탄절
# 관우, 소드마스터 되다!
# 말하는 대로!
# 바람과 별무리
# SSS급 미친놈이 캐리한다
#
# -----------------------------------------------
#
# https://ridibooks.com/category/books/1750?page=55
# 귀환하니 보상이 콸콸콸!
# 리턴 마스터
# 역대 최강 레벨업
# 작곡가 최현일
# 될 때까지 리셋!
# 나 홀로 SSS급 테이머
# 마나통이 너무 커요!
# 붉은 제국의 축구 황제
# 황제처럼 살아볼란다.
# 홧김에 시장 되다
# 초월의 검제
# 다시 그린 자화상
# 최고의 행운 - 노량진 고시생 재벌이 되다!
# 무공으로 박살낸다
# 용팔이 - 용의 팔을 가진 사나이
# 차원이 다른 헌터
# 정령으로 요리왕
# 천풍전설
# 갓 싱어
# 재능 재벌
#
# -----------------------------------------------
#
# https://ridibooks.com/category/books/1750?page=56
# 경영의 귀재
# 혼자 다 해 먹는 먼치킨
# 팬텀 제로 - 물질간섭자
# 튜토리얼부터 SSS급 무기가!?
# 스타의 신 APP!
# 4000년 만에 귀환한 대마도사
# DNA가 계속 진화한다
# VIP시스템 for (주)차원
# 부동산왕 박문수
# 100억 골드부터 시작하는
# 스킬의 제왕
# 정령과 농부
# 마검사
# 삼국지 영주 되다
# 남은 건 복수뿐
# 창천마검
# FFF급 만능 스트라이커
# 아빠의 레이드
# 잡종능력자
# 신규무사
#
# -----------------------------------------------
#
# https://ridibooks.com/category/books/1750?page=57
# 어서 와 처음이지?
# 스탯 먹는 플레이어
# 블랙 헌터
# 복싱의 제왕
# 위탁요원 위신호
# 애니멀 엔터테이너
# 도화만리
# 흑염마도
# 내 나이 90살에 회귀라니!
# 색공
# 월혼검
# 내 눈에 아우라가 보여
# 생존만으로는 부족해.
# 천마의 100번째 회귀
# 마왕이 너무 많다
# 미칠듯한 레전드의 존엄
# 엠파이어 오브 더 링
# 호텔 매니지먼트
# 강철 상남자
# 귀환 SSS급혈마 현대 소환록
#
# -----------------------------------------------
#
# https://ridibooks.com/category/books/1750?page=58
# 레벨업 닥터 최기석
# 공략집을 습득하셨습니다
# 팔방미남 뮤지션
# 초룡신검
# 제네온
# 리스타트 라이프
# 더러워서 내가 키운다
# 기적의 이메일
# 포식하며 폭풍성장
# 고결한 영혼
# 내가 쓰면 최고 시청률!
# 에이스의 2세
# 골렘의 장인
# 혼비백산
# 나는 작가다
# 천풍무영(天風無影)
# 상태창이 사라졌다
# 레벨업 아파트
# 먼치킨의 전승
# 환생자의 제자
#
# -----------------------------------------------
#
# https://ridibooks.com/category/books/1750?page=59
# 너의 진심이 들려
# 강호 만렙지존
# 이계독존기
# 용사 키우는 글쟁이
# 카오스 월드
# 주먹의 노래
# 그림자 군주
# 귀환 진유청
# 올 리셋 라이프
# 성황의 손자는 네크로맨서
# 뉴비 천마
# 사후세계에서 안녕하세요
# 이도류, 20승-20홈런
# 나는 유격수다
# 멸망한 세계의 사냥꾼
# 여섯 영혼의 노래, 그리고 가수
# 골드로 현질해 전쟁에 승리하라
# 신을 죽이러 갑니다
# 사상 최강의 안방마님
# BJ가 싸움을 잘함
#
# -----------------------------------------------
#
# https://ridibooks.com/category/books/1750?page=60
# NPC로 각성한 헌터
# 불멸의 방패병
# 이계에서 프랜차이즈
# 금속 먹는 마법사
# 별이 되다
# 톱배우 매니지먼트
# 바바리안 퀘스트
# Re: Final Boss(리: 파이널 보스)
# 퍼펙트 센터
# 마운드 위의 절대자
# MLB의 새끼고양이
# 나노 마신(喇勞 魔神)
# 차원이 다른 백쉐프
# 킬 더 히어로
# 대해의 백제
# 헌터노트
# 손만 대면 무공 흡수
# 원더풀! 마이 라이프!
# 카르마를 모으는 자들
# 무림 컨설턴트
#
# -----------------------------------------------
#
# https://ridibooks.com/category/books/1750?page=61
# 내 재능 다재다능
# 생사검
# 39호실 오갑수입네다
# 이 남자가 사는 법
# 상태창으로 스타강사
# 악기의 목소리가 들려!
# 재벌마법사
# 온 에어(on air) 고종
# 치킨집 첫째 아들
# 천사혈성
# 잔여 포인트 999999999999P
# 지상 최강의 연예인
# 목수와 가구의 신비한 이야기
# 검은 왕 : 마검의 주인
# 조자룡 하북제패
# 밸런스 붕괴, 무기상점
# 용랑기
# 업어 키운 사매들
# 무림여학원
# 신마경천기
#
# -----------------------------------------------
#
# https://ridibooks.com/category/books/1750?page=62
# 무한스킨으로 이계최강
# 메디컬
# 용사를 피해 튀어라
# 업어 키운 여포
# 개정판 | 메모라이즈
# 슬기로운 생존생활
# 톱스타 이건우
# 내 디딤발이 360°
# 이스포츠 프로게이머
# 딸바보 톱스타
# 배우, 조선 왕이 되다
# 삼국지 속으로
# 사상 최강의 군주
# 길 가다 주운 SSS급 반지
# 천옥대공 진조여휘
# 예능신이 강림하사
# 슈퍼크랙
# 유랑화사
# 뽑기 마스터
# 던전에서 살아온 남자
#
# -----------------------------------------------
#
# https://ridibooks.com/category/books/1750?page=63
# 주먹은 강기를 싣고
# 악당의 아들로 태어났다
# 책을 읽으면 경험이 쌓여!
# 지니 스카우터
# 스타 메이커
# 회귀한 북부의 전투 사령관
# 개정판 | 전검왕
# 더 랩스타
# 그림 그리는 마법사
# 음악의 신
# 야설가와 대마왕
# 남창목가
# 먼치킨의 필독서
# 학사무경
# 신의 눈을 가졌다
# 시스템으로 레벨업
# 마탄의 연금술사
# 마법도 이력서에 써도 되나요?
# sss급 랭커, 회귀하다
# 폭군 갱생기
#
# -----------------------------------------------
#
# https://ridibooks.com/category/books/1750?page=64
# 천하제일 아이돌
# 모르도 온라인
# 야망의 눈동자
# 나는 왕이로소이다
# 고고학자
# 한의韓醫 스페셜리스트
# 내 손끝의 탑스타
# 이제 내가 몹이다
# 심판의 군주
# 소드마스터로 회귀
# 두 번 사는 포수
# 추억팔이 BJ의 회귀방송
# 대항해시대 이야기
# 유적 포식자
# 필드의 군주
# 닥터, 조선 가다
# 광끼 : 미친 재능의 탑스타
# 에이스 오브 에이스
# 요리의 신
# 피도 눈물도 없는 용사
#
# -----------------------------------------------
#
# https://ridibooks.com/category/books/1750?page=65
# 식사를 합시다
# 더 게이머 : 판타지아
# 시스템으로 레벨업 하는 영주님
# 마성의 락스타
# 축구소설인데 주인공이 아님
# 킬 더 드래곤
# 사자의 역투
# 15서클 마법사였습니다
# 던전 견문록
# 무협 게임 캐릭터로 21세기에 가면
# 강화 실패를 리셋한다!
# 유물 읽는 감정사
# 재벌삼국지: 현질 과금전
# 신룡의 주인
# 내가 영화다
# 배틀워치
# 퀘스트 주는 프로듀서
# 학사귀환
# 책에서 연기를 배웠습니다
# 게임캐릭터로 환생
#
# -----------------------------------------------
#
# https://ridibooks.com/category/books/1750?page=66
# 현세귀환록
# 사상 최강의 에이전트
# 맛깔나게 만들어드려요!
# 전설적인 교도관입니다만
# 설향
# 나는 프로게이머다
# 천상의 목소리
# 21세기 무림세가
# 레전드 플레이어
# 십장생
# 영주학개론
# 대군으로 산다는 것
# 천하제일 석가장
# 사이 영 재림하다
# 신의 아들
# 내 머릿속 무한 레시피
# 워싱턴 키드 : 대한민국의 꿈
# 역대급 천재작가, 전설이 되다!
# 폭딜 누커
# 마교서생
#
# -----------------------------------------------
#
# https://ridibooks.com/category/books/1750?page=67
# 나태한 소드마스터
# 스킬로 이세계 탑셰프
# 조상님 능력 흡수
# 천마, 재벌되다
# 라스트 콘스탄틴
# 무한의 마법사
# 베르사유의 이방인
# 시스템 오류로 에이스 등극!
# 지옥에서 돌아온 한대성
# 내 아이돌은 인생 2회차
# 회귀하고 더 강해진다
# 일식이가 간다
# 사상 최강의 마법사
# 영화 찍는 마법사
# 해피니스 스토어
# 마법탐정
# 회귀의 축복
# 던전 채널
# 쌍룡기
# 나는 아직 살아있다.
#
# -----------------------------------------------
#
# https://ridibooks.com/category/books/1750?page=68
# 영주, 재벌이 되다
# 인생 2회 차, 축구의 신
# 회귀도 13번이면 지랄 맞다
# 무영문
# 서폿용사님 볼 차신다
# 다이아몬드의 지배자
# 약팔이에서 성좌까지
# 염라무
# 오늘의 예언
# 술 마시다 각성한 SSS급 던전 마스터
# 회귀자의 배틀로얄
# 던전을 만든 신이 보인다
# 회귀하여 무과금으로 S급 플레이
# 제독 미하엘
# 굶주린 소녀용사
# 0.0001초 광속의 이레귤러
# 축구가 가장 쉬웠어
# 회귀로 대박난 헌터
# 후작가의 망령재림
# 조선, 내가 바꾼다
#
# -----------------------------------------------
#
# https://ridibooks.com/category/books/1750?page=69
# 마왕
# 조지 부시의 위대한 미국
# 만렙인턴 이현성
# 저니맨은 우승청부사
# 맛으로 승부합니다!
# 오합지존
# 리셋라이프
# 십이천문
# 월드 스타
# 시스템창으로 옥타곤 최강자
# 회귀한 소환술사
# 미래컴퓨터를 줍다 : 초갑질기업물
# 창조노트
# 홧병신공: 빡칠수록 쎄진다
# 독재자
# 나 혼자만 일일 보상
# 독존왕
# 제국의 여명
# 나 혼자만 무한 스킬
# 만렙 뉴비
#
# -----------------------------------------------
#
# https://ridibooks.com/category/books/1750?page=70
# 내 근력 스탯은 20억
# 재벌 회장이 죽었다
# 100층의 회귀자
# 죽지 않는 랭커
# 마왕 바텐더 이정민
# 담배만 펴도 강해진다
# 나 혼자 쿨타임 제로
# 반격의 엑스트라
# 위저드 스톤
# 엘프는 친절한 종족입니다
# 최강현령
# 레벨업 건달 강대풍
# 개정판 | 정신 생존 투쟁기
# 이런 매니저 또 없습니다
# 신광복군
# 초대박 환생
# 인랑지왕(人狼之王)
# 기적의 환생
# 회귀한 게임천재, 권신이 되다!
# 전생에 나라를 구했다
#
# -----------------------------------------------
#
# https://ridibooks.com/category/books/1750?page=71
# 마법사 전성시대
# 일제를 쏴라!
# 내가 드래곤이 되던 날
# 전생자轉生者
# 파이널 보스
# 마법사 미국을 먹다
# 1000조 재벌
# 신의 마법사
# 간택하는 남자
# 빅찬스
# 헌터, 인생 역전!
# 리바이블 마검사
# 쇼미더 엔터
# 야만의 군주
# 재벌 매니지먼트
# 이소파한
# 트윈문
# 나는 무공을 가지고 환생했다
# 알고 보니 천마 지존
# 만렙부터 레벨업
#
# -----------------------------------------------
#
# https://ridibooks.com/category/books/1750?page=72
# 나는 군주다
# 양자 노트북으로 초대박 인생!
# 내 마법이 더 쎈데?
# 슈퍼스타의 비밀 어플
# 쥐뿔도 없는 회귀
# 군주의 게임
# 의도치 않게 내 던전이 최악의 던전이 되어간다
# 장수태왕전
# 대망
# 환생행
# 공략까지 무한회귀
# 시공 상인 이강석
# 육룡재림록
# 우주아이돌
# 필그림
# 군터
# SSS급 천재
# 삼국지 제국의 변란
# 그라운드 볼러
# 이계에서 힘을 얻다
#
# -----------------------------------------------
#
# https://ridibooks.com/category/books/1750?page=73
# 검황도제
# 데드 엔드
# 머실리스 : 무법지대
# 인외마경 광룡투희
# 마도종사
# 파왕소람
# 내 가족 정령들
# 모두 다 내 거!
# 귀환무사
# 절대공자
# 스킬메이커
# 충무공, 대한의 황제가 되다
# 색을 보는 배우님
# 삼국지 서영전
# 新 대한제국실록
# 랭커가 되겠다
# 우월하거나 압도적이거나
# 돈의 신
# 코리언 발롱도르
# MVP
#
# -----------------------------------------------
#
# https://ridibooks.com/category/books/1750?page=74
# 위대한 나라
# 시작부터 먼치킨
# 나 혼자 자동사냥
# 두개의 달
# D등급 개미, SSS등급 되다!
# 무림에서 돌아온 RAPSTAR
# ONE GAME
# 소환수 레벨 업!
# 브레이커즈
# 심연의 주인
# 통장빨로 마나 마스터
# 전지적 관중 시점
# 용사가 없는 세계의 영웅
# 암천제
# 마법서생
# 주인공보다 강함(연재)
# 이세계 황제, 탑스타 되다
# 마나의 지배자
# 힘만 찍은 궁수
# 미들라이커
#
# -----------------------------------------------
#
# https://ridibooks.com/category/books/1750?page=75
# 미래 USB로 인생역전!
# 성진변
# 임페리얼 랜서
# 삼황자가 되었다
# 전신 척사영
# 먼치킨의 정석
# 칼에 산다
# 블랙 라벨
# 벨라트릭스
# 헌터계급론
# 빙혼전기
# 불사무적
# 서점으로 나혼자 무한스킬
# 나만 플레이어다 : 절대자의 귀농생활
# 강민혁, 세계를 먹다
# 달려라 김영훈
# 만렙이 귀환했다
# 역대급 먼치킨 중력 각성자
# 전생에 천마였던 남자
# 신내린 연기자
#
# -----------------------------------------------
#
# https://ridibooks.com/category/books/1750?page=76
# 무언가가 침공했다
# 나 혼자 100층
# 환생포식자
# 힐통령-태양의 사제
# 생사결
# 레벨업하는 천만배우
# 리그너스 대륙전기
# 레벨1부터 시작하는 드래곤 라이프
# 두뇌가 계속 진화한다-10000
# 환생부터 재벌까지
# 포식마스터
# 필드에서 레벨업
# 표절도
# 재벌3세 회귀하다
# 야왕전기
# 무극혈
# 무극
# 폭딜 어쌔신
# 저승에서 배웠다
# 소환상인
#
# -----------------------------------------------
#
# https://ridibooks.com/category/books/1750?page=77
# 먼치킨 알바
# 아르카나 하트
# 구독자
# 이 스킬은 이제 제 겁니다
# 싱글플레이어, 멀티에서 TOP먹다
# 삼류무사 2부
# 8서클 마법사의 환생
# 금가무적
# 십전제
# 마신,귀환하다
# 나는 투수다
# 파이어볼러
# 신의 마구
# 슬러거 프로젝트
# 패전처리, 회귀하다.
# 레벨업 에이스
# 자명공자
# 이 헌터 실화냐?
# [개정판] 레필리아 레소드
# 작가, 전설을 쓰다
#
# -----------------------------------------------
#
# https://ridibooks.com/category/books/1750?page=78
# 역대급 마법 재능
# 귀신잡고 폭렙업
# 악마의 오른발
# 죽었다 깨어난 가수
# 비천신마
# 엘로스의 군주
# 천하제일가
# 내 눈에 라인이 보여
# 내 것만 엑스라지
# 미소녀를 공략하자
# 스킬 대장장이
# 갓코인
# 등급인생
# 화산권마
# 삼국수호전
# 리블 온라인
# 이세계 골드리치
# 경험 많은 뉴비
# 쪼렙 천마
# 개정판 | 페널티박스의 폭군
#
# -----------------------------------------------
#
# https://ridibooks.com/category/books/1750?page=79
# 이세계 영주 생활
# 야망검
# 국민배우 정도현
# 계약이 완료되었습니다
# 레벨 업! 하는 식당
# 신흥재벌
# 믿음직한 1승 카드
# 이세계 쉐프 생존기
# 영혼을 노래하다
# 내가 슈퍼맨이 되던 날
# 되찾은 새벽
# 진짜 쩐다
# 기록을 부수는 타자
# 내가 지존이다
# 회귀군주
# 천하제일 부자
# 포션으로 무한성장
# 재능의 책
# 무신귀환
# 신검화산
#
# -----------------------------------------------
#
# https://ridibooks.com/category/books/1750?page=80
# 풍뢰도
# 괴물 투수 성낙기
# 7번째 환생
# 포효강호
# 회귀했더니 검신이었다
# 이계에서 무기상
# 시바! 혼자 딜탱 다 하잖아!
# 나 혼자 극한 던전
# 천애협로
# 마도 진조휘
# 배우, 미친 흡입력
# 탑 레시피가 보여!
# 금검풍운(金劍風雲)
# 스크린의 별
# 천 번의 환생 끝에
# 전생부터 다시
# 오버로드 : 남들은 헬 나에겐 이지
# 일인전승(一人全勝)
# 고검독보
# 드래곤 레이드
#
# -----------------------------------------------
#
# https://ridibooks.com/category/books/1750?page=81
# 신 조선:개혁의 파도
# 환웅의 검
# 다시 한 번
# 물약이 자꾸 땡겨
# 만석꾼
# 내 몸은 무한재생
# 회귀자의 스킬무쌍
# 마검쟁천
# 두 세계의 재벌
# 최강질주
# 이세계 플레이어
# 창천
# 낭왕무오
# 무신학사
# 센터 포워드
# 레전드 오브 노가다
# 라 만차의 전사
# 전직 폭군의 결자해지
# 와룡귀환
# 마인드 마스터
#
# -----------------------------------------------
#
# https://ridibooks.com/category/books/1750?page=82
# 다시 시작하는 헌터 : 암왕 강림
# 무공의 신
# 12시간 뒤
# 로마 : 무신의 기억
# 나는 BJ다
# 리얼헌터
# 비뢰천신
# 필드 위의 전사
# 월드클래스
# lv999 소환의 마신
# 필검우사筆劒羽士
# 21세기 고구려
# 뭐만 하면 강해져
# 귀신 덕에 재벌 되다!
# 나는 전설의 홈런왕이다
# 나 혼자서 클리어
# 도시의 초인
# 여심헌터
# 마스터헌터k
# 환생 절대자
#
# -----------------------------------------------
#
# https://ridibooks.com/category/books/1750?page=83
# 스틸 라이프
# 내 인생 만세!
# 천마왕 유세현
# 형사, 회귀하다!
# 최강스파이 김본
# 게이트 그거 내가 열었다
# 반 언데드
# 삼국지 이성계전 : 천하를 향해 쏘다
# 검사님, 정의구현 가신다
# 축구인생 999회차
# 광룡기
# 마정록
# 장인전생
# 개정판│S.K.T
# 삼국지 생존철학
# 십만년만에 깨어난 함장님
# 삼촌팬, 아이돌 되다!
# 대한민국
# 레벨업하는 저승차사
# 나 혼자 징수 달인
#
# -----------------------------------------------
#
# https://ridibooks.com/category/books/1750?page=84
# 신의 장갑을 얻다
# 대박공자
# 갓 게임
# 폭풍의 그라운드
# 최고다, 강철민
# 그라운드의 지배자
# 갓 오브 블랙필드
# B급 포션 메이커의 회귀
# 레벨업의 전설
# 그랜드 위저드
# 세상은 게임이 아니다
# 정령학개론
# 랭커의 대학생활 : The Original
# 헌터 포식자 : 퍼스트 어벤져
# 1인 방송의 전설이 되다!
# 축구는 상태창으로 하는 거야
# 다시 살다
# 책만 보고 탑배우!
# 신의 축구
# 손만 대도 맛있어!
#
# -----------------------------------------------
#
# https://ridibooks.com/category/books/1750?page=85
# 역천의 왕
# 자동으로 수련되는 남자
# 영업사원 김유빈
# 플레이어즈
# 요리사가 먹방을 잘함
# 나 홀로 상점창
# 나 혼자 리스타트
# 똑같은 아이템이 계속 나와!
# 내가 조선의 주인이다
# 특성 있는 소드마스터
# 소드마스터 힐러님
# 리버스 슬러거
# 어플-미래 미리보기
# 거신사냥꾼
# 시스템 메이저리거
# 이그레트
# 내 방어력 무한
# 전장의 화신
# 풋볼 라운드
# 헌터스톤
#
# -----------------------------------------------
#
# https://ridibooks.com/category/books/1750?page=86
# 두 번 사는 플레이어
# 회귀했더니 던전
# 화려하게 잔혹하게
# 태극마경
# 탑 뮤지션, 음악이 눈에 보여!
# 전생부
# 용병단장 회귀하다
# 신의비서
# 소군
# 살문
# 미래에서 온 컴퓨터
# 먼치킨 플레이어
# 달이 지다
# 낙성검웅
# 가왕 이태백
# 100배로 갚아 주겠어!
# 신사의 상점
# 내 눈에 스카우트
# 공허의 마도사
# 천상의 하모니
#
# -----------------------------------------------
#
# https://ridibooks.com/category/books/1750?page=87
# 미래 지식을 계승 중입니다!
# 헌터생활
# 신의 게임 : 새로운 기회
# 어떻게 파티에 사람 새끼가 한 명도 없냐
# 올힘! 전직 대마법사
# 용사 소환 당했습니다. 근데 마왕을 잡을 필요가 있나요?
# 리베라 : 부회의 방랑자
# 15만 번의 챌린저
# 마교육제
# 나 혼자만 무한 전직
# 야구를 게임으로 배웠습니다
# 생존형 대마법사
# 전왕전기
# 시스템 스트라이커
# 대당검왕
# 탑스타의 비밀상점
# 속가제자
# 레벨이 갑이다
# 로열센추리
# 폰 블레이크
#
# -----------------------------------------------
#
# https://ridibooks.com/category/books/1750?page=88
# 의술의 탑
# 불량학사
# 몬스터 소드마스터
# 어게인 마이 라이프
# 무림인, 이계에서 스텟 업!
# 포탈 생존기
# 삼국지-정훈전
# 오늘은 출근
# 스트라이커 NO.9
# 기원
# 검명
# 천마십위
# 스토리 메이커
# 심득의 레이드
# 그라운드 제로
# 신의 목소리
# 나 혼자 999레벨
# 장인이 돈이 많아요
# 기적의 피아노
# 재능에 눈을 뜨다
#
# -----------------------------------------------
#
# https://ridibooks.com/category/books/1750?page=89
# 만월의 아키텍처
# 기연 네비게이션
# 위대한 갓바치
# 레이드 마스터
# 천재 보컬리스트
# 에스퍼
# 천극수라
# 요리하는 소드마스터
# 왕은 돈이 고프다
# 못생겨도 천하제일
# 엿보기 능력자
# 사마성, 이계에 가다
# 귀환자의 북한경영론
# 분신의 제왕
# 투수 : 죽음의 끝에서
# 이세계 내가 다 먹는다
# 개정판 | 나만이 지구를 선택했다
# 에레도스
# 리터너즈
# 무르바
#
# -----------------------------------------------
#
# https://ridibooks.com/category/books/1750?page=90
# 삼국지 서량난신
# 인비저블 브로큰
# 그 남자의 세 번째 환생
# 모든 숫자를 기억하는 남자
# 새 게임을 시작합니다
# 학원 나웰론에 오신 것을 환영합니다!
# 슈퍼스타, 누구도 막을 수 없어!!!!!!
# 호협천추
# 정자부터 레벨 업!
# 군주의 귀환
# 신의 사도, 영주 되다
# 삼국지 금수저 하후충전
# 좀비 청소부
# 아픈 곳이 보인다
# 탑 스타(Top Star)
# Y13
# 절대수저 재벌인생!
# 서울역 네크로맨서
# 무림 신세계
# 게임 속으로 떨어진 남자
#
# -----------------------------------------------
#
# https://ridibooks.com/category/books/1750?page=91
# 무한소소
# 그리고 너는 용이 되어
# 완전판 | 무공상인
# 낭만용병
# 마검신협
# 준비된 자 이스 2부 : 발륵
# 부의 정점에 서다
# 대사자평
# 천황벽금
# 개천출룡
# 독왕유고
# 녹림마존
# 축구 황제의 귀환
# 질풍 스트라이커
# 무당학사전
# 퍼스트 카운트다운
# 야수왕
# 레벨업 재능마법사
# 레벨업 못하는 플레이어
# 디오(D.I.O)
#
# -----------------------------------------------
#
# https://ridibooks.com/category/books/1750?page=92
# 현대 사회의 악마들
# 대스타, 김대우입니더!
# 재벌가의 탑매니저
# 청운적하검
# 탑스타 K
# 아린이야기
# 회귀 검사, 마피아 되다!
# 전장의 저격수
# 태극검해 1, 2부
# 무당괴협전
# 싸이코패스 in 무림
# 레인디어家 둘째 공자
# RPM3000
# 100마일
# 인생역전, 삼류피디
# 무적 천마(無敵 天魔)
# 대한제국사-한러전쟁
# 매일매일 다른 능력
# 더 매니저
# 저니맨 김태식
#
# -----------------------------------------------
#
# https://ridibooks.com/category/books/1750?page=93
# 삼국천하
# 조선의 봄
# 기적의 연출
# 귀환해서 복수한다
# 완빤치
# 인생을 바꿔라
# 연기의 신
# 서린의 검
# 개척자
# 용마검전
# 개과천선
# 베이스볼 커멘더
# 더 트리니티(The Trinity)
# 불가사의
# 초보마왕의 던전 건설기
# 푸른 늑대
# 전생무신
# 일단 뚝배기부터 깬다
# 성조실록
# 하급 서기관의 회귀
#
# -----------------------------------------------
#
# https://ridibooks.com/category/books/1750?page=94
# 절대무사
# 북천적가
# 회귀빨로 다시 한 번
# 공략자들
# 용문쟁천
# 묵객
# 칼끝에 천하를 묻다
# 최강무사
# 마왕, 귀환하다
# 비정상 헌터
# 검귀의선
# 불멸의 지배자
# 더 라이브
# 마법상점의 대마법사
# 의술의 신
# 드렁큰 블레이드
# 시공귀환
# 무당신룡
# 오크 변호사
# 내가 마인이 된 이유
#
# -----------------------------------------------
#
# https://ridibooks.com/category/books/1750?page=95
# 엠파이어 오브 나이트(Empire Of Knight)
# 노비가 된, 혈마님
# 알바는 거대재벌
# 로만의 검공
# 초월의 마도현자
# 잔인하고 흉악하게
# 언브레이커블(Unbreakable)
# 희귀한 좌완언더, 회귀한 탑아이돌
# 나 홀로 지구에!
# 개정판 | 대풍운연의
# 대미궁 시대
# 조선 쌍놈
# 돌아온 전설 사냥꾼
# 캡슐먹고 축구최강
# 부자(父子) 부자(富者)되다
# 철혈의 제국
# 이번엔 인형술사다
# 삼국지 원술전
# 삼국지 촉한궐기
# 다 쓸어버린다
#
# -----------------------------------------------
#
# https://ridibooks.com/category/books/1750?page=96
# 영구결번
# 퍼펙트 미드필더
# 100마일의 슈터
# 망국의 왕, 재벌이 되다
# 살수가 탑에서 살아가는 방법
# 힐링송 메이커
# vvip재벌 플러스
# 강남 정령사
# 착한 사신
# 무림을 털어먹다
# 환생으로 새 인생을
# 정령사의 회귀
# 발할라 사가
# 본의 아니게 시간 회귀
# 마이더스
# 철혈의 회귀자
# SSS급 언령술사
# 도둑놈에서 고수까지.
# 블랙홀을 삼키다
# 광란의 트롤랑
#
# -----------------------------------------------
#
# https://ridibooks.com/category/books/1750?page=97
# 천마 더 비기닝
# 당구의 신
# 레드썬 레볼루션
# 위대한 소설가
# 메디컬 신드롬
# 내 심장은 드래곤 하트
# 삼류투수의 재기 : 파이어볼러
# 헬 난이도만 깬다
# 삼국지 주상전
# 무당 말고 배우 할랍니다!
# 마운드의 폭군
# 판타스틱 에이스
# 크레이지 무브먼트
# 참 쉬운 레이드
# 가수는 아무나 하나
# 대마법사 재벌 3세 되다
# 용병 아단
# 내 미친 잠재력
# 메디컬 리턴즈
# 전장의 패왕
#
# -----------------------------------------------
#
# https://ridibooks.com/category/books/1750?page=98
# 영주, 검을 들다
# 게이트 넘어 세상
# 시황제가 되다
# 법이 있다
# 나는 대한민국 대통령이다
# 벼락맞은 작가님
# 차원군주
# 나를 위해 살겠다
# 드림사커
# 트란들로스의 신좌
# 스토퍼
# 더아레스
# 능력계승 수호자
# 에센스 오리진-높은산
# 환생 거지왕자 성공적?
# 깨어나라, 최강의 능력자
# 탁구왕 김제빵
# 우리 회사 인턴은 백만장자
# 짐꾼이었다
# 기적의 테이밍 헌터
#
# -----------------------------------------------
#
# https://ridibooks.com/category/books/1750?page=99
# 테이밍으로 지존까지!
# 삼국지 맹장소환
# 천검제
# 역귀 사냥꾼
# 코리안 네트워크
# 가상교환
# 은빛 마계왕
# 불빨-화염포식자
# 용제검전
# 로엔의 마나뱅크
# 신인왕좌
# 나만 빼고 다 회귀했다
# 쇼핑중독자 절대자되다
# 창천의 백제
# 연쇄흥행마 유 감독
# 재벌강점기
# 삼국지 여포전
# 강철의 열제 2부 - 서울정벌기
# 혈왕파천
# 혈신회귀록
#
# -----------------------------------------------
#
# https://ridibooks.com/category/books/1750?page=100
# 딥블루 프론티어
# 무한질주 - 음속의 마법사
# 던플 - 던전에 갇힌 플레이어
# 공간지배자 - 이계를 삼키다
# 신석기 마스터
# 신비소설 무
# 신의 미각
# 하차 이후의 소설 속
# 하이눈High Noon
# 회귀해서 스타셰프
# 이 세계는 멸망해야 한다
# 태조 마연호
# 오버크라운
# 포텐 폭발, 김작가!
# 고스트 요리왕
# 천만영화 제작사
# 권왕의 레이드
# 천의 허지훈
# 신비공자
# 마왕, 사업으로 세계정복하다!
#
# -----------------------------------------------
#
# https://ridibooks.com/category/books/1750?page=101
# 우주에서 온 영주님
# 드래곤 잡아서 강해진 남자
# 비도귀환
# 풍운기협
# 일곱번째 기사
# 형사의 게임
# 마법사인데 마나가 없어
# 광호(狂虎)
# 던전 클로저
# 아티팩트 메이지
# 렙업하는 마왕님
# 퍼펙트 헌터
# 프로젝트：오벨리스크
# 아론의 귀환
# 이세계의 창세기
# 법보다 주먹
# 회귀빨로 지존 헌터
# 히든피스헌터
# 내 명중률 100%
# 무림전생
#
# -----------------------------------------------
#
# https://ridibooks.com/category/books/1750?page=102
# 공작가 장남이지만 엑스트라
# 내 머릿속 혈마(血魔)
# 더 링크 : 절대자는 스마트폰 사용 중
# 레벨업으로 꿀빤다!
# 연단가
# 더 게이머 오리진
# 도사강호
# 천마의 대장간
# 더 시커 : 마나가 필요없어
# 현질 전사
# 내 능력은 매크로
# SSS급 용병의 회귀
# 라이프 하울링
# 헌터는 강화를 한다
# 이 대마도사는 회귀했습니다
# 군주, 귀환하다
# 생존의 대가
# 축구의 화신 : 월드클래스
# 군주, 회귀하다
# 정령사는 회귀로 꿀빤다
#
# -----------------------------------------------
#
# https://ridibooks.com/category/books/1750?page=103
# 오데른 가(家)의 공부하는 후계자
# 발터 가(家)의 회귀한 영주님
# 배우, 희망을 찾다
# 더 뮤지션 : 신의 목소리
# 혼자 레벨업 합니다
# 더 리턴 : 마도공학자
# 검존의 던전사냥
# 회귀자vs전생자
# 모바일로 레벨업
# 역천도
# 간도진위대
# 황하난장
# 선검학사
# 슈퍼 (SUPER)
# 귀견수
# 귀 큰 놈이 되었다 [삼국지 유비전]
# 조상 덕에 영주 합니다만
# 기적의 빅 데이터
# 책만 보고 먼치킨
# 나 혼자만 세이브
#
# -----------------------------------------------
#
# https://ridibooks.com/category/books/1750?page=104
# 참으면 강해지는 남자
# 신을 잡는 절대자
# 드라마의 제왕
# 마이, 마이 라이프!
# 황제! 스탯이 보인다?
# 컴플리트 포워드
# 난봉왕
# 전능의 지배자
# 미티어 스트라이커
# 왕후장상
# 화이트 필드
# 선택지로 랭킹 1위
# 싱크로율-소울 앤 드래곤
# 메타모포시스: SS급 신체변형자
# 비룡승천
# 곤륜패선
# 뱀파이어 스타
# 공작가의 마마보이
# 내 장비창 무한
# 개과천선 스트라이커
#
# -----------------------------------------------
#
# https://ridibooks.com/category/books/1750?page=105
# 혼돈의 군주
# 책사 이만호 1894-1944
# 이 세상 톱스타가 아니다
# 또 다시, 작가
# 무한전생-망나니
# 재벌집 슈퍼스타
# 시스템 위저드
# 클리어 확률 제로
# 나 혼자 게임한다
# 미래에서 온 스마트폰의 신
# 먼치킨과 수련의 방
# 잠만 자도 강해져
# 나만 로그아웃이 안 돼!
# 스켈레톤 마스터
# 에임핵 헌터
# SSS급 공무원
# 1서클 마법사의 회귀
# 무한전생 - 나는 히어론데 우리 형은 무한 전생자
# 환생재벌
# 메모리 리더
#
# -----------------------------------------------
#
# https://ridibooks.com/category/books/1750?page=106
# 너희가 정령을 아느냐
# 미친 재능의 B급 용병
# 라비돌 : la vie dor
# 유결점 스트라이커
# 몬스터 부리는 남자
# 상태창 소드마스터
# 레벨업하는 몬스터
# 일천회귀록
# 만렙 플레이어
# 자꾸 자꾸 잘생겨져!
# 심장 강탈자
# 이계의 후예
# 건축의 신
# 링커
# 강남점쟁이
# 현세독존기
# 혈황지담
# 퓨어 헌터
# 패자지천
# 패왕전설
#
# -----------------------------------------------
#
# https://ridibooks.com/category/books/1750?page=107
# 판광천하
# 탑으로 세계정복
# 킬러의 이계는
# 치트키 쓰는 재벌님
# 정령사
# 적룡마제
# 이계용사 귀환기
# 의생진검
# 내 인생 최고의 샷
# 심연
# 승승장구 9서클 마스터
# 스타셰프, 분식점 아들되다
# 술로 세상을 얻다
# 소환왕 강철중
# 소공자로 환생한 그랜드 마스터
# 삼류작가 회귀하다
# 보스 회귀하다
# 몰락무당
# 더 하이브
# 대군주 하선
#
# -----------------------------------------------
#
# https://ridibooks.com/category/books/1750?page=108
# 당문소공자 당사독
# 나쁜 재벌
# 기간트 마스터
# 군림무적
# 공동전기
# 곤륜소협
# 곤륜금선
# 고수 현대생활백서
# 개미왕
# 북유럽 신화
# 꼼짝 안 해도 레벨업
# 환생표국
# 포인트 헌터
# 뽑기의 신이 강림하였습니다.
# 나는 뱀파이어다
# 검성, 환생하다!
# 전생괴의
# 몬스터는 로또다
# 더 문 차원의 비밀
# 헌터, 웃기지마!
#
# -----------------------------------------------
#
# https://ridibooks.com/category/books/1750?page=109
# 무적호위
# 신체 주고 게임 최강
# 주먹쓰는 사제님
# 황혼. 직감의 소유자
# 브리튼의 용병 군주
# 귀신 보는 퇴마사
# 삼국지 - 패왕지략
# 창공의 기사
# 일대검호
# 남천문
# 21세기 신마록
# 명왕전기
# 천인혈
# 파멸왕
# 환영무인
# 대붕신화
# 내 프리킥이 너무 잘 들어간다
# 검마도
# 인챈트로 인생역전!
# 팽가신화
#
# -----------------------------------------------
#
# https://ridibooks.com/category/books/1750?page=110
# 스타 작가 차태훈
# 제국의 꿈
# 에이스 카드(ACE CARD)
# 주먹의 품격
# 업어 키운 BJ
# 판사 이한영
# 스낵의 왕
# 우리 삼촌은 월드스타
# 권왕전생
# 불멸의 슬레이어
# 철혈검가
# 검마왕
# 초월, 강화의 신
# 윈드 오브 파이어
# 아크(ARK)
# 재벌 말고 사람 되렵니다
# 시바의 후예
# 퍼펙트 게임-더 라스트 볼
# 피가 부르는 바람
# 사커 매니저
#
# -----------------------------------------------
#
# https://ridibooks.com/category/books/1750?page=111
# 종천지애
# 헌터스
# 신세계
# 아이작
# 두 개의 심장을 가진 자
# 나만 공략법을 알고있다
# 무한성장
# 조선의 상왕
# 강철 마왕
# 에고전함입실론
# 낭왕전생
# 듀얼메이지
# 1인 레이드
# 헌터신화
# 아크 더 레전드
# 역대급
# 상왕흥선
# 레이드 콜렉터
# 짝퉁의 전설
# 출사 : 삼국지 촉서 제갈량전
#
# -----------------------------------------------
#
# https://ridibooks.com/category/books/1750?page=112
# 엔딩 보고 현실에서 2회차
# 개정판 | 제로니스
# 생기왕
# 탑스타의 회귀
# 회귀자, 게임으로 억만장자!
# 천마 하고 싶은 거 다 해!
# 노병의 시간은 거꾸로 흐른다
# 21세기 용병왕!
# 아름다운 톱스타
# 아메리칸 드림
# 마크
# 돌아온 전설의 남자
# 슈퍼스타 갱생기
# 몬스터 조합사
# 전장의 사신
# 내 미친 노력
# 돈의 왕
# 강탈의 군주
# 대공 리턴
# 낭만이 사라진 필드
#
# -----------------------------------------------
#
# https://ridibooks.com/category/books/1750?page=113
# 월야행
# 마신귀환
# 만렙 먼치킨
# 미래를 읽는 남자
# 전생인 줄 알았다
# 척안의 마도사
# 답답해서 내가 뛴다
# 천마왕
# 전설이 돌아왔다
# 스포트라이트
# 역대급 IT 재벌
# 리로드 헌터
# 나노머신으로 야동배우 되다
# 개정판 | 강호기행록
# 음양무자(陰陽武子)
# 박멸의 학살자
# 경영의 대가
# 마검
# 최종보스의 귀환
# 크리미널 스타트
#
# -----------------------------------------------
#
# https://ridibooks.com/category/books/1750?page=114
# 내가 영웅이다
# 스탯 찍는 마법사
# 진화의 시대
# 방송의 신
# 화타가 된 외과의사
# 검황 이계 정벌하다
# 정복자 강태풍
# 대현자가 회귀함
# 블랙 듀티
# 협마전
# 책 먹는 마법사
# 저는 용사가 아닙니다
# 기적의 소환사
# 현대 연금술사
# 해왕, 하늘을 건너다
# 북검전기 5권
# 이데아
# 이세계에서 요리사를 꿈꾼다
# 프레릭의 영주
# 천조를 가진 남자
#
# -----------------------------------------------
#
# https://ridibooks.com/category/books/1750?page=115
# 엘론드의 군주
# 이계에서 마교 교주로 살아남기
# 라이프 리트라이
# 1874 대혁명
# 봉명도(鳳鳴刀)
# 바람의 제국
# 생존시대
# 꿈의 제국
# 역검(易劍)
# 삼국지: 유비환생전
# 이세계에서 요식업 하기
# 던전 로드, 진화하다
# 주문 포식자
# 기적의 분식집
# 그래서 나는 탈옥했다
# 탐
# 착하게 살자
# 인외마경
# 스물네 개의 심장
# 좀비 에이지 백수 생존기
#
# -----------------------------------------------
#
# https://ridibooks.com/category/books/1750?page=116
# 신들의 정원
# 리턴 투 포워드
# 이세계 모험 헬퍼
# 불멸의 수군
# 용사기담
# 마수 지배자
# 럭셔리 버프
# 스테이지(stage): 시공의 주인
# 용사를 도우라는군요
# 영웅전
# 드래곤의 유산
# 미궁은 사업이다!
# 현자의 시간
# 정치는 생활이다
# 홈런왕 백강호
# 귀환자 강태성
# 평범하게 빛나는 방법
# 혈크
# 신의 아바타
# 역적조련사 : 조선을 바꾸다
#
# -----------------------------------------------
#
# https://ridibooks.com/category/books/1750?page=117
# 무인향
# EPL-프리미어 리그
# 자본주의가 낳은 괴물 헌터
# 더 게이트
# 유희
# 무자천서
# 뇌전의 군주
# 위풍당당 스토리
# 유건
# 알고보니 야구 재능충
# 신권무쌍
# 갑자기 양녕에 빙의함
# 고인물, 망나니로 살아남기
# 드래곤 푸어
# 암천해일
# 퍼즐백
# 위키니트
# 역전무사
# 금사도
# 패도무혼
#
# -----------------------------------------------
#
# https://ridibooks.com/category/books/1750?page=118
# 용사님, 마왕부터 잡으셔야죠!
# 에델바이스
# 퍼레이션트
# 가면의 마존
# BJ 도슨트
# 전신의 강림
# 무진천하
# 무정지로
# 화산진도
# 십삼월무
# 무사곽우
# 귀궁사
# 패왕기
# 제왕기
# 내가 악마가 되던 날
# 대군주
# 대물헌터 최강남
# 패도무쌍
# 삭풍, 칼이 지나간 자리
# 허무의 세계
#
# -----------------------------------------------
#
# https://ridibooks.com/category/books/1750?page=119
# 악마잡고 레벨업
# 검공무쌍
# 고려검신
# 멋짐이 폭발한다
# 이계귀환자 보디가드 되다
# 마이다스의 손
# 9서클 영주님
# 제로 그라운드
# 저지 타이런트 : 폭군의 저울
# 거침없이 스탯 업
# 클레이즈 A.C
# 사립 사프란 마법 여학교였던 학교
# 검은 심장의 마도사
# 현령무적
# 마감무림
# 사라전종횡기
# 적운의 별
# 벽력왕
# 파천
# 화공도담
#
# -----------------------------------------------
#
# https://ridibooks.com/category/books/1750?page=120
# 검명무명
# 열국지
# 스펙테이터
# 에뜨랑제
# 퇴마행
# 에드가&재호
# 악소림
# 운종룡변종견
# 모험가 배인
# 검선 김체건
# 화산검가
# 무명계
# 알파 플레이어
# 크리티카 성황 흑제
# 내가 영웅일 리 없어
# 아바타 메이커
# 신무시위사
# 트리플A
# 미아리
# 인디고 스톰
#
# -----------------------------------------------
#
# https://ridibooks.com/category/books/1750?page=121
# 집행자
# 자객전서
# NPC 수호자
# 축복의 블루스톤
# 훔치는 연기자
# 귀영마수
# 산왕무적
# 역린
# 유성전 - 신 삼국지
# 용사를 만드는 방법
# 고고학자인데 땅을 안 팜
# 머리에 과학이 넘쳐
# 걸인각성
# 후흑문주 심온
# 타격에 눈을 뜨다!
# 해결사
# 만선문의 후예
# 전전긍긍 마교교주
# 마인정전
# 잠마검선
#
# -----------------------------------------------
#
# https://ridibooks.com/category/books/1750?page=122
# 폭풍이 바치는 시
# 와이즈맨
# 대탈출
# 언더월드
# 조로서도의 괴수
# 제갈세가의 선공자
# 야색계
# 개정판 | 센트널 월드
# 창해군
# 갤럭시
# 준비된 자 이스
# 청랑비사
# 풋볼매니저
# 신을 막아라
# 전투왕
# 천위문
# 질풍의 로젠크란츠
# 이계의 과학자
# 올라운드 플레이어
# 역천검제
#
# -----------------------------------------------
#
# https://ridibooks.com/category/books/1750?page=123
# 엉뚱 히어로
# 쌍룡겁(雙龍劫)
# 십왕결(十王訣)
# 벽강혈루
# 배틀 엠페러
# 무적지존
# 무상검형
# 무당제자
# 맨이터(Man-eater)
# 기가스
# 귀혼열
# 계림유사(桂林流辭)
# 검우
# 고수
# 태양의 전설 바람의 노래
# 대한민국 발차기
# 사이킥 위저드
# 그라운드 헌터
# 샐러리맨과 킬러
# 후안무치
#
# -----------------------------------------------
#
# https://ridibooks.com/category/books/1750?page=124
# 암살자
# 강한 여자
# 멋진 사나이
# 몬스터 대백과사전
# 꿈꾸는 작사가
# 영웅의 발자취 - 두 개의 검
# 삼인조
# 장롱 밑엔 세계가 있다
# 신주검환기
# 불사
# 사가
# 광오문
# 무차별 연기 대전-장미전쟁
# 특전사
# 무영검(無影劍)
# 악마를 부리는 소녀
# 채널-신들의 전쟁
# 죽창무적
# 40,41
# 인트로 코드
#
# -----------------------------------------------
#
# https://ridibooks.com/category/books/1750?page=125
# 마신성존전
# 마계 이야기
# 코뉴 : ONLY ONE LIFE
# 태양의 전설 바람의 노래 2부
# 무급의 제왕
# 무공삼류 내공절정
# 창성전기
# 월하강호
# NPC 공략해서 먼치킨
# 윙포워드
# 최강의 소환령이 되었다
# 치트 플레이로 꿀 빠는 법
# 마제뇌우
# 이것이 5툴이다
# 은퇴기사학개론
# 재벌사위, 콩고의 왕이 되다
# 클라쓰 있는 사장님
# 우리 검사님은 선무당
# 윤극사전기
# 전설의 투자가
#
# -----------------------------------------------
#
# https://ridibooks.com/category/books/1750?page=126
# 귀신 잡는 사장님
# 데일리 히어로
# 아르디엔 전기
# 현대강림 마스터
# 마인의 자식으로 태어났다
# 팔선문
# 헌터지상주의
# 쉘터 능력으로 살아남기
# 와룡봉추
# 절대검해
# 선상의 검신
# 여신의 아이
# 승천무적
# 검선마도
# 사형 집행인의 아침
# 투왕: 나 홀로 이계 무쌍
# 하드펀처 이철민
# 뉴욕 사는 그 마법사
# 낭인천하
# 대사부
#
# -----------------------------------------------
#
# https://ridibooks.com/category/books/1750?page=127
# 무정도
# 무생록
# 덤비지 마!
# 아르카디아 대륙기행
# 현대귀환 마법사
# 이포두
# 슈라라펜란트
# 복수의 길
# 암제귀환록
# 천마신교 낙양지부
# 죽은 자들의 왕
# 재중귀환록
# 대마종
# S.I.R
# 여왕의 창기병
# 드래곤 체이서
# 정령왕의 딸
# 아사랴
# 불사왕
# 아르벤드 연대기
#
# -----------------------------------------------
#
# https://ridibooks.com/category/books/1750?page=128
# 선애야 선애야
# 집사 그레이스
# 귀환병사
# 독보행
# 사이케델리아
# 화산검종
# 소림곤왕
# 만검조종
# 재능 넘치는 게이머
# 골목식당 리얼갑부
# 만학검전
# 지존학사: 히든클래스 in 무림
# 네크로 마스터
# 불영야차
# 내 언데드 100만
# 마법사의 새벽
# 금서의 사서
# 삼국지 마휴전
# 개방 방주 창업신공
# 맞을수록 강해져
#
# -----------------------------------------------
#
# https://ridibooks.com/category/books/1750?page=129
# 인터넷으로 사회를 지배하는 방법
# 퍼펙트 에디터
# 절대적 왕의 탄생
# 상남자 스타일
# 마계 건물주
# 삼국지-금왕 진오
# 폭염의 용제
# 흑암의 귀환자
# 천.산.루
# 완벽한 인생
# 영주 레이샤드
# 어둠의 성자
# 아레나, 이계사냥기
# 비룡의 기사
# 라이프&라이브
# 뉴 에이지(New Age)
# 내일을 향해 쏴라
# 괴짜 변호사 : 악마의 저울
# 용병가
# 그레이트 원
#
# -----------------------------------------------
#
# https://ridibooks.com/category/books/1750?page=130
# 달의 아이
# 붉은 소금성
# 북천의 사슬
# 홍염의 성좌
# 9급 공무원 포에버
# 마라
# 1분마다 돈을 버는 각성자
# 그녀는 마왕?!
# 승소머신 강변호사
# 보스
# 로빈
# 호감 받고 성공 더!
# 아우스:마도 시대의 시작
# 삼국지 더 비기닝
# 헌터, 마신이 되다
# HALF
# 시크릿 메즈
# 헬리오스 나인
# 갓오브솔저
# 게임 캐릭터로 무림에 가면
#
# -----------------------------------------------
#
# ...
# 당신은 모르는 소중한 순간
# 당신은 모르는 사소한 순간
# 새벽, 라디오
# 함께 가자, 천국으로
# 나의 구원 히어로
# 이곳은 금연구역입니다
# 내 주인이 무대포인 건에 대하여
# 코인 세탁소 편
# 미움받는 상사, 완벽한 부하
# 흘러, 넘치다
#
# -----------------------------------------------
#
# https://ridibooks.com/category/books/4050?page=123
# 그의 침실로
# 상아의 탑
# 너의 고양이가 되고 싶어
# 나와 하인들 ~당신이 원한다면 모든 것이 부서질때까지 안아주겠다~
# 형의 처음, 주세요
# 가까운 그 녀석의 비밀 사정
# 이즈미
# 형, 큰일났어! 이거 안 빠져!
# 최면 브라더! ~변태력이 넘쳐버려~
# 신부~제멋대로 카메라맨의 건방진 결혼식~
# 좋아하지 않을 거야
# 아파트에 어서오세요 ~심야의 뱀파이어~
# 에이치★선생님, 시간됐어요
# 폭주족의 사나이 대약속★ ~저 오래전부터 선배를…!~
# 남친은 그의 아버지!? ~당근과 채찍의 BL공방전~
# 있잖아 무라세, 전교방송으로 볼품없게 가버려.
# 그만 여장을 벗겨도 될까요?
# 이런 교제를 시작하는 방법 ~회장님의 수난~
# 포르노
# 고민 상담해 드립니다! ~그 사람과 다시 한 번~
#
# -----------------------------------------------
#
# https://ridibooks.com/category/books/4050?page=124
# 야쿠자 남자의 우정과 욕망 사이~친구에게 품은 마음~
# 싫어하는 그녀석이 날 너무 좋아해서 곤란해
# 서툰 네 고백을 들어줄게
# 이제 제 겁니다 ~늑대 비서의 하극상~
# 쏟는 남자~너를 나만의 것으로 만들고 싶어~
# 사랑으로 맺어지는 방법
# 부적~붉은 실의 출처~
# 끈팬티 피팅체험
# 보칼리제
# 세 개짜리 내 자랑!!!
# 파티쉐☆ ~쇼케이스에 진열되는 것은?~
# 엉덩이를 다루는 법♂
# 바이러스 증식중, 저릿하게 엉덩이에 극대 주사
# 언리미티드 ~속죄의 왕자와 군복의 그대~
# 고민 ~간질간질♪ 은밀한 그 곳♪~
# 왕자님 ~세 사람의 테크닉~
# 비밀 매뉴얼~돌격! 그곳에 피어나는 꽃다발~
# 그이
# 나의 XX한 관계
# 에스테에서 매끈매끈★부드럽게 미끄러지는 마사지♂
#
# -----------------------------------------------
#
# https://ridibooks.com/category/books/4050?page=125
# 사랑한 뚱보
# 남친은 우메보시 보이
# 괜찮나? 괜찮다, 문제 없다
# 합법 완구 NO.666 ~당한 만큼 되갚아라~
# 남동생이 매일 밤 나를 노린다
# 나만의 차장님~중도하차해서 만나러 와 줘~
# 밟아줘!!
# 그 녀석의 그곳을 저주합니다~사랑의 저주인형~
# 그 남자를 맛있게 먹는 방법 ~당신의 좋은 부분, 잘먹겠습니다~
# 과장님의 속옷 사정 ~내가 프릴에 흥분할 리가 없어!~
# 공중 화장실 남자~처음으로 하는 야외 플레이~
# SNIPER
# Sexy Boy~내가 게이 세계의 비너스?!~
# Colors 도쿄전뇌영역
# 뽀뽀해줄테니까 보라구! ~저주받은 식객~
# [블랙스완] 앱으로 맺어진 인연도 사랑이야
# [블랙스완] 딜레마의 사랑
# [블랙스완] 초보자를 위한 첫사랑 입문편
# [블랙스완] 이웃집이 듣겠어!!
# [블랙스완] 수습탐정 미즈키의 최악의 재앙 사건수첩
#
# -----------------------------------------------
#
# https://ridibooks.com/category/books/4050?page=126
# [블랙스완] 맑은 날엔 공원에서
# [블랙스완] 단 것을 좋아하는 그 아이
# [블랙스완] 나에게 남자친구가 생긴 특별한 이야기
# [블랙스완] 건방진 왕자님은 응석쟁이
# [블랙스완] 3년 전 그날부터 계속, 난 너의 장난감이었어
# [블랙스완] 커플링을 사랑한 엑스트라 신데렐라
# [블랙스완] 칠월의 괴담
# [블랙스완] 연상 남친을 사로 잡는 방법
# [블랙스완] 엇갈리는 동거생활
# [블랙스완] 부드러운 온기
# [블랙스완] 스트레이트★사기 테크닉
# [블랙스완] 도둑고양이 회사원과 냥냥 플레이
# [블랙스완] 꿈에서 깨어난 꿈
# [블랙스완] 네 녀석의 그 눈은 반칙이야!!
# [블랙스완] 일그러진 첫사랑
# [블랙스완] 연옥의 인연
# [블랙스완] 내 취향은 당신
# [블랙스완] 나만을 봐줘
# [블랙스완] 열혈 교생X고민쟁이 선생님
# 아름다운 남자 ~욕정남과 사랑받는 나~
#
# -----------------------------------------------
#
# https://ridibooks.com/category/books/4050?page=127
# [블랙스완] 인큐버스를 주웠습니다
# [블랙스완] 승리의 여신은, 안쪽 사람
# [블랙스완] 백귀야행
# [블랙스완] 청춘 크라이시스!
# [블랙스완] 짝사랑 분홍빛 사이다
# [블랙스완] 알파의 외침
# [블랙스완] 약속의 결말
# [블랙스완] 식객과 허당 호스트
# [블랙스완] 그의 장난감이 되었습니다
# [블랙스완] 새끼 손가락에 운명을
# [블랙스완] 허니 글라사쥬~집사, 시작했습니다~
# [블랙스완] 여우 남자와 괴물
# [블랙스완] 비관적인 아이의 사랑법
# [블랙스완] 절륜 뱀파이어
# [블랙스완] 애완소년
# [블랙스완] 잊을 수 없는 입맞춤
# [블랙스완] 이타히메
# [블랙스완] 나의 선생님!
# [블랙스완] 밤까지 기다릴 수 없어
# [블랙스완] 유키의 속박
#
# -----------------------------------------------
#
# https://ridibooks.com/category/books/4050?page=128
# [블랙스완] 카라스마군
# [블랙스완] 아짱은 주근깨 투성이
# [블랙스완] 제멋대로인☆트윈즈
# [블랙스완] 새겨진 애정
# [블랙스완] 고양이식 과격한 사랑법
# [블랙스완] 난 나대로
# [블랙스완] 메이플시럽
# [블랙스완] 위험한 서커스
# [블랙스완] 정열적인 관계
# [블랙스완] 행복해지고 싶어
# [블랙스완] 남자는 그것을 참을 수 없다
# [블랙스완] 터쿼이즈 트랩
# [블랙스완] 파이널 인프레션
# [블랙스완] BORDER -보더-
# [블랙스완] 베이비★메이비
# [블랙스완] 끝나지 않는 밤
# [블랙스완] 연인 베타 테스트
# [블랙스완] 페로몬 사장과 경호원의 일주일
# [블랙스완] 동성과 동거
# [블랙스완] 등을 씻겨드리겠습니다
#
# -----------------------------------------------
#
# https://ridibooks.com/category/books/4050?page=129
# [블랙스완] 마성의 카페 케스케이드
# [블랙스완] 당신을 안아서 사랑을 그린다
# [비애] 아빠 어서 오세요
# [비애] 아이 러브 브라더스!(I LOVE BROTHERS!)
# [비애] 사랑은 조용히 내린다
# [비애] 꼬마의 주장
# [비애] 형, 꺼져버려!
# [비애] 마돈나의 짝사랑
# [비애] 오른손엔 총 왼손엔 사랑
# [비애] 8번째 왕자
# [비애] 손끝에 키스
# [비애] 여름의 마지막 장미
# [비애] 유언(遺言)
# [비애] 만만한 녀석
# 말이 없는 나라에서
# [비애] N.G!(엔.지!)
# [비애] 경국 뮤즈
# [비애] 사랑이라는 병에 바르는 약
# [비애] 입술의 달콤한 독
# [비애] 눈에는 선명하게 보이지 않아도
#
# -----------------------------------------------
#
# https://ridibooks.com/category/books/4050?page=130
# [비애] 차라리 꼬시고 싶어!
# [비애] 한랭전선 지휘자
# [비애] HEROㆍHEEL -영웅과 악당-
# [비애] 제멋대로 로미오
# [비애] 하트 비트 히트(Heart Beat Heat)
# [비애] 크로키(CROQUIS)
# [비애] 이 사랑은 비밀
# [비애] 은빛나비기담
# [비애] 엘리시온의 문
# [비애] 트러블썸 러버(Troublesome Lover)
# [비애] 사랑은 수증기 속에서
# [비애] 네크라트 홀릭
# [비애] 취미의 문제
# [비애] 사랑의 노래를 부르자
# [비애] 임금님 게임
# [비애] 왕자님 게임
# [비애] 난폭한 개
# [비애] 하현달 밤 이야기
# [비애] 만만치 않은 당신
# [비애] 라스트 파트너
#
# -----------------------------------------------
#
# https://ridibooks.com/category/books/4050?page=131
# [비애] 첫사랑 이야기
# [비애] 귀족의 푸른 입맞춤
# [비애] 공작의 은밀한 입맞춤
# 사수생도 연애를 한다
# 프리퀀시 모듈레이션
# 프루스트 탐정L의 미결 사건일지
# 만지지 마!
# 거칠어진 너의 손길 (Brotherly)
# 마음의 강
# 참을 수 없는 유혹
# 그냥 같이 잘까?
# 선배, 괜찮아요.
# 퍼즐(puzzle)
# 관계의 재설정
# 빛 시리즈
# 모란기획
# 시스의 빛
# 만남과 이별의 변주곡
# 달콤한 경계
# 그가 있는 집
#
# -----------------------------------------------
#
# https://ridibooks.com/category/books/4050?page=132
# 악마의 신부 만들기 1부
# 장르 탈출이 시급하다
# 너를 부르는 숫자
# 헌트&헌트(Hunt&Haunt)
# 이기적인 크리스마스를 보내는 방법
# 해파리 소년
# 악마와의 화양연화
# 투 톱(Two Top)
# 새장 속의 새
# 이케부쿠로 집사학원~성아담~
# 뒤를 보니 사랑이었다
# 구제 불능 사장은 가지 않으면 만족하지 못해
# Stay with me!
# 못된 암캐 민감한 그곳을 꾹꾹
# 플레잉!
# 귀여운 게 잘못이야
# Green. 쇼콜라 키스
# 남동생은 이성애자 형과 사이좋게 하고싶다
# 누군가의 오팔
# [크림툰] 교활한 당신이 바꾸는 세계
#
# -----------------------------------------------
#
# https://ridibooks.com/category/books/4050?page=133
# 모티마(Motima: Star in the universe)
# 겨울 나무 숲
# 적당히가 안돼
# 하나 둘 셋!
# 세컨드 시크릿 3부 : 왕자님의 비밀
# 세컨드 시크릿 2부 : 제멋대로 왕자님
# 두근두근
# 친구로는 안 되겠니?
# 친구 새끼, 못난 새끼
# 제주도의 푸른밤
# 두 얼굴의 천사들
# 법률사무소의 왕자님
# 법률사무소의 사로잡힌 왕자님
# 참을 수 없는 욕망
# 우리 가슴에 애정을!
# to one
# 이나즈마의 우정
# 뱀파이어 레퀴엠
# 이 거리가 하얗게 물들 무렵
# 쪽방 이웃집의 위험한 형님
#
# -----------------------------------------------
#
# https://ridibooks.com/category/books/4050?page=134
# 르상티망의 푸른모래
# 포동포동그이
# [허니B] 네리마의 휴일
# 콤플렉스 실험실
# [허니B] 사랑스런 당신에게
# [허니B] 꽃이 될 수 있다면
# [허니B] 사랑은 이렇게
# [허니B] Be my baby (비 마이 베이비)
# [허니B] 지나친 부정은 긍정 아닐까?
# [허니B] 이웃집 남자가 수상해
# [허니B] 외톨이 신은 오늘도 장난을 친다
# [허니B] 깨물고 싶은 녀석
# [허니B] 옆집 오빠가 내 최애 캐릭터랑 닮았다?!
# [허니B] 인정할 수 없어!
# [허니B] 너와 나 사이에는
# [허니B] 이 별에서 가장 밝은 너 -유키의 경우-
# [허니B] 내 순정을 너 따위에게 뺏길 순 없어
# [허니B] 좋아한다고 말할 수 없어
# [허니B] 반짝반짝 스포트라이트
# [허니B] 그날의 우리는
#
# -----------------------------------------------
#
# https://ridibooks.com/category/books/4050?page=135
# [허니B] 십자가에 맹세
# [허니B] 마리오네트
# [허니B] 도둑과 도박꾼
# [허니B] 속박
# [허니B] 유령이 들러붙었습니다
# [허니B] SLOW LIFE EVERY DAY
# [허니B] 세라복을 입은 그 녀석
# [허니B] 귀여운 나의 밤비노
# [허니B] 구제불능, 그 녀석
# [허니B] 동경 소년 시네마
# [허니B] RENAI
# [허니B] LOVERS
# [허니B] 붉은 나비의 봄
# [시크릿] 신 미소년과 야수
# [시크릿] 미소년과 야수
# [허니B] 노치트 라펠에 스친 바람
# [허니B] 벌거벗은 공주님
# [허니B] 유키 군은 마음대로 되지 않아
# [허니B] 동거인
# [허니B] 너에게만 말해줄게
#
# -----------------------------------------------
#
# https://ridibooks.com/category/books/4050?page=136
# [허니B] Movin’On
# [허니B] MAKE LOVE
# [허니B] 그에게 약점이 잡혔다
# [허니B] 귀여운 달링
# [허니B] LOVE SEXALOID
# [허니B] 목요일에 다시 한번
# [허니B] 부서지는 것
# [허니B] 울게 만들고 싶어
# [허니B] 셰어하우스에 오신 걸 환영합니다
# [허니B] 또 갑자기 두근거려 버려
# [허니B] 선생님은 사랑에 서툴다
# [허니B] 묘한 동거 생활
# [허니B] step forward
# [허니B] 우리들의 BL일기
# [허니B] 몸부터 끌리는 사랑
# [허니B] 바보와 안경
# [허니B] 변덕쟁이 고양이를 사랑하는 방법
# [허니B] Black Cowl
# [허니B] 꽃을 취하다
# [허니B] 고양이보다 사랑스러워
#
# -----------------------------------------------
#
# https://ridibooks.com/category/books/4050?page=137
# [허니B] 넘어가면 안 돼요! 이 녀석은 남자예요!
# [허니B] 일그러진 마음의 행방
# [허니B] 러브 스나이퍼즈
# [허니B] 너의 차디찬 입술에
# [허니B] 서투른 나의 달콤한 사랑
# [허니B] 신기루
# [허니B] 느끼는 대로 안기고 싶어!
# [허니B] 무저항 브라더스
# [허니B] 음마에겐 내가 필요해!
# [허니B] 너에게 꽃을 줄게!
# [허니B] 음마와 동거하면….
# [허니B] 사랑한다, 이별한다, 너를 묻는다
# [허니B] 짝사랑 스테이지
# [허니B] 제멋대로 키스해줘
# [허니B] 위기일발 내 입술
# [허니B] 무릎꿇고 영원을 맹세해
# [허니B] 나만의 아이돌 남친
# [허니B] 남학교의 일상!
# Crazy LOVE(크레이지 러브)
# [허니B] 이 별에서 가장 밝은 너
#
# -----------------------------------------------
#
# https://ridibooks.com/category/books/4050?page=138
# [허니B] 카이도 군의 수난
# [허니B] 잠들지 못하는 밤을 위해서
# 비밀이 있는 그 녀석
# [허니B] 돌고 도는 목소리
# [허니B] 방과 후 연애
# [허니B] 집사의 밤은 끝나지 않아 - 천년의 포로-
# 당신만 보여
# [허니B] 가면의 포옹
# [허니B] 집사의 밤은 끝나지 않아
# [허니B] 사랑을 깨달으려면 아직 멀었다
# [허니B] 버섯요정의 연애코치
# [허니B] 밝히는 의사 선생님
# [허니B] 농밀한 손장난
# [허니B] 파견천사의 순정
# 붉은 실이 보이나요?
# [허니B] 사랑만 있으면 살아갈 수 있어
# [허니B] 셋이서 할까요?
# [허니B] 원더 라스트
# [허니B] 친구 신드롬
# 여우신의 신부
#
# -----------------------------------------------
#
# https://ridibooks.com/category/books/4050?page=139
# 아~하고 나를 먹어줘
# [허니B] 꿈꾸고 싶어
# [허니B] 사랑이 가득한 계절
# [허니B] 파란만장☆마성의 남자
# [허니B] 물의 윤곽
# [허니B] 마성의 입술
# [허니B] 러브 도서관
# [허니B] 평생의 연인
# [허니B] 사랑에 매뉴얼이 있나요?
# [허니B] my★bud
# [허니B] colors
# [허니B] 선생님과 함께
# [허니B] 마법청년 니시다군
# [허니B] 꿈의 정원
# [허니B] 오늘부터 달콤한 동거
# [허니B] 정처없이
# [허니B] 아이ⅹ어른의 방정식
# [허니B] 장미 왕자님
# [허니B] 순정남자와 방탕한 정부
# [허니B] 애완 고양이의 유혹
#
# -----------------------------------------------
#
# https://ridibooks.com/category/books/4050?page=140
# [허니B] CALL ME -사랑한다고 말해봐-
# [허니B] 이 손을 놓지 않아
# [허니B] 앞서나간다면 사라지지 말아줘
# [허니B] 에로닌자
# [허니B] 내 연인이 노팬티일 리 없어!
# [허니B] 무중력 왈츠
# 촉촉한 수트
# [허니B] 쾌감 일기
# [허니B] 푸른 하늘★워즈
# [허니B] 봄의 향기
# [허니B] 그래도 내사랑
# [허니B] 사랑의 묘약
# [허니B] 삐뚤어진 왕과 나
# [허니B] PRETTY GUYS
# [허니B] 궁극의 사랑
# [허니B] 너의 목소리가 듣고싶어
# [허니B] 두얼굴의 보컬리스트
# 씬 스틸러
# 봄이 왔다
# 립스틱 바르는 남자
#
# -----------------------------------------------
#
# https://ridibooks.com/category/books/4050?page=141
# 하늘에 울려퍼지는 용의 노랫소리
# 나쁜남자 앤솔로지
# 내일 할 말이 있어!
# 평행선이 만나는 날
# 개정판 | 프로그
# 개정판 | 일그러진 복수
# 개정판 | 휘저어줘! 매직스틱
# 열두 번의 시그니처
# 영국소년~기숙사에서 사로잡아라
# 가르송 카페에서 만나요
# 귀신잡는 공무원
# [BL비엘] 귀여운 게 좋아
# [BL비엘] 사랑의 레시피
# [BL비엘] 애인같은 남자친구
# [BL비엘] 얕보지 마!
# [BL비엘] 저렴한 전율
# 불행체질과 오지랖
# [BL비엘] 너는 하얀 장미 같아
# [BL비엘] 연애기담
# 특별 옵션 안드로이드
#
# -----------------------------------------------
#
# https://ridibooks.com/category/books/4050?page=142
# 촉촉한♂ 신부
# 열애 포르노
# 여장남자 웨딩
# 아름다운 우애
# 시간을 멈추더라도…
# 선생님과 나
# 상품은 치어리더 남자
# 사랑을 쏟는 남자
# 불온한 부적
# 별 세 개짜리 내 자랑!!
# 동인남 비밀 매뉴얼
# 동인남 그이
# 닥터와 나의 XX한 관계
# 내 남친은 우메보시 보이
# 남자끼리 괜찮나? 괜찮다, 문제 없다
# 고스로리 야쿠자 헤븐
# [BL비엘] 로열 버진
# [BL비엘] 귀여운 그 아이는 요망한 늑대였습니다
# [BL비엘] 잡아먹힐 것 같은 생활
# [BL비엘] 사랑의 형태!
#
# -----------------------------------------------
#
# https://ridibooks.com/category/books/4050?page=143
# [BL비엘] 가까운 그 녀석의 비밀 사정
# [BL비엘] 아래까지 모시겠습니다!
# [BL비엘] 이즈미
# [BL비엘] 진짜★좋아!
# [BL비엘] 밝히는 남자 기숙사
# [BL비엘] 몰아치는 연애 구역
# [BL비엘] 추한 금붕어의 사랑
# [BL비엘] 좋아하지 않을거야
# [BL비엘] 저승의 파발꾼
# [BL비엘] 이런 교제를 시작하는 방법
# [BL비엘] 의무실에 어서 오세요
# [BL비엘] 우리의 우정과 욕망
# [BL비엘] 연하 똥개와 거짓말쟁이 선배
# [BL비엘] 연애수사
# [BL비엘] 여장남자 앤솔로지
# [BL비엘] 어쩌다 내가 AV에?!
# [BL비엘] 야쿠자 남자의 우정과 욕망 사이
# [BL비엘] 아름다운 그대
# [BL비엘] 순애 인모럴
# [BL비엘] 숙련된 조교와 솔직한 약속
#
# -----------------------------------------------
#
# https://ridibooks.com/category/books/4050?page=144
# [BL비엘] 소꿉친구의 관리법
# [BL비엘] 사장님이 원하는 스위트 바나나
# [BL비엘] 사랑스런 인큐버스
# [BL비엘] 비밀의 화원
# [BL비엘] 부디 이 감정을 네 이름으로
# [BL비엘] 보칼리제
# [BL비엘] 배신자의 사정
# [BL비엘] 동인남의 추천 리스트!
# [BL비엘] 단맛X짠맛 학원 퓨어 옴니버스
# [BL비엘] 내가 AV에 출연한 이유
# [BL비엘] 나와 건방진 그 녀석
# [BL비엘] 나만의 차장님
# [BL비엘] 나를 골라!
# [BL비엘] 나도 하고 싶어
# [BL비엘] 그대로의 네가 좋아 방과후의 비밀
# [BL비엘] 그 사람의 개가 되고 싶어
# [BL비엘] 그 남자는 양보 못해 (미유키 단편집)
# [BL비엘] 고양이의 일상
# 감독님과 BL성우!
# [BL비엘] 스나이퍼 SNIPER
#
# -----------------------------------------------
#
# https://ridibooks.com/category/books/4050?page=145
# [BL비엘] 스킵 키스 SKIP-KISS
# [BL비엘] NO.1 호스트의 개인지도
# [BL비엘] Colors 도쿄전뇌영역
# [BL비엘] AV남자X순진남자
# [BL비엘] 뽀뽀해줄테니까 보라구!
# [BL비엘] 봄을 기다리는 꽃망울의 상사병
# [BL비엘] 의형제에게 비밀이 있다
# [BL비엘] 잔혹한 우리
# [BL비엘] 너를 보고 있어
# [BL비엘] HELP! 사랑의 신
# [BL비엘] HELP! 사랑 바이러스
# [BL비엘] 집착심
# [BL비엘] 영원한 구속
# [BL비엘] 서툰 네 고백을 들어줄게
# [BL비엘] 그의 애인
# [BL비엘] 좋아하는 걸
# [BL비엘] 이상한 사랑이야기
# [BL비엘] 꽃보다 동정
# [BL비엘] 내가 당신을 만나고 싶은 이유
# [BL비엘] 키스로 반응한 건 생리현상입니다
#
# -----------------------------------------------
#
# https://ridibooks.com/category/books/4050?page=146
# [BL비엘] 가련한 남친
# [BL비엘] 룸메이트의 음란한 연구
# [BL비엘] 해도 좋아
# [BL비엘] 포르노 작가의 애완 정사
# [BL비엘] 저도 함께 어떠세요?
# [BL비엘] 아름다워
# [BL비엘] 신령님의 제물
# [BL비엘] 그 사랑, 교칙 위반!
# [BL비엘] 배고픈 인큐버스
# [BL비엘] 그늘에 나뭇잎 사이로 비치는 햇빛, 그리고 푸르름
# [BL비엘] 음란마귀와 외톨이
# [BL비엘] LOVE적
# [BL비엘] 나와 고양이와 첫사랑 교차
# [BL비엘] 최악의 룸셰어 시작했습니다
# [BL비엘] 남자 기숙사 301호실의 연애플래그
# [BL비엘] 코가미 선생님과 사오토메 군
# [BL비엘] 짜증나는 녀석과 멋대로 플래그가 서버린 건
# [BL비엘] 러브레터 러브레터 카페
# [BL비엘] 새장 속의 파랑새
# [BL비엘] 에고이스틱 블루
#
# -----------------------------------------------
#
# https://ridibooks.com/category/books/4050?page=147
# [BL비엘] 사랑난만
# [BL비엘] 싸움 최고! 키스 최고!
# [BL비엘] 미안해 나를 사랑해줘
# [BL비엘] 러브 이즈 블라인드
# [BL비엘] 석유왕은 사랑도둑
# [BL비엘] 교활하고 사랑스러워
# [BL비엘] 영웅을 주세요
# [BL비엘] 지상으로부터 10센티
# [BL비엘] 에로틱 로얄
# [BL비엘] 건드리면 끝
# [BL비엘] 연화일화
# [BL비엘] VS학생회장
# [BL비엘] 하뉴 선생님의 기숙사 생활
# [BL비엘] 웨딩 S플래너
# [BL비엘] 사랑의 형태
# [BL비엘] 극상의 러브 송
# [BL비엘] 아이돌 비스트
# [BL비엘] 모토야마 치프의 비밀
# [BL비엘] 두 남자의 연애사정
# [BL비엘] 맹수!?러버스
#
# -----------------------------------------------
#
# https://ridibooks.com/category/books/4050?page=148
# [BL비엘] 말로할 수 없어
# [BL비엘] 러브 미 베이비
# [BL비엘] 사랑의 비밀 그 끝은?
# [BL비엘] 어쩔 수가 없어
# [BL비엘] 스모커즈 멜랑콜리
# [BL비엘] 소년이여, 큰 뜻이나 여러 가지를 품어라
# [BL비엘] 유혹하는 밤엔 금단의 쾌락
# [BL비엘] 터프 바이 스마트
# [BL비엘] 패치워크패밀리 (Patchwork Family)
# [BL비엘] 사랑스런 피치 군
# [BL비엘] 짝사랑 권고
# [BL비엘] 욕정, 시작했습니다!
# [BL비엘] 보디가드는 괴짜
# [BL비엘] 안티플라워즈 (Anti Flowers)
# [BL비엘] 지오프론트 (Geofront)
# [BL비엘] 인상파 소녀 군과 두근두근 왕자님
# [BL비엘] 커스텀돌리스 (Custom Dollys)
# [BL비엘] 밤은 너의 색
# [BL비엘] 여우비
# [BL비엘] 당신이 곁에 있는 이유
#
# -----------------------------------------------
#
# https://ridibooks.com/category/books/4050?page=149
# [BL비엘] 연애를 하세요 대디
# [BL비엘] 고슴도치는 반드시 꿈을 꾼다
# [BL비엘] 요괴의 집
# [BL비엘] 마누라 포획계획
# [BL비엘] 한밤중의 사랑
# [BL비엘] 타락천사의 관
# [BL비엘] 존귀하신 도련님의 연애
# [BL비엘] 신주쿠 로맨스 3부
# [BL비엘] 엑스터시 파라다이스
# [BL비엘] 사정점유율
# [BL비엘] 동경
# [BL비엘] 양들의 파수꾼 2부
# [BL비엘] 두 사람의 비밀
# [BL비엘] 정복자와 짐승과 나
# [BL비엘] 그리고 사랑이 된다
# [BL비엘] 리스키크라임 (Risky Crime)
# [BL비엘] 허니데이즈 (Honey Days)
# [BL비엘] 꽃과 폭풍
# [BL비엘] 오래된 연인
# [BL비엘] 사랑은 어디 갔어?
#
# -----------------------------------------------
#
# https://ridibooks.com/category/books/4050?page=150
# [BL비엘] 하트를 훔친 건 누구야?
# [BL비엘] 넥스트 도어 허니
# [BL비엘] 양들의 파수꾼 1부
# [BL비엘] 스크램블 게임
# [BL비엘] 10년이 지나도 사랑해?
# [BL비엘] 러브컬러♥페로몬
# [BL비엘] 사춘기, 열병
# [BL비엘] 부드럽게 속박해 줄게
# [BL비엘] 사랑흉내
# [BL비엘] 뷰티스톡 (Beauty Stock)
# [BL비엘] 떨어지는 꿀의 정숙한 유혹
# [BL비엘] 아프리오리~너와 나의연애규칙~
# [BL비엘] 러브 오어 프라이드 (Love or Pride)
# [BL비엘] 오픈에어 (Open Air)
# [BL비엘] 사랑은 하룻밤에 이뤄지지 않는다 3부
# [BL비엘] 에토와
# [BL비엘] 앤틱로즈
# [BL비엘] 신주쿠 로맨스 2부
# [BL비엘] 플라워 제일 (Flower Jail)
# [BL비엘] 사랑의 맛은 한번만
#
# -----------------------------------------------
#
# https://ridibooks.com/category/books/4050?page=151
# [BL비엘] 계약애인
# [BL비엘] 신주쿠 로맨스 1부
# [BL비엘] 사랑은 하룻밤에 이뤄지지 않는다 2부
# [BL비엘] 달에게 밝히다
# [BL비엘] 애송이라 미안!
# [BL비엘] 와일드와일드 베이비스 2부
# [BL비엘] 사랑은 모르는 것
# [BL비엘] 백년의 사랑에서 깨더라도
# [BL비엘] 시티 가디언
# [BL비엘] 사랑은 하룻밤에 이뤄지지 않는다 1부
# [BL비엘] 요염한 유희
# [BL비엘] 운이 좋은 건지 나쁜 건지
# [BL비엘] 와일드와일드 베이비스 1부
# [BL비엘] 세룰리안 카페
# [BL비엘] 빙글빙글 카레이도스코프
# [BL비엘] 카페 렐리시로 오세요 (카페 Relish로 오세요)
# [BL비엘] 연애수난
# [BL비엘] 너츠크러시 (Nuts Crash)
# [BL비엘] 멜티 립스
# [BL비엘] 눈을 감고 오세요
#
# -----------------------------------------------
#
# https://ridibooks.com/category/books/4050?page=152
# [BL비엘] 야수의 폭풍
# [BL비엘] 유사군 승리
# [BL비엘] 러브 포션 2부
# [BL비엘] 색도 향기도
# [BL비엘] 어른스러운 교수님이 좋아
# [BL비엘] 러브낫(LOVE/KNOT)
# [BL비엘] 러브 포션 1부
# [BL비엘] 그가 자는 곳
# [BL비엘] 하이퍼 러브 파워 (Hyper Love Power) 3부
# [BL비엘] 하이퍼 러브 파워 (Hyper Love Power) 2부
# [BL비엘] 컬러풀 플라워
# [BL비엘] 하이퍼 러브 파워 (Hyper Love Power) 1부
# [BL비엘] 헤어진 남자는 어떠십니까?
# [BL비엘] 그와 그 미만
# [BL비엘] 이상적인 연인을 보냅니다
# [BL비엘] 패션후르츠의 향기
# [BL비엘] 달빛도 닿겠지
# [BL비엘] 콜링
# [BL비엘] 에덴
# [BL비엘] 노웨어
#
# -----------------------------------------------
#
# https://ridibooks.com/category/books/4050?page=153
# [BL비엘] 비엘티 (BLT)
# [BL비엘] 해피 플레이스 3부
# [BL비엘] 연립주택에 어서오세요
# [BL비엘] 심술궂은 사람
# [BL비엘] 비교적 흔히 있는 남학교 연애사정
# [BL비엘] 당신은 나만의 꽃
# [BL비엘] 허쉬! (Hush!)
# [BL비엘] 해피 플레이스 2부
# [BL비엘] 해피 플레이스 1부
# [BL비엘] 사랑의 언령 2부
# [BL비엘] 피스 2부
# [BL비엘] 피스 1부
# [BL비엘] 숨결보다도 다정해
# [BL비엘] 오랫동안
# [BL비엘] 닥터의 기분은 저기압
# [BL비엘] 허니 허니 허니
# [BL비엘] 러브 레시피 2부
# [BL비엘] 러브 레시피 1부
# [BL비엘] 비터 스위트 카페 (Bitter sweet cafe)
# [BL비엘] 정상의 해바라기 2부
#
# -----------------------------------------------
#
# https://ridibooks.com/category/books/4050?page=154
# [BL비엘] 정상의 해바라기 1부
# [BL비엘] 원룸의 사랑
# [BL비엘] 스펠(Spell)
# [BL비엘] 낙하속도
# 순결한 새색시
# 아스테_Asteroid
# 마피아와 마법사
# 신의 연애사
# 잘 있어 이베리스 다녀왔어 아이비
# 쾌감 스위트바디
# AM 4
# 동물학적 정원
# 최강의 수
# [해피니스B] S, 체험판♥
# [해피니스B] 서른두 살의 지도
# [해피니스B] 극동기담
# [해피니스B] 비밀스러운 일
# [해피니스B] 고양이 길들이기
# [해피니스B] 연애와 몸의 경계선
# [해피니스B] 정글킹
#
# -----------------------------------------------
#
# https://ridibooks.com/category/books/4050?page=155
# [해피니스B] 패러프레이즈
# [해피니스B] 히로익 에고이스트
# [해피니스B] 로맨티스트 에고이스트
# [해피니스B] 어른의 시간
# [해피니스B] 아이의 시간
# [해피니스B] 타올라라! 타카라라 코퍼레이션
# [해피니스B] 러브? YES
# [해피니스B] 그 마을에서 남자는 버스에서 내렸다
# [해피니스B] 구속지원
# [해피니스B] 우리는 타카라라 코퍼레이션
# [해피니스B] 첫 사랑의 감옥
# [해피니스B] 가끔 우리는 어린아이 같다
# [해피니스B] RUB in LOVE (러브 인 러브)
# [해피니스B] 미타무라의 장난감
# [해피니스B] 목욕탕에서 합체계획
# [해피니스B] -6mm의 터부
# [해피니스B] 순정 새디스틱
# [해피니스B] Sleep
# [해피니스B] DK기술부 에로틱과
# [해피니스B] 3과 2분의 1
#
# -----------------------------------------------
#
# https://ridibooks.com/category/books/4050?page=156
# [해피니스B] LOGOS ~로고스~
# [해피니스B] 성감 텔레파시
# [해피니스B] 비밀스런 입맞춤
# [해피니스B] 남자의 은밀한 즐거움
# [해피니스B] 잔혹한 사랑
# [해피니스B] Beauty & Beast
# [해피니스B] AV놀이
# Happy Valentine Day - 소매치기 두 소년
# [해피니스B] 애완형제
# [해피니스B] 심야소년
# [해피니스B] 방열JIVE
# [해피니스B] 반창고와 수염
# [해피니스B] 미완성인 몸
# [해피니스B] 나는 천사가 아니야
# [해피니스B] 꽃
# [해피니스B] 선배의 연인은 나?!
# [해피니스B] 애욕·발정MENS ~애완 파견~
# 애인 절찬 발정 중
# [해피니스B] 해피 허니 라이프
# [해피니스B] 핑크 버터플라이
#
# -----------------------------------------------
#
# https://ridibooks.com/category/books/4050?page=157
# [해피니스B] 연애1차시험
# [해피니스B] 우리의 내일에는 사랑이 있다
# [해피니스B] 페로몬계
# [해피니스B] 셔터찬스
# [해피니스B] 낙원 30000피트
# [해피니스B] 연인은 매그넘
# [해피니스B] 쾌감 FORTUNE
# [해피니스B] 귀축 샐러리맨
# [해피니스B] 원내감염
# [해피니스B] 올가닉SONS
# 하늘 아래 그와 나
# [해피니스B] 4차원 남자
# [해피니스B] 사로잡힌 눈동자
# [해피니스B] H보이스라서 미안해!
# [해피니스B] 남겨진 자에게도 사랑은 온다!?
# [해피니스B] 성희롱 교실
# [해피니스B] XI (엑스아이)
# [해피니스B] 하지만 사랑이잖아!?
# [해피니스B] 주치의 (원내감염 후속)
# [해피니스B] 욕망식당
#
# -----------------------------------------------
#
# https://ridibooks.com/category/books/4050?page=158
# [해피니스B] 백마 탄 왕자님
# 신데렐라
# Boui - boui!
# 짝사랑 블루스
# 은상에 대하여
# 블랙초코
# 하트잭 패밀리
# 김태경의 비밀
# 말해줘 달링 [일반판]
# [루비] 가시 감옥 2부
# [루비] 가시 감옥 1부
# [루비] 사랑하는 왕자님
# [루비] 사랑이라고는 부를 수 없어 2부
# [루비] 무인도의 연인들
# [루비] 나쁜 선생의 방정식
# [루비] 진실의 널 붙잡고 싶어
# [루비] 사랑이라고는 부를 수 없어 1부
# [루비] 극상의 연인
#
# -----------------------------------------------
#
# 로맨스 장르 총 647편
# 로맨스 장르 페이지 : 33
# 판타지 장르 총 4000편
# 판타지 장르 페이지 : 200
# BL 장르 총 3158편
# BL 장르 페이지 : 158

# %% [markdown]
# # 조아라 작품 리스트 추출

# %%
import requests
from bs4 import BeautifulSoup

# [카테고리 : 로맨스]
joara_rom_page = 0
joara_rom = 0
while True:
    joara_rom_page += 1
    url = "http://www.joara.com/premium_new/book_list.html?page_no=" + str(joara_rom_page) + "&sl_category=&sl_search=&sl_keyword=&sl_orderby=&sl_othercategory=&list_type=&sub_category=&sl_cate_no=r"
    req=requests.get(url)
    source=req.text
    soup=BeautifulSoup(source, 'html.parser')
    
    # 마지막 페이지 확인
    if (soup.find('div',{'class','list_list_con best_c'})) == None:
        joara_rom_page -= 1
        print("마지막 페이지.")
        break
        
    else:
        # 제목 추출
        title_list = []
        romance = soup.find_all('div',{'class','list_list_con best_c'})
        romance = soup.find_all('div',{'class','finish_list_view'})
        romance = soup.find_all('b')
        
        for i in romance:
            title_list.append(i.get_text())
            
        # 중복 제거
        title_list = list(set(title_list))
        
        if '연재 작품' in title_list:
            title_list.remove('연재 작품')
        if '조회:' in title_list:
            title_list.remove('조회:')
        if '추천:' in title_list:
            title_list.remove('추천:')
        if '선작:' in title_list:
            title_list.remove('선작:')
        if 'Fax' in title_list:
            title_list.remove('Fax')
        if 'Tel' in title_list:
            title_list.remove('Tel')
        
        joara_rom += (len(title_list))
        print(title_list)
        
print("\n---------------------------------------------------------------\n")

# [카테고리 : 판타지/무협]
joara_fm_page = 0
joara_fm = 0
while True:
    joara_fm_page += 1
    url = "http://www.joara.com/premium_new/book_list.html?page_no=" + str(joara_fm_page) + "&sl_category=&sl_search=&sl_keyword=&sl_orderby=&sl_othercategory=&list_type=&sub_category=&sl_cate_no=fm"
    
    req=requests.get(url)
    source=req.text
    soup=BeautifulSoup(source, 'html.parser')
    
    # 마지막 페이지 확인
    if (soup.find('div',{'class','list_list_con best_c'})) == None:
        joara_fm_page -= 1
        print("마지막 페이지.")
        break
        
    else:
        # 제목 추출
        fm_title_list = []
        fantasy = soup.find_all('div',{'class','list_list_con best_c'})
        fantasy = soup.find_all('div',{'class','finish_list_view'})
        fantasy = soup.find_all('b')
        
        for j in fantasy:
            fm_title_list.append(j.get_text())
            
        # 중복 제거
        fm_title_list = list(set(fm_title_list))
        
        if '연재 작품' in fm_title_list:
            fm_title_list.remove('연재 작품')
        if '조회:' in fm_title_list:
            fm_title_list.remove('조회:')
        if '추천:' in fm_title_list:
            fm_title_list.remove('추천:')
        if '선작:' in fm_title_list:
            fm_title_list.remove('선작:')
        if 'Fax' in fm_title_list:
            fm_title_list.remove('Fax')
        if 'Tel' in fm_title_list:
            fm_title_list.remove('Tel')
        
        joara_fm += (len(fm_title_list))
        print(fm_title_list)
# Out:
# ['밤의 탐닉', '벗어나지 못해', '비밀을 지키는 방법', '겉과 속이 다른 그녀', '특이점이 온 관계', '러브 트웬티', '알리사와 마법일기', '아내는 나의 전부', '프리틸라리아-황제의 꽃', '골드퀸', '겨울별의 플라네타륨', '그 여자와의 원나잇', '꽃점, 봐드립니다', '아콰터파나', '아멜리가 연애를 하지 않는 이유', '장밋빛 미래', '결혼당한 남자', '호접 (狐接)', '타임리스 타임', '여라의 잿빛 늑대']
# ['첫날밤에', '美치도록 위험한', '설레어서 [외전증보 개정판]', '너만 몰라', '첫사랑 코디네이터', '당하는 남자, 당기는 여자', '공유하는 사이', '다시, 사랑', '완벽한 비서', '대공을 애첩으로 착각했다', '디어 마이 엔젤', '엘시아', '그 영애의 양조장', '트윈문', '죽다 살아났더니 황태자가 꼬인다', '목줄의 주인은 바뀌었다', '심쿵 로맨스', '수위조절불가', '지독하게 야한 ', '허즈번드']
# ['잠자는 꿈속의 배우님', '위험하고 은밀한', '허락해줘, 누나', '힘 센 로맨스', '애인 대행', '헤스티아', '결혼을 반납하다', '내 호랑이는 물지 않아요', '너랑 할 자유', '이중첩자', '남편 실격', 'Mr. 메리씨', '카를의 주인', '어두운 밤, 당신을 위하여', '얄궂은 선배님', '그리고, 봄이 온다', '다정한 전남편', '첫사랑이었다', '너로 물들어 가는 밤 [외전포함]', '올 오브 미']
# ['나쁜 엑스', '비즈니스 퍼포먼스', '별이 빛나지 않는 밤', '엔딩 체인지', '[BL]신록의 늑대', '바른 생활 악녀님', '야릇한 대표님', '신의 아이 ', '미션, 그를 잡아요']
# ['못된', '추녀, 날다', '스캔들 돌려막기', '이토록, 뜨겁게', '바람이 물을 태울 때', '공작님을 길들여 버렸습니다', '웃지마, 기타!', '길들여지다', '누가 내 죄를 알렸을까', '흔적', '고서점 고냥을 찾아오세요.', '소원을 하나 말할 수 있다면', '내 몸의 조련사', '사랑은 직진', '끌리는 오빠 친구', '늑대가 백조를 사랑할 때', '완벽한 남편', '말하지 아니하고', '새벽달 지새도록 자규성을 어이하리', '대공비 엘레노아']
# ['지구 휴가기', '잔인하고 오만한', '순결한 오빠', '야한 관계 [외전포함]', '섹시한 그 남자의 유혹', '이웃집 악당', '나쁜 시선', '내가 더 잘할게', '달콤한 각인', '그 남자의 결혼 파트너', '페퍼민트 로즈', '질투로 타는 밤', '에로스의 정석', '홀리다', '흔들어도 될까요?', '너를 안아', '아찔한 웨딩플래닝', '백 검사와 홍 수사관', '아가씨는 민폐쟁이?', '아찔한 상사']
# ['히든 게임 시즌4 펜트 업 이모션', '냉궁 황후', '깊게 빠지다', '게임의 여왕 리즈', '히든 게임 시즌 3.5 스페셜 팀', '비서는 괴로워', '불가분의 관계', '히든 게임', '히든 게임 시즌 3 데칼코마니', '비서의 S 다이어리', '그 사랑에 이의있다', '불순한 결혼', '두근두근 뛰고 있어', '사랑을 거닐다', '히든 게임 시즌 2 에볼루션', '그 소설을 믿지 마세요', '작전명 : Red shoes', '이별 연습', '군주의 열애(熱愛)', '늑대왕, 루프스']
# ['달콤한 나의 블루베리', '세실리아의 발밑에는 검은 머리칼이 묻혀 ..', '야릇한 상상', '흑과 백의 퀸', '내가 널 좀 사랑해 [일반판]', '아름다운 인사', '하찮은 신일지라도', '탐스러운 남자', '크리스마스니까요', '너를 사랑하기 위한 300일', '우리 사이', '하얀의 눈사람', '대배우의 품격', '사자님, 소원을 들어주세요!', '치료하는 왕녀님', '아찔한 세입자', '짙은', '양에게 먹힌 여우', '그녀는 지독한 악녀다', '황제폐하의 여왕님']
# ['[BL] 사슬(鎖)', '[BL] 킬 유 어 달링', '터치 보이', '진창에서 꽃은 피는가', '남편을 조련하는 공작부인', '내 사랑 몽슈슈', '내 아내는 스캔들 메이커', '한번 더 반해영', '당신의 뜻대로 하소서', '악역의 구원자', '타므라트의 주인', '오싹한 나의 후배님', '[BL] 페티쉬', '이사장님의 가정부', '내가 당신을 사랑하면', '체온을 나누다 [개정판]', '황금가지를 찾아서-신과 나', '재워주세요', '몽중애', '우리, 헤어질까']
# ['연하남의 사정', '사랑도 성형이 될까요?', '빛나는 결혼', '나랑 자요, 누나', '능해목의 령', '사랑해, 아저씨', '가짜 황후', '살려주세요! 용님!', '나를 안아, 거칠게 [개정판]', '시월愛 몽희', '다시 만난 세상', '깊은 후회', '절대영도 1부', '반짝반짝 나의 별', '내 남자친구는 수호천사', '사랑, 그 지독함', '도련님 길들이기', '첫사랑 적응기', '그대라는 꽃에 물들다', '불순한 사내관계']
# ['마성의 레시피', '수의사 리즈의 전성시대', '100번의 환생', '들려줘, 너의 세레나데', '대표님 길들이기', '까칠하게 달콤하게', '사랑니', '천년보다 달콤한 환생', '[BL] 201호엔 늑대가 산다', '악마 수집하는 성녀님', '아찔한 시크릿', '어어리전(傳)', '금기(Taboo)', '그 남주를 사수했어요', '꽃미남 걸리버', '인생 2회차를 샀다', '톱스타와의 비밀여행', '블랙스완', '가보', '설련화 그리고 사랑']
# ['Luv, cue!', '꼬리 치는 여자', '그대 둘, 나 둘', '시크릿 스캔들 - 내 남친은 아이돌', '헬로우 약혼녀', '[完] 안녕하세요, 학원 나웰론에 오신 것을..', '엿보지 마세요', '[BL] 인턴', '세 개의 칼날', '연애세포가 +1 늘어납니다', '흑린화', '너를 거닐다', '독보천하', '그것은 흩날리는 벚꽃처럼 ', '호텔스쿨 셀린느 다비', '귀족의 딸', '친구끼리 이러면 어쩌지?', '파라오의 연금술사(개정판)', '미친 달', '의심']
# ['그대가 손을 내밀 때', '우리 폐하가 달라졌어요!', '중원에서 살아남기', '트롬페', '푸른 달을 걷다', '이안나 드 리뷔엥 공녀', '샌드위치를 먹는 소년 [완]', '약한 것은 잡아먹힌다', '우리', '말할 수 없는 고백', '밴댕이 대 왈가닥', '사랑은 방울방울', '그는 나를 돌아보지 않는다', '숨겨진 성녀', '장미를 사랑하는 남자', '국민남편 길들이기', '러브 송(Love Song)', '왈가닥 대 밴댕이', '후회없이 사랑해', '막장드라마로 들어가']
# ['로미오와 줄미오를 부탁해', '이그레트', '물속에서', '카로 미오 벤', '요괴와 삽니다', '존재의 이유', '청랑의 반려', '흠뻑 젖은 백의의 순정', '페사한트 공작家', '정려문', 'She? No! He!(그녀? 아니, 그!)', '_', '사막에 피어난 열락의 꽃', '아카디아의 빛', '(完)마피아와 마법사(Maffia&Magician;)', '사랑의 모닝커피', '레이디 해피니스(Lady Happiness)', '그 남매의 사정', '친구로는 안 되겠니?', '그놈에게 이끌리다']
# ['살바토레의 구혼(개정판)', '후궁 스캔들 ', '달콤한 신혼', '사랑의 유효기간♥', '이세계의 아리아', '겨울 노래', '사로잡힌 순정', '구경하는 들러리양', '부드러운 욕망의 속삭임(개정판)', '요정왕의 여기사', '내숭의 정석', '그 손 좀 치워줄래요?', 'plug in(플러그 인)', '함락된 낙원의 신부(개정판)', '만월의 밤', '꿈꾸는 펜던트', '악역을 사랑하다', '날개 달린 황녀님']
# 마지막 페이지.
#
# ---------------------------------------------------------------
#
# ['콜로니 - 사르코시스트 No.12', 'VVVIP 차원 쇼퍼', '개망나니 철종', '인생역전 우강호', '생존게임 : 원 오브 사우전드', '무당패왕(武當覇王)', '랜덤뽑기로 학원최강', '치트코치 정수찬', '나만의 소원퀘스트 ', '나 혼자 미래독식 서바이벌 ', '백작가의 망나니가 되었다', '용돈이 계속 늘어!', '아빠가 너무 강함', '변호의 신, 강태풍 변호사!', '군주로 돌아왔다', '내 딸이 검술 천재', '뽑기게임에서 살아남는 법', '기사의 일기(Diary of a Knight)', '입금 완료, S급 용병!', '게임의 신, 돌아오다']
# ['복수의 끝은 재벌', '태제 덕령[연재]', '불량국가-로그네이션', '전신의 강림', '전략게임 속 엑스트라', '블랙기업조선', '성스러운 아이돌', '알고 보니 천재 뮤지션', '어떤 던전의 인간몬스터[개정판]', '더 엠페러', '파왕소람', '환생한 도련님은 신문구독중', '타자가 공을 너무 잘 던짐', '일식이가 간다', '작전명 : 귀향', '극단적으로 축구하는 놈', '멸망한 세계의 농부', '이것이 법이다', '조선철강왕', '세컨드 : 두 번째 남자']
# ['시체사냥꾼 [연재]', '신의 무공을 배운 초월급 헌터', '천마성의 막내아들', '피아니스트의 마을', '아이돌 육성의 천재', '일념영원', '마신의 힘을 받은 자', '힐링하는 정령사 플레이어', 'Project_Mar-On', '1993 회귀재벌', '템복사로 인생 역전!', '엔딩메이커', '신비의 제왕', '몽골에서 유럽까지', '시스템 에러로 종족초월', '카오스맨', '학사신공', '0살부터 슈퍼스타', 'SSS급 마검사 도련님', ' 환룡의 전승자']
# ['귀신 보는 남자 오덕팔', '은천검제(2부 화산검제)', '능력계승 수호자', '경애하는 수령동지', '훈수로 메이저리거', '좌천당한 하급 장교가 살아남는 법', '시스템 강호지존', '아르카나 마법도서관', '환생자의 제자', '내 능력은 매크로', '성진변', '역대급 재벌 사위', '1919년 대한광복만세 [연재]', '뮤리', '전생검신(轉生劍神)', '삼국지 여포전', '만렙 영웅님께서 귀환하신다!', '헌터의 차원 농장', '각성으로 차원최강', '회귀자 사용설명서']
# ['백작가 서자의 가정교사', '회귀했더니 입대 전날', '나 혼자 검술상점', '소설 속 엑스트라', '주인공이 불행을 다 막음', '이번엔 진짜 재벌!', '믿고 보는 봉감독님', '어서 오세요 드라큘의 흥신소에', '혈마검신', '검사 김서진', '재각성을 하고 보니 마왕이 되었다', '정령 포식자', '각성자', '일신상의 이유로 잠시 휴재합니다', '회귀자의 그랜드슬램', '튜토리얼 라이프', '전직 용사', '로그인하자마자 VIP', '제가 게임 속 악신이라고 하네요', '70억분의 1의 이레귤러']
# ['회귀자의 로열라이프', '이과생 둘이 회귀했다', '북경의 신룡', '재능이 자꾸 늘어', '명문고 EX급 조연의 리플레이', '회귀자의 스타트업', '패왕이 되는 방법', '방구석 프로듀서', '회귀하니 천재 재벌', '예능의 제왕', '조자룡 하북제패', '조선, 혁명의 시대', '문과라도 안 죄송한 이세계로 감', '나혼자 진짜 재벌', '무제 관우전: 천하를 품은 구름', '돌아온 용병왕', '나 혼자 균열에 산다', '천재의 음악방송', '알고보니 일대일 천재', '고려 상왕']
# ['전직지존', '국적없는 용병', '기프티드 (GIFTED)', '이계에서 돌아온 대통령', '재벌가 차남은 먼치킨', '전략삼국지 : 이정(李整)전', '세상엔 씹어먹을 게 너무 많다', '내일은 일인자', '후작가 둔재는 먼치킨', '마운드의 미친 재능', '재벌집 막내로 회귀한 김팀장', '조지 부시의 위대한 미국', '시간을 돌리는 회사원', '로그인 더 헌터', '재능복사 미드라이너는 프로게이머', '아기부터 시작하는 연예계 생활', '붕어된 썰 품ㅋㅋㅋ', '유대인과 세계경영 재벌', '벌써 벗은 영주님 : 델로아 전기', '회귀해서 주식재벌']
# ['막내 공자가 제일 강해', '히든 퀘스트로 탑셰프', '승승장구 연예계 생활', '환생으로 독존한다', '10서클 직전에 환생', '말단 마법공학자의 귀환', '외계 기생체의 숙주', '서자의 반지', '시간 상점으로 나도 역대급 재벌', '그 남자가 살아가는 방법', '레벨제한이 없는 유일한 헌터', '회귀적 반로환동', '너클볼', '슬기로운 연예생활', '증권가 큰손 백 할머니', '신화를 만드는 축구 감독', '다시 한 번 톱스타', '공작가의 서자로 살아가는 법', '수의사 진태민', '회귀해서 다해먹음']
# ['회귀가 뭐 이래', '위대한 편집자', '나는 BJ다', '청동기 시대에서 살아남기', '닭 튀기고 레벨 업!', '운명을 보는 회사원', '달콤, 찬란한 재벌기', '충무공, 대한의 황제가 되다', '마인드 마스터', '로또 1등 재벌 정벌기', '공포흉가 비제이', '9이닝 : 야구의 찬가', '충무공의 후예는 청년백수', '보이스피싱인데 인생역전', '게임 속 전사가 되었다', '주인공이 자비를 숨김', '코딩의 신 IT재벌 되다', '생사무운 : 아수라의 길', '일제를 쏴라!', '추억팔이 BJ의 회귀방송']
# ['폭군의 필드', '대표님의 향기로운 덕질생활', '평범한 회사원입니다', '회귀한 공간 보유자', '축복의 블루스톤', '내 눈에 아우라가 보여', '검신의 검은 우주를 가르고', '슬기로운 매니저 생활', '필드의 고인물', '템빨', '적국의 왕자로 사는 법', '거대 인공지능 키우기', '귀신 들린 제작자', '재벌 정벌기', '보통유저', '탈모형 미드필더', '3회차 톱매니저', '재능만렙 미드라이너', '백작가 장자는 재벌', '재벌가 후레자식']
# ['사가', '아기부터 검신', '내 안에 마교있다', '애독자의 복선 회수일지', '뚝배기로 발롱도르', '이소파한', '천마 객잔', '평행세계의 나는 축구천재', '대본의 목소리가 들려!', '재벌마법사', '인생 리셋 오 소위!', '막장드라마의 제왕', '함장에서 제독까지', '아포칼립스 2회차', '163417413번째 소울라이크 용사', '내가 키운 S급들', '레벨업 강호', '내 재능 다재다능', '회귀한 톱스타의 힐링라이프', '농사로 이계 평정']
# ['재벌서자이지만 천재라서', '배틀 킹덤 언플의 킹', '만렙커피:던전입구점', '공작님, 회개해주세요!', '1999년 게임 스타트', '이계로 가다 정신만?', '철과 화염의 시대', '핵인싸 이계 모험기', '마교검후 - 중원제일미녀전설', '만렙 찍은 예비 헌터', '약빨이 신선함', '무영문', '망한 재벌 4세, 돌아오다', '100억 영혼으로 꿀 좀 빨겠습니다', '데스 나이트였던 아저X씨', '역대급 천재 재벌', '신세계: 시스템 아포칼립스', '이세계의 정령사가 되었다', '너무 강한 산장 주인', '영웅 - 삼국지']
# ['걸그룹 키우는 현질러', '위저드 스톤', '폭풍의 한반도', '유물의 목소리가 들려', '죽지 않고 살아남기', '폭풍의 그라운드', '플레이어님 귀환하신다!', '하북팽가 막내아들', '공작가 막내아들은 다재다능', '아론의 귀환', '강철의 법칙 : 기갑공학자', '빙의의 신', '나는 회귀했다.', '라이징 스타', '삼국지 서영전', '최강의 검술 천재가 되었다', '사기당해 지구최강', '그리고 용사는 행복하게 살았습니다?', '삼국지 장료신전張遼新傳', 'AOS 소설 아닌데요?']
# ['내가 바로 세종대왕의 아들이다', '사상 최강의 드루이드', '열왕기(列王記)', '수양대군, 코끼리를 만나다!', '정복자 카사르[연재]', '축구소설인데 주인공이 아님', '어서와 내 던전은 처음이지', '정령농사꾼', '광호(狂虎) ', '스탯 먹는 플레이어', '이계 검왕 생존기', '출근하는 강화술사', '나는 헌터다', '스킬조합으로 꿀빠는 공무헌터', '전생자轉生者', 'LV306부터 시작하는 이세계 제왕기', '으라차차! 강찬', '망나니 1왕자가 되었다', '워싱턴 키드 : 대한민국의 꿈', '기적의 민간요법 치료사']
# ['하이데론', '천마가 환생했습니다', '일도천하', '2인자 전성시대', '신화급 각성으로 최상위종', '상태창으로 스타강사', '소천행록', '삼국지 위현전 - 죽림결의', '전설, 망나니를 꿈꾸다', '준비된 자 이스 2부', '전국수석 무림가다', '신마전설', '천지무쌍', '하이브리드 크로스', '요리의 신께서 보우하사', '레벨업의 전설', '리얼(real) 삼국지-원조비사[袁祖秘史]', '한량 정인환 - 혁명의 시대', '천마님 요리하신다', '투수, 미치다']
# ['시스템 오류로 에이스 등극!', '내 머릿속 혈마(血魔)', '템신 강림하신다', '회귀자의 소소한 꿀팁방송', '최고의 맛을 요리해드립니다', '황제, 귀환하다', '평화로운 먼치킨 영지', '유닛 뽑는 헌터', '북부의 제왕', '간지날수록 강해져', '이세계 천재 화가', '졸부 집 망나니[2부 연재]', '게임 속 검투사가 되었다', '귀환 진유청', '마왕님, 배송이 시작되었습니다', '미래를 고르는 매니저', '치트 플레이어', '양학하는 기갑 헌터', '뉴비가 너무 강함', '나 혼자 엔딩을 본 성자']
# ['월야환담 ', '날로 먹는 플레이어', 'BJ대마도사', '나는 명왕이다', '나는 0.1프로다', '은빛 어비스', '고인물, 망나니로 살아남기', '근육조선(筋肉朝鮮)', '피아노의 신', '환생표사', '게이트, 그거 내가 열었다', '재벌집 망나니 7대독자', '양자 노트북으로 초대박 인생!', '마초를 삼킨 페미니스트', '갓 게임', '광전사가 죽지 않아!', '나는 무공을 가지고 환생했다', '레벨이 대수냐', '나 홀로 주문 사용자', '주인공이 자꾸자꾸 부활함']
# ['지옥에서 돌아온 박부장', '이번 생은 축구다', '특성강탈자', '노비에서 황제까지:천장지구(天長地久)', '학사귀환', '마스터 캐슬', '홈런치는 괴물투수', '나 혼자 만렙 귀환자', '꼬마 영주와 전투 골렘', '갓코인', '밤의 대통령', '신의 아들', 'SSS급 특성으로 촌장에서 황제까지', '그 헌터의 자취방 ', '귀환 마교관', '스타 재활 공장', '이세계 황제, 탑스타 되다', '회귀무쌍록', '지상 최강 망나니', '진화하는 플레이어']
# ['세상이 망나니라 깽판침', '유물 먹는 헌터', '허세작렬 배우님', '용사를 피해 튀어라', '플레이볼 ', '갓 오브 블랙필드', '회귀자의 요리비책', '링커 : 유물의 주인을 찾아드립니다', '나만 빼고 다 회귀했다', '게임 관리자 모드', '전설적 재벌', '금속 먹는 마법사', '일단 생존해 보자!', '회귀로 대박난 헌터', '대륙 최강의 복수는 2회차부터', '에테르  흡수하고 지상최강', '임기 첫날에 게이트가 열렸다', ' 역적조련사 : 조선을 바꾸다', '내 딸이 천마인데 나는 무림맹주', '스파이, 슈퍼리치 되다']
# ['마도선자', '현대 네크로맨서 길라잡이', '타나토스', '신풍기협', '도살도법', '패러렐라이프', '마법의 검', '헌터 김황제의 몸속 왕국', '유체이탈 망나니', '각성하니 아내가 자꾸 늘어난다', '홍룡의 나라', '무한전생-사냥꾼 아크', '이계에서 독점방송', '대공자, 가출하셨다', '귀신 잡는 사장님', '마물정화재단', '닥터', '황금 심장의 용', '페이트스피너', '카나바리움']
# ['내 아들은 회귀한 대마법사', '국뽕 스트라이커 박규태', '나의 길', '환생했더니 정령군주', '장수태왕전', '전지적 구독 시점', '강철의 포식자', '전지적 독자 시점', 'DNA가 계속 진화한다', '밸런스 붕괴, 무기상점', '광고천재의 회귀생활', '마법천재 마술방송', '해피해피 고문재단', '태양전기', '천재 보컬리스트', '전설을 꿈꾸다!', '인랑지왕(人狼之王)', '리그너스 대륙전기', '검은 전쟁', '2차 한국전쟁']
# ['회귀했더니 쩔더라', '정자부터 잘생김', '연예계에 등장한 몬스터 PD', '음악천재를 위하여', '귀환자의 영지 경영', '스킬 마스터', '이 악물고 레벨업!', '종말 이후의 포인트 사용법', '5초 후의 게시판이 보여!', '별들의 게임', 'NPC는 모두 내 편', '눈 떠 보니 현대 라이프', '천마강림', '재벌을 향해 Suit Up', '소드마스터 힐러님', '정점에 서다', '성공신화', '회귀도 13번이면 지랄 맞다', '야구의 신', '사립 루레인 학원 시리즈']
# ['상단주의 망나니 아들이 되었습니다', '뽑기로 SSS급 군단 육성', '여신의 아이', '정감록', '역천귀', '망나니 회귀하다', '이계접속', '신대륙', 'MLB-메이저 리그', '타격의 신', '밴드매니아 76', '세계 최강 행복한 가장', '삼국지 유봉전 : 계한의 부흥', '도시의 주인', '도망가용', '주식의 신', '시스템을 초기화하시겠습니까?', 'EPL-프리미어 리그', '소환상인', '먼치킨의 필독서']
# ['영화의 신', '내가 만든 AI가 성좌가 되었다', '너의 스탯이 보여', '조선의 명왕, 강림하다', '막나가는 백작가 망나니 ', '더 로딩', '어쩔 수 없이 레벨업', '분신으로 자동사냥', 'S2급 결혼 헌터', '용왕의 아들이 되었다', '언브레이커블(Unbreakable)', '용사무적', '소크라테스와 귀찮은 제자들', 'The Chef : 흐르는 미각의 선율에 따라', '던전이터', '마운드의 괴물', '사상 최강의 길드마스터', '스킬로 탑배우', '내 마법이 더 쎈데?', '현세의 마제']
# ['엔딩 보고 현실에서 2회차', '삼정풍운', '불사의 포식자', '게이트가 나타났다', '독야행', '역대급 톱스타의 회귀', '무한의 성자', '황제의 서: 유럽 정복기', '십절낭객', '죽음의 기사', '미친 황제가 되어버렸다', '핵재벌 개망나니', '땅만 파도 랭커', '은의 군주', '멸망한 세계의 생존지침서', '플레이어의 탄생', '백작가 막내-카론의 귀환', '용랑기', '[남녀역전] 남자인데 히로인 포지션', '제독 미하엘']
# ['악마의 숲', '환생정령', '이계에서 무기상', '생존학교 : 마피아 게임의 이해', '내 무공 넘사벽!', '세상은 게임이 아니다', '위대한 표절자', '더 워커-아주 특별한 언데드', '회귀 검사, 마피아 되다!', 'B급 포션 메이커의 회귀', '패자의 시대', '내가 조선의 무당이다', '그녀의 딸이 날 노린다?!', '언터칭', '전국 제패의 꿈', '축구황제 신종철', '빙마술사의 금주서', '타임리스', '함장 레이지', '야만의 군주']
# ['프라이드', '언론의 신', '검황의 이름으로', '정복자', '산공질풍기', '차원이 다른 백쉐프', '무림영주', '천하무적 미드필더', '포이즌 킹', '타임 리퍼 [개정판]', '내 특성은 한국인', '철혈백작 리카이엔', '회귀했더니 검신이었다', '1만의 법칙', '정령사 자일', '리버스 슬러거', '삼국지 맹장소환', '묵향', '미래 지식을 계승 중입니다!', '조선, 봉황이 포효하다']
# ['로드는 로드 중 : 회귀자의 영지', '무사', '전투의 신', '도굴왕', '경종, 살아남은 왕', '늑대를 개로 만드는 방법', '두 개의 심장을 가진 자', '현실적생존', '전생을 했으면, 당연히 즐겨야겠지?', '대스타, 김대우입니더!', '포란', '자하검전', '마도환생', '병(病) 검성의 귀환.', '제로 디멘션', '가상교환', '사상 최강의 노클래스', '갓 싱어', '무신귀환', '위 공공(魏 公公)']
# ['눈 떠보니 음악천재!', '아소비도', '임페리얼 랜서', '바이트 미', '[완결] 필드에서 레벨업!', '[완결] 축구의 품격', '삼국지 모사 희지재', '강철의 열제', '4000년 만에 귀환한 대마도사', '성자는 개뿔, 현대의학의 힘이다', '마신의 유희', '저지 타이런트 : 폭군의 저울', '프로즌 어스', '계약이 완료되었습니다', '회귀빨로 지존헌터', '환영', 'S급 운빨로 얻은 회귀능력', '귀환하니 보상이 콸콸콸!', '50년간 수련 그리고 회귀', '월드 스타']
# ['기적의 올라운더', '마도천하', '청조만리성', '생존과 죽음', '화산검노', '엄마는 절대고수', '야수의 땅', '화산검가', '풍운검협전', '금사도', '만렙in현실', '흑풍구', '패왕투', '몽유강호기', '파천', '귀궁사', '신필천하', '가면의 용병왕', '마류', '참 마스터']
# ['불량용사', '태엽장인', '이계생존귀환계획', '간도대란', '무차별 연기 대전-장미전쟁', '포인트는 넘쳐흐른다고!', '재능 만렙 재벌 2세', '사이코패스와 기업살인', '사자의 귀환', '남자의 축구', '힐러, 현대를 주름잡다', '오러워즈', '동해', '켈베로스', '호박마차', '악마를 부리는 소녀', '역적 이한용', '이력서의 경력란에 마왕이라고 적을 수 있..', '환생CEO', '신화경']
# ['피도 눈물도 없는 용사', '역대급 먼치킨 마법사의 회귀', '민간군사기업  BLACK ANGEL', '마도종사', '어플-미래 미리보기', '게임 캐릭터로 이계에 떨어졌다', '더 데이 : 태초의 전쟁', '강호기행록 [개정증보판]', '상태창 소드마스터', '봉황의 비상 - 조일전쟁편', '검왕까지 레벨업!', '종천지애', '피가 부르는 바람', '포춘 콜렉터', '심장 강탈자', '지천명아비무쌍', '사천당문', '삼국지(三國志):더 비기닝', '지옥에서 온 좌완 파이어볼러', '아프니까 절대자다']
# ['마장 골핑머신', '히든 메이지', '뽑기의 신이 강림하였습니다', '천년 백작: 브라운가의 비밀', '깃발 아래서', '용제, 신을 찢어라', '선혈의 군주', '히든 직업으로 대박내기', '검황이계정벌하다', '고검독보', '삼인조(三人組)', '미스터 매직ENT', '야장, 기적을 만들다', '편의점의 소드마스터', '프리랜서 마법사', '진실게임 : 배신의 덫', '시작하면서부터 끝나는 그와 그녀들의 학교..', '랍타: 이계 변호사', '싱크[Sync]', '임베디드']
# ['바람의 아들', '더블 에이스', '21세기 무림세가', '전능의 지배자', '제작해서 갑질한다', '그레이트 써전', '월드 엔터테인먼트', '영웅의 발자취 - 두 개의 검', '재벌로이드 (Chaeboloid)', '지존', '백수연대기', '말세 종결자', '하얀 그림자―영웅연대기', '얼라이브', '신대한제국', '검황도제', '유령의 주인-유령도서관-', '히어로는 없다', '대제국시대', '대마법사 락스타 (Magical Rockstar)']
# ['영혼을 지배하는 플레이어', '링크(LINK)', '강철의 정령술사', '이계십자로', '영주 레이샤드', '꿈을 찾아 왔단다', '물리소년', '나는 7급 공무원이다!', '그라운드의 지배자', '환생재벌', '제국의 새벽', '맥스씨', '회귀능력자 이자성', '샤이닝 스타', '판도라 이팩트', '잠룡물용', '귀환전생', '원더풀 라이프', '노룡전기', '끝내주는 조상 탓']
# ['엘리멘탈 마스터 2부(정령왕 가라사대)', '신개척시대', '이원연공', '황량몽 : 황혼의 시편', '야구 좋아하세요?', '은퇴 마왕 전기 ', '엘리멘탈 마스터 1부', '천마 레이드', '검황기', 'EPL의 전설', '헬 오브 더 시티 워', '미래에서 온 구단주', '당신의 머리 위에', '올마스터 플레이어', '히든 플레이어(전체연령가)', '시공귀환록', '브리더(Breeder)', '퍼펙트 로드', '시공천마', '마도의사']
# ['사이딘의 영주', '케이어스(Chaos)', '똑바로 살아라', '링크(LINK) 외전-무림종횡기', '태왕기 - 현왕전', '[현대물] 빅 브라더', '고려제국기(高麗帝國記)', '마법대제']
# 마지막 페이지.

# %%
print(joara_rom_page)
print(joara_rom)
print(joara_fm_page)
print(joara_fm)
# Out:
# 15
# 287
# 37
# 728
